# %%
#Data Exploration by Crystal Butler

import pandas as pd
csv_data = "Resources/pokemon.csv"

# %%
pokemon_df = pd.read_csv(csv_data)

# %%
pokemon_df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     80           1      False
# 4     65           1      False

# %%
csv_data2 = "Resources/combats.csv"

# %%
battles_df = pd.read_csv(csv_data2)

# %%
battles_df = battles_df.sort_values('First_pokemon')

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner
# 15176              1             372     372
# 45814              1             462     462
# 17362              1               6       6
# 15251              1             649     649
# 4883               1             285       1

# %%
initial_value = 1
battles_df['Battle_number'] = range(initial_value, len(battles_df) +initial_value)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5

# %%
battles_df['Did_the_first_pokemon_win?'] = (battles_df['First_pokemon'] == battles_df['Winner']).astype(int)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           0
# 45814                           0
# 17362                           0
# 15251                           0
# 4883                            1

# %%
battles2_df = battles_df.copy()

# %%
battles2_df = battles2_df.iloc[:,[1,0,2,3]]

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5

# %%
battles2_df['Did_the_first_pokemon_win?'] = (battles2_df['Second_pokemon'] == battles2_df['Winner']).astype(int)

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number  \
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
battles2_df.rename(columns = {'Second_pokemon':'First_pokemon', 'First_pokemon':'Second_pokemon'}, inplace = True)

# %%
battles2_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176            372               1     372              1
# 45814            462               1     462              2
# 17362              6               1       6              3
# 15251            649               1     649              4
# 4883             285               1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
all_battles_df = pd.concat([battles_df, battles2_df], axis=0)

# %%
all_battles_df = all_battles_df.sort_values('Battle_number')

# %%
all_battles_df.dtypes
# Out:
# First_pokemon                 int64
# Second_pokemon                int64
# Winner                        int64
# Battle_number                 int32
# Did_the_first_pokemon_win?    int32
# dtype: object

# %%
merged_df = pd.merge(all_battles_df,pokemon_df, how='inner', left_on=['First_pokemon'], right_on = ['#'])
#new_df = pd.merge(all_battles_df, pokemon_df,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])
merged_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner  Battle_number  \
# 0              1             372     372              1
# 1              1             462     462              2
# 2              1               6       6              3
# 3              1             649     649              4
# 4              1             285       1              5
#
#    Did_the_first_pokemon_win?  #       Name Type 1  Type 2  HP  Attack  \
# 0                           0  1  Bulbasaur  Grass  Poison  45      49
# 1                           0  1  Bulbasaur  Grass  Poison  45      49
# 2                           0  1  Bulbasaur  Grass  Poison  45      49
# 3                           0  1  Bulbasaur  Grass  Poison  45      49
# 4                           1  1  Bulbasaur  Grass  Poison  45      49
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       49       65       65     45           1      False
# 1       49       65       65     45           1      False
# ...

# %%
merged_df = merged_df.iloc[:,[3,0,6,1,2,4]]

# %%
merged_df.rename(columns = {'Name':'First_name'},inplace = True)
#battles2_df.rename(columns = {'Second_pokemon':'First_pokemon', 'First_pokemon':'Second_pokemon'}, inplace = True)

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon First_name  Second_pokemon  Winner  \
# 0              1              1  Bulbasaur             372     372
# 1              2              1  Bulbasaur             462     462
# 2              3              1  Bulbasaur               6       6
# 3              4              1  Bulbasaur             649     649
# 4              5              1  Bulbasaur             285       1
#
#    Did_the_first_pokemon_win?
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           1

# %%
merged_df = pd.merge(merged_df,pokemon_df, how='inner', left_on=['Second_pokemon'], right_on = ['#'])

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon                First_name  Second_pokemon  \
# 0              1              1                 Bulbasaur             372
# 1          23232            638                Gothitelle             372
# 2          24480            391                   Tropius             372
# 3          23257            717  Meloetta Pirouette Forme             372
# 4          23218            558                     Tepig             372
#
#    Winner  Did_the_first_pokemon_win?    #      Name Type 1  Type 2  HP  \
# 0     372                           0  372  Barboach  Water  Ground  50
# 1     638                           1  372  Barboach  Water  Ground  50
# 2     372                           0  372  Barboach  Water  Ground  50
# 3     717                           1  372  Barboach  Water  Ground  50
# 4     372                           0  372  Barboach  Water  Ground  50
#
#    Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
merged_df.rename(columns = {'Name':'Second_name'},inplace = True)

# %%
merged_df = merged_df.iloc[:,[0,1,2,3,7,4,5]]

# %%
merged_df = merged_df.sort_values('Battle_number')

# %%
merged_df.head()
# Out:
#        Battle_number  First_pokemon  First_name  Second_pokemon Second_name  \
# 0                  1              1   Bulbasaur             372    Barboach
# 15447              1            372    Barboach               1   Bulbasaur
# 15448              2            462      Mothim               1   Bulbasaur
# 148                2              1   Bulbasaur             462      Mothim
# 15449              3              6  Charmeleon               1   Bulbasaur
#
#        Winner  Did_the_first_pokemon_win?
# 0         372                           0
# 15447     372                           1
# 15448     462                           1
# 148       462                           0
# 15449       6                           1

# %%
winner_df_names = merged_df.iloc[:,[0,2,4,6]]

# %%
winner_df_names.head()
# Out:
#        Battle_number  First_name Second_name  Did_the_first_pokemon_win?
# 0                  1   Bulbasaur    Barboach                           0
# 15447              1    Barboach   Bulbasaur                           1
# 15448              2      Mothim   Bulbasaur                           1
# 148                2   Bulbasaur      Mothim                           0
# 15449              3  Charmeleon   Bulbasaur                           1

# %%
#importing in scraped web data to bring in Pokemon tiers info

csv_data3 = "Resources/pokemon_with_tiers.csv"
tiers_df = pd.read_csv(csv_data3)

# %%
#viewing dataframe
tiers_df.head()
# Out:
#    #           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1      Bulbasaur  Grass  Poison  45      49       49       65       65
# 1  2        Ivysaur  Grass  Poison  60      62       63       80       80
# 2  3       Venusaur  Grass  Poison  80      82       83      100      100
# 3  4  Mega Venusaur  Grass  Poison  80     100      123      122      120
# 4  5     Charmander   Fire     NaN  39      52       43       60       50
#
#    Speed  Generation  Legendary Tier
# 0     45           1      False   LC
# 1     60           1      False  NFE
# 2     80           1      False   RU
# 3     80           1      False   OU
# 4     65           1      False   LC

# %%
#merging tier_df and merged_w_tiers dataframe, so First Name can have it's attributes associated with the pokemon that have battled
merged_w_tiers = pd.merge(tiers_df,merged_df, how='left', left_on=['Name'], right_on=['First_name'])

# %%
#viewing dataframe
merged_w_tiers.head()
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 2  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 3  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 4  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary Tier  Battle_number  First_pokemon First_name  \
# 0           1      False   LC            1.0            1.0  Bulbasaur
# 1           1      False   LC            2.0            1.0  Bulbasaur
# 2           1      False   LC            3.0            1.0  Bulbasaur
# 3           1      False   LC            4.0            1.0  Bulbasaur
# 4           1      False   LC            5.0            1.0  Bulbasaur
#
#    Second_pokemon Second_name  Winner  Did_the_first_pokemon_win?
# ...

# %%
#merging tier_df and merged_w_tiers dataframe, so Second Name can have it's attributes as well
merged_w_tiers2 = pd.merge(tiers_df,merged_w_tiers, how='left', left_on=['Name'], right_on=['Second_name']).sort_values('Battle_number')

# %%
#viewing columns for renaming
merged_w_tiers2.columns
# Out:
# Index(['#_x', 'Name_x', 'Type 1_x', 'Type 2_x', 'HP_x', 'Attack_x',
#        'Defense_x', 'Sp. Atk_x', 'Sp. Def_x', 'Speed_x', 'Generation_x',
#        'Legendary_x', 'Tier_x', '#_y', 'Name_y', 'Type 1_y', 'Type 2_y',
#        'HP_y', 'Attack_y', 'Defense_y', 'Sp. Atk_y', 'Sp. Def_y', 'Speed_y',
#        'Generation_y', 'Legendary_y', 'Tier_y', 'Battle_number',
#        'First_pokemon', 'First_name', 'Second_pokemon', 'Second_name',
#        'Winner', 'Did_the_first_pokemon_win?'],
#       dtype='object')

# %%
#Renaming columns to reflect which attributes go to which Pokemon (First or Second)
merged_w_tiers2 = merged_w_tiers2.rename(columns={'#_x':'#_Second', 'Name_x':'Second_Name', 'Type 1_x':'Type 1_Second', 'Type 2_x':'Type 2_Second', 'HP_x':'HP_Second', 'Attack_x':'Attack_Second',
       'Defense_x':'Defense_Second', 'Sp. Atk_x':'Sp. Atk_Second', 'Sp. Def_x':'Sp. Def_Second', 'Speed_x':'Speed_Second', 'Generation_x':'Generation_Second',
       'Legendary_x':'Legendary_Second', 'Tier_x':'Tier_Second', '#_y':'#_First', 'Name_y':'First_Name', 'Type 1_y':'Type 1_First', 'Type 2_y':'Type 2_First',
       'HP_y':'HP_First', 'Attack_y':'Attack_First', 'Defense_y':'Defense_First', 'Sp. Atk_y':'Sp. Atk_First', 'Sp. Def_y':'Sp. Def_First', 'Speed_y':'Speed_First',
       'Generation_y':'Generation_First', 'Legendary_y':'Legendary_First', 'Tier_y':'Tier_First' })

# %%
#Sorting by Battle Number
merged_w_tiers2 = merged_w_tiers2.sort_values('Battle_number')

# %%
#Filtering to just Pokemon without battles
orphan_pokemon = merged_w_tiers2[merged_w_tiers2['Battle_number'].isnull()]

# %%
#Dataframe of Pokemon that haven't battled

orphan_pokemon.head()
# Out:
#       #_Second Second_Name Type 1_Second Type 2_Second  HP_Second  \
# 1057        12   Blastoise         Water           NaN         79
# 3442        33   Sandshrew        Ground           NaN         50
# 4635        46  Wigglytuff        Normal         Fairy        140
# 6830        66     Poliwag         Water           NaN         40
# 8109        78  Victreebel         Grass        Poison         80
#
#       Attack_Second  Defense_Second  Sp. Atk_Second  Sp. Def_Second  \
# 1057             83             100              85             105
# 3442             75              85              20              30
# 4635             70              45              85              50
# 6830             50              40              40              40
# 8109            105              65             100              70
#
#       Speed_Second  ...  Generation_First  Legendary_First Tier_First  \
# 1057            78  ...               NaN              NaN        NaN
# ...

# %%
#filtering out Pokemon that haven't battled
merged_reduced =merged_w_tiers2.dropna(subset=['Battle_number']).sort_values('Battle_number')

# %%
#Dataframe with only Pokemon that were involved in a battle

merged_reduced.head()
# Out:
#        #_Second Second_Name Type 1_Second Type 2_Second  HP_Second  \
# 65            1   Bulbasaur         Grass        Poison         45
# 42104       372    Barboach         Water        Ground         50
# 79            1   Bulbasaur         Grass        Poison         45
# 51724       462      Mothim           Bug        Flying         70
# 0             1   Bulbasaur         Grass        Poison         45
#
#        Attack_Second  Defense_Second  Sp. Atk_Second  Sp. Def_Second  \
# 65                49              49              65              65
# 42104             48              43              46              41
# 79                49              49              65              65
# 51724             94              50              94              50
# 0                 49              49              65              65
#
#        Speed_Second  ...  Generation_First  Legendary_First Tier_First  \
# 65               45  ...               3.0            False         LC
# ...

# %%
merged_reduced.columns
# Out:
# Index(['#_Second', 'Second_Name', 'Type 1_Second', 'Type 2_Second',
#        'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp. Atk_Second',
#        'Sp. Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '#_First', 'First_Name',
#        'Type 1_First', 'Type 2_First', 'HP_First', 'Attack_First',
#        'Defense_First', 'Sp. Atk_First', 'Sp. Def_First', 'Speed_First',
#        'Generation_First', 'Legendary_First', 'Tier_First', 'Battle_number',
#        'First_pokemon', 'First_name', 'Second_pokemon', 'Second_name',
#        'Winner', 'Did_the_first_pokemon_win?'],
#       dtype='object')

# %%
merged_reduced[['#_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp. Atk_Second',
       'Sp. Def_Second', 'Speed_Second', 'Generation_Second', '#_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp. Atk_First', 'Sp. Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win?']] = merged_reduced[['#_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp. Atk_Second',
       'Sp. Def_Second', 'Speed_Second', 'Generation_Second', '#_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp. Atk_First', 'Sp. Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win?']].astype(int)

# %%
merged_reduced.columns
# Out:
# Index(['#_Second', 'Second_Name', 'Type 1_Second', 'Type 2_Second',
#        'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp. Atk_Second',
#        'Sp. Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '#_First', 'First_Name',
#        'Type 1_First', 'Type 2_First', 'HP_First', 'Attack_First',
#        'Defense_First', 'Sp. Atk_First', 'Sp. Def_First', 'Speed_First',
#        'Generation_First', 'Legendary_First', 'Tier_First', 'Battle_number',
#        'First_pokemon', 'First_name', 'Second_pokemon', 'Second_name',
#        'Winner', 'Did_the_first_pokemon_win?'],
#       dtype='object')

# %%
final_df = merged_reduced[['#_First', 'First_Name',
       'Type 1_First', 'Type 2_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp. Atk_First', 'Sp. Def_First', 'Speed_First',
       'Generation_First', 'Legendary_First', 'Tier_First','#_Second', 'Second_Name', 'Type 1_Second', 'Type 2_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp. Atk_Second',
       'Sp. Def_Second', 'Speed_Second', 'Generation_Second',
       'Legendary_Second', 'Tier_Second',  'Battle_number',
       'Did_the_first_pokemon_win?']]

# %%
final_df.head()
# Out:
#        #_First  First_Name Type 1_First Type 2_First  HP_First  Attack_First  \
# 65         372    Barboach        Water       Ground        50            48
# 42104        1   Bulbasaur        Grass       Poison        45            49
# 79         462      Mothim          Bug       Flying        70            94
# 51724        1   Bulbasaur        Grass       Poison        45            49
# 0            6  Charmeleon         Fire          NaN        58            64
#
#        Defense_First  Sp. Atk_First  Sp. Def_First  Speed_First  ...  \
# 65                43             46             41           60  ...
# 42104             49             65             65           45  ...
# 79                50             94             50           66  ...
# 51724             49             65             65           45  ...
# 0                 58             80             65           80  ...
#
#        Attack_Second Defense_Second Sp. Atk_Second  Sp. Def_Second  \
# ...

# %%
final_df.dtypes
# Out:
# #_First                        int32
# First_Name                    object
# Type 1_First                  object
# Type 2_First                  object
# HP_First                       int32
# Attack_First                   int32
# Defense_First                  int32
# Sp. Atk_First                  int32
# Sp. Def_First                  int32
# Speed_First                    int32
# Generation_First               int32
# Legendary_First               object
# Tier_First                    object
# #_Second                       int32
# Second_Name                   object
# Type 1_Second                 object
# Type 2_Second                 object
# HP_Second                      int32
# Attack_Second                  int32
# Defense_Second                 int32
# Sp. Atk_Second                 int32
# Sp. Def_Second                 int32
# Speed_Second                   int32
# Generation_Second              int32
# Legendary_Second                bool
# ...

# %%
final_df.index.name = "Index"

# %%
final_df.to_csv("Resources/final_df.csv")
