# %%
# Run this file first to scrape Pokemon tier data from smogon.com, combine the data with pokemon and battle stats from Kaggle, and generate a sqlite db

# %%
# Import relevant libraries
import requests
import re
import json
import pandas as pd
import numpy as np

# %%
# Web scraping by Lea Jinks

# %%
# this cell modified from https://stackoverflow.com/q/60017438/19966544
response = requests.get('https://www.smogon.com/dex/xy/pokemon/')

# pull JSON from response text via regex
data = "".join(re.findall(r'dexSettings = (\{.*\})', response.text))

# parse JSON
data = json.loads(data)

# query JSON to return relevant info
data = data.get('injectRpcs', [])[1][1].get('pokemon')

# %%
# make list of pokemon names
name_list = []
for row in data:
  name = row.get('name')

  # make names match original csv by removing hyphens and 
  x = name.split('-')
  if "Mega" in x:
    x.reverse()
    result = " ".join(x)
  else:
    result = " ".join(x)
  name_list.append(result)

# make list of tiers
tier_list = []
for row in data:
  tier_list.append(row.get('formats'))

# %%
# create df with name and tier values
tier_df = pd.DataFrame(name_list, columns = ["Name"])
tier_df.insert(1, "Tier", tier_list)
tier_df['Tier'] = tier_df['Tier'].str[0]
tier_df
# Out:
#                    Name  Tier
# 0             Bulbasaur    LC
# 1               Ivysaur   NFE
# 2              Venusaur    RU
# 3            Charmander    LC
# 4            Charmeleon   NFE
# ..                  ...   ...
# 876      Darmanitan Zen    UU
# 877     Mega Kangaskhan  Uber
# 878  Meloetta Pirouette    RU
# 879     Mega Aerodactyl    UU
# 880      Mega Blastoise    UU
#
# [881 rows x 2 columns]

# %%
# import kaggle pokemon info dataset
pokemon_df = pd.read_csv('Resources/pokemon.csv')
pokemon_df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 12 columns]

# %%
# standardize pokenames and combine df's 
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Forme', '')
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Size', '')
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Mode', '')

# %%
# merge kaggle data with scraped tiers data
pokemon_df = pokemon_df.merge(tier_df, on='Name')

# %%
# export to json for JS formatting
pokemon_df.to_json('Resources/pokemon_with_tiers.json', orient="records", indent=4)

# %%
pokemon_df = pokemon_df.reset_index()

# %%
# rename columns to be compatible with sqlite
pokemon_df = pokemon_df.rename(columns={'#': 'Number', 'index':'_ID', 'Type 1':'Type_1', 'Type 2':'Type_2', "Sp. Atk": "Sp_Atk", 'Sp. Def': 'Sp_Def' })
pokemon_df
# Out:
#      _ID  Number           Name   Type_1  Type_2   HP  Attack  Defense  \
# 0      0       1      Bulbasaur    Grass  Poison   45      49       49
# 1      1       2        Ivysaur    Grass  Poison   60      62       63
# 2      2       3       Venusaur    Grass  Poison   80      82       83
# 3      3       4  Mega Venusaur    Grass  Poison   80     100      123
# 4      4       5     Charmander     Fire     NaN   39      52       43
# ..   ...     ...            ...      ...     ...  ...     ...      ...
# 739  739     794        Yveltal     Dark  Flying  126     131       95
# 740  740     796        Diancie     Rock   Fairy   50     100      150
# 741  741     797   Mega Diancie     Rock   Fairy   50     160      110
# 742  742     799  Hoopa Unbound  Psychic    Dark   80     160       60
# 743  743     800      Volcanion     Fire   Water   80     110      120
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary  Tier
# 0        65      65     45           1      False    LC
# 1        80      80     60           1      False   NFE
# 2       100     100     80           1      False    RU
# 3       122     120     80           1      False    OU
# 4        60      50     65           1      False    LC
# ..      ...     ...    ...         ...        ...   ...
# 739     131      98     99           6       True  Uber
# 740     100     150     50           6       True    RU
# 741     160     110    110           6       True    OU
# 742     170     130     80           6       True  Uber
# 743     130      90     70           6       True    OU
#
# [744 rows x 14 columns]

# %%
# create sqlite file for flask app by Becky Klosowski

# %%
import sqlite3
from pathlib import Path

# %%
database_path = "Resources/pokemon_with_tiers.sqlite"
Path(database_path).touch()

# %%
conn = sqlite3.connect(database_path)
c = conn.cursor()

# %%
c.execute('''DROP TABLE IF EXISTS poketiers;''')

# %%
c.execute('''CREATE TABLE poketiers(
    _ID INT NOT NULL PRIMARY KEY,
    Number INT NOT NULL,
  	Name VARCHAR(40) NOT NULL,
    Type_1 VARCHAR(40),
	Type_2 VARCHAR(40),
	HP INT NOT NULL,
	Attack INT NOT NULL,
	Defense INT NOT NULL,
	Sp_Atk INT NOT NULL,
	Sp_Def INT NOT NULL,
	Speed INT NOT NULL,
	Generation INT NOT NULL,
	Legendary INT NOT NULL,
	Tier VARCHAR(40) NOT NULL
	);''')

# %%
pokemon_df.to_sql("poketiers", conn, if_exists='append', index = False)

# %%
c.execute('''SELECT * from poketiers''').fetchall()
# Out:
# [(0, 1, 'Bulbasaur', 'Grass', 'Poison', 45, 49, 49, 65, 65, 45, 1, 0, 'LC'),
#  (1, 2, 'Ivysaur', 'Grass', 'Poison', 60, 62, 63, 80, 80, 60, 1, 0, 'NFE'),
#  (2, 3, 'Venusaur', 'Grass', 'Poison', 80, 82, 83, 100, 100, 80, 1, 0, 'RU'),
#  (3,
#   4,
#   'Mega Venusaur',
#   'Grass',
#   'Poison',
#   80,
#   100,
#   123,
#   122,
#   120,
#   80,
#   1,
#   0,
#   'OU'),
#  (4, 5, 'Charmander', 'Fire', None, 39, 52, 43, 60, 50, 65, 1, 0, 'LC'),
#  (5, 6, 'Charmeleon', 'Fire', None, 58, 64, 58, 80, 65, 80, 1, 0, 'NFE'),
#  (6, 7, 'Charizard', 'Fire', 'Flying', 78, 84, 78, 109, 85, 100, 1, 0, 'NU'),
#  (7, 10, 'Squirtle', 'Water', None, 44, 48, 65, 50, 64, 43, 1, 0, 'LC'),
#  (8, 11, 'Wartortle', 'Water', None, 59, 63, 80, 65, 80, 58, 1, 0, 'NFE'),
#  (9, 12, 'Blastoise', 'Water', None, 79, 83, 100, 85, 105, 78, 1, 0, 'RU'),
#  (10,
#   13,
#   'Mega Blastoise',
#   'Water',
#   None,
#   79,
#   103,
#   120,
#   135,
#   115,
#   78,
#   1,
#   0,
#   'UU'),
#  (11, 14, 'Caterpie', 'Bug', None, 45, 30, 35, 20, 20, 45, 1, 0, 'LC'),
#  (12, 15, 'Metapod', 'Bug', None, 50, 20, 55, 25, 25, 30, 1, 0, 'NFE'),
#  (13,
#   16,
#   'Butterfree',
#   'Bug',
#   'Flying',
#   60,
#   45,
#   50,
#   90,
#   80,
#   70,
#   1,
#   0,
#   'Untiered'),
#  (14, 17, 'Weedle', 'Bug', 'Poison', 40, 35, 30, 20, 20, 50, 1, 0, 'LC'),
#  (15, 18, 'Kakuna', 'Bug', 'Poison', 45, 25, 50, 25, 25, 35, 1, 0, 'NFE'),
#  (16,
#   19,
#   'Beedrill',
#   'Bug',
#   'Poison',
#   65,
#   90,
#   40,
#   45,
#   80,
#   75,
#   1,
#   0,
#   'Untiered'),
#  (17,
#   20,
#   'Mega Beedrill',
#   'Bug',
#   'Poison',
#   65,
#   150,
#   40,
#   15,
#   80,
#   145,
#   1,
#   0,
#   'UU'),
#  (18, 21, 'Pidgey', 'Normal', 'Flying', 40, 45, 40, 35, 35, 56, 1, 0, 'LC'),
#  (19,
#   22,
#   'Pidgeotto',
#   'Normal',
#   'Flying',
#   63,
#   60,
#   55,
#   50,
#   50,
#   71,
#   1,
#   0,
#   'NFE'),
#  (20,
#   23,
#   'Pidgeot',
#   'Normal',
#   'Flying',
#   83,
#   80,
#   75,
#   70,
#   70,
#   101,
#   1,
#   0,
#   'Untiered'),
#  (21,
#   24,
#   'Mega Pidgeot',
#   'Normal',
#   'Flying',
#   83,
#   80,
#   80,
#   135,
#   80,
#   121,
#   1,
#   0,
#   'UUBL'),
#  (22, 25, 'Rattata', 'Normal', None, 30, 56, 35, 25, 35, 72, 1, 0, 'LC'),
#  (23,
#   26,
#   'Raticate',
#   'Normal',
#   None,
#   55,
#   81,
#   60,
#   50,
#   70,
#   97,
#   1,
#   0,
#   'Untiered'),
#  (24, 27, 'Spearow', 'Normal', 'Flying', 40, 60, 30, 31, 31, 70, 1, 0, 'LC'),
#  (25,
#   28,
#   'Fearow',
#   'Normal',
#   'Flying',
#   65,
#   90,
#   65,
#   61,
#   61,
#   100,
#   1,
#   0,
#   'Untiered'),
#  (26, 29, 'Ekans', 'Poison', None, 35, 60, 44, 40, 54, 55, 1, 0, 'LC'),
#  (27, 30, 'Arbok', 'Poison', None, 60, 85, 69, 65, 79, 80, 1, 0, 'PU'),
#  (28, 31, 'Pikachu', 'Electric', None, 35, 55, 40, 50, 50, 90, 1, 0, 'NFE'),
#  (29, 32, 'Raichu', 'Electric', None, 60, 90, 55, 90, 80, 110, 1, 0, 'PU'),
#  (30, 33, 'Sandshrew', 'Ground', None, 50, 75, 85, 20, 30, 40, 1, 0, 'LC'),
#  (31, 34, 'Sandslash', 'Ground', None, 75, 100, 110, 45, 55, 65, 1, 0, 'NU'),
#  (32, 36, 'Nidorina', 'Poison', None, 70, 62, 67, 55, 55, 56, 1, 0, 'NFE'),
#  (33, 37, 'Nidoqueen', 'Poison', 'Ground', 90, 92, 87, 75, 85, 76, 1, 0, 'UU'),
#  (34, 39, 'Nidorino', 'Poison', None, 61, 72, 57, 55, 55, 65, 1, 0, 'NFE'),
#  (35, 40, 'Nidoking', 'Poison', 'Ground', 81, 102, 77, 85, 75, 85, 1, 0, 'UU'),
#  (36, 41, 'Clefairy', 'Fairy', None, 70, 45, 48, 60, 65, 35, 1, 0, 'PU'),
#  (37, 42, 'Clefable', 'Fairy', None, 95, 70, 73, 95, 90, 60, 1, 0, 'OU'),
#  (38, 43, 'Vulpix', 'Fire', None, 38, 41, 40, 50, 65, 65, 1, 0, 'LC'),
#  (39, 44, 'Ninetales', 'Fire', None, 73, 76, 75, 81, 100, 100, 1, 0, 'PU'),
#  (40,
#   45,
#   'Jigglypuff',
#   'Normal',
#   'Fairy',
#   115,
#   45,
#   20,
#   45,
#   25,
#   20,
#   1,
#   0,
#   'NFE'),
#  (41,
#   46,
#   'Wigglytuff',
#   'Normal',
#   'Fairy',
#   140,
#   70,
#   45,
#   85,
#   50,
#   45,
#   1,
#   0,
#   'Untiered'),
#  (42, 47, 'Zubat', 'Poison', 'Flying', 40, 45, 35, 30, 40, 55, 1, 0, 'LC'),
#  (43, 48, 'Golbat', 'Poison', 'Flying', 75, 80, 70, 65, 75, 90, 1, 0, 'RU'),
#  (44, 49, 'Oddish', 'Grass', 'Poison', 45, 50, 55, 75, 65, 30, 1, 0, 'LC'),
#  (45, 50, 'Gloom', 'Grass', 'Poison', 60, 65, 70, 85, 75, 40, 1, 0, 'NFE'),
#  (46, 51, 'Vileplume', 'Grass', 'Poison', 75, 80, 85, 110, 90, 50, 1, 0, 'NU'),
#  (47, 52, 'Paras', 'Bug', 'Grass', 35, 70, 55, 45, 55, 25, 1, 0, 'LC'),
#  (48,
#   53,
#   'Parasect',
#   'Bug',
#   'Grass',
#   60,
#   95,
#   80,
#   60,
#   80,
#   30,
#   1,
#   0,
#   'Untiered'),
#  (49, 54, 'Venonat', 'Bug', 'Poison', 60, 55, 50, 40, 55, 45, 1, 0, 'LC'),
#  (50, 55, 'Venomoth', 'Bug', 'Poison', 70, 65, 60, 90, 75, 90, 1, 0, 'RUBL'),
#  (51, 56, 'Diglett', 'Ground', None, 10, 55, 25, 35, 45, 95, 1, 0, 'LC'),
#  (52, 57, 'Dugtrio', 'Ground', None, 35, 80, 50, 50, 70, 120, 1, 0, 'OU'),
#  (53, 58, 'Meowth', 'Normal', None, 40, 45, 35, 40, 40, 90, 1, 0, 'LC'),
#  (54,
#   59,
#   'Persian',
#   'Normal',
#   None,
#   65,
#   70,
#   60,
#   65,
#   65,
#   115,
#   1,
#   0,
#   'Untiered'),
#  (55, 60, 'Psyduck', 'Water', None, 50, 52, 48, 65, 50, 55, 1, 0, 'LC'),
#  (56, 61, 'Golduck', 'Water', None, 80, 82, 78, 95, 80, 85, 1, 0, 'Untiered'),
#  (57, 62, 'Mankey', 'Fighting', None, 40, 80, 35, 35, 45, 70, 1, 0, 'LC'),
#  (58, 64, 'Growlithe', 'Fire', None, 55, 70, 45, 70, 50, 60, 1, 0, 'LC'),
#  (59, 65, 'Arcanine', 'Fire', None, 90, 110, 80, 100, 80, 95, 1, 0, 'UU'),
#  (60, 66, 'Poliwag', 'Water', None, 40, 50, 40, 40, 40, 90, 1, 0, 'LC'),
#  (61, 67, 'Poliwhirl', 'Water', None, 65, 65, 65, 50, 50, 90, 1, 0, 'NFE'),
#  (62,
#   68,
#   'Poliwrath',
#   'Water',
#   'Fighting',
#   90,
#   95,
#   95,
#   70,
#   90,
#   70,
#   1,
#   0,
#   'NU'),
#  (63, 69, 'Abra', 'Psychic', None, 25, 20, 15, 105, 55, 90, 1, 0, 'LC'),
#  (64, 70, 'Kadabra', 'Psychic', None, 40, 35, 30, 120, 70, 105, 1, 0, 'PU'),
#  (65, 71, 'Alakazam', 'Psychic', None, 55, 50, 45, 135, 95, 120, 1, 0, 'UUBL'),
#  (66,
#   72,
#   'Mega Alakazam',
#   'Psychic',
#   None,
#   55,
#   50,
#   65,
#   175,
#   95,
#   150,
#   1,
#   0,
#   'UUBL'),
#  (67, 73, 'Machop', 'Fighting', None, 70, 80, 50, 35, 35, 35, 1, 0, 'LC'),
#  (68, 74, 'Machoke', 'Fighting', None, 80, 100, 70, 50, 60, 45, 1, 0, 'PUBL'),
#  (69, 75, 'Machamp', 'Fighting', None, 90, 130, 80, 65, 85, 55, 1, 0, 'UU'),
#  (70, 76, 'Bellsprout', 'Grass', 'Poison', 50, 75, 35, 70, 30, 40, 1, 0, 'LC'),
#  (71,
#   77,
#   'Weepinbell',
#   'Grass',
#   'Poison',
#   65,
#   90,
#   50,
#   85,
#   45,
#   55,
#   1,
#   0,
#   'NFE'),
#  (72,
#   78,
#   'Victreebel',
#   'Grass',
#   'Poison',
#   80,
#   105,
#   65,
#   100,
#   70,
#   70,
#   1,
#   0,
#   'PUBL'),
#  (73, 79, 'Tentacool', 'Water', 'Poison', 40, 40, 35, 50, 100, 70, 1, 0, 'LC'),
#  (74,
#   80,
#   'Tentacruel',
#   'Water',
#   'Poison',
#   80,
#   70,
#   65,
#   80,
#   120,
#   100,
#   1,
#   0,
#   'UU'),
#  (75, 81, 'Geodude', 'Rock', 'Ground', 40, 80, 100, 30, 30, 20, 1, 0, 'LC'),
#  (76, 82, 'Graveler', 'Rock', 'Ground', 55, 95, 115, 45, 45, 35, 1, 0, 'NFE'),
#  (77, 83, 'Golem', 'Rock', 'Ground', 80, 120, 130, 55, 65, 45, 1, 0, 'PU'),
#  (78, 84, 'Ponyta', 'Fire', None, 50, 85, 55, 65, 65, 90, 1, 0, 'LC'),
#  (79, 85, 'Rapidash', 'Fire', None, 65, 100, 70, 80, 80, 105, 1, 0, 'PU'),
#  (80, 86, 'Slowpoke', 'Water', 'Psychic', 90, 65, 65, 40, 40, 15, 1, 0, 'LC'),
#  (81, 87, 'Slowbro', 'Water', 'Psychic', 95, 75, 110, 100, 80, 30, 1, 0, 'OU'),
#  (82,
#   88,
#   'Mega Slowbro',
#   'Water',
#   'Psychic',
#   95,
#   75,
#   180,
#   130,
#   80,
#   30,
#   1,
#   0,
#   'OU'),
#  (83,
#   89,
#   'Magnemite',
#   'Electric',
#   'Steel',
#   25,
#   35,
#   70,
#   95,
#   55,
#   45,
#   1,
#   0,
#   'LC'),
#  (84,
#   90,
#   'Magneton',
#   'Electric',
#   'Steel',
#   50,
#   60,
#   95,
#   120,
#   70,
#   70,
#   1,
#   0,
#   'RU'),
#  (85,
#   91,
#   "Farfetch'd",
#   'Normal',
#   'Flying',
#   52,
#   65,
#   55,
#   58,
#   62,
#   60,
#   1,
#   0,
#   'Untiered'),
#  (86, 92, 'Doduo', 'Normal', 'Flying', 35, 85, 45, 35, 35, 75, 1, 0, 'LC'),
#  (87, 93, 'Dodrio', 'Normal', 'Flying', 60, 110, 70, 60, 60, 100, 1, 0, 'PU'),
#  (88, 94, 'Seel', 'Water', None, 65, 45, 55, 45, 70, 45, 1, 0, 'LC'),
#  (89, 95, 'Dewgong', 'Water', 'Ice', 90, 70, 80, 70, 95, 70, 1, 0, 'Untiered'),
#  (90, 96, 'Grimer', 'Poison', None, 80, 80, 50, 40, 50, 25, 1, 0, 'LC'),
#  (91, 97, 'Muk', 'Poison', None, 105, 105, 75, 65, 100, 50, 1, 0, 'PU'),
#  (92, 98, 'Shellder', 'Water', None, 30, 65, 100, 45, 25, 40, 1, 0, 'LC'),
#  (93, 99, 'Cloyster', 'Water', 'Ice', 50, 95, 180, 85, 45, 70, 1, 0, 'UU'),
#  (94, 100, 'Gastly', 'Ghost', 'Poison', 30, 35, 30, 100, 35, 80, 1, 0, 'LC'),
#  (95, 101, 'Haunter', 'Ghost', 'Poison', 45, 50, 45, 115, 55, 95, 1, 0, 'NU'),
#  (96, 102, 'Gengar', 'Ghost', 'Poison', 60, 65, 60, 130, 75, 110, 1, 0, 'OU'),
#  (97,
#   103,
#   'Mega Gengar',
#   'Ghost',
#   'Poison',
#   60,
#   65,
#   80,
#   170,
#   95,
#   130,
#   1,
#   0,
#   'Uber'),
#  (98, 104, 'Onix', 'Rock', 'Ground', 35, 45, 160, 30, 45, 70, 1, 0, 'LC'),
#  (99, 105, 'Drowzee', 'Psychic', None, 60, 48, 45, 43, 90, 42, 1, 0, 'LC'),
#  (100,
#   106,
#   'Hypno',
#   'Psychic',
#   None,
#   85,
#   73,
#   70,
#   73,
#   115,
#   67,
#   1,
#   0,
#   'Untiered'),
#  (101, 107, 'Krabby', 'Water', None, 30, 105, 90, 25, 25, 50, 1, 0, 'LC'),
#  (102, 108, 'Kingler', 'Water', None, 55, 130, 115, 50, 50, 75, 1, 0, 'PU'),
#  (103, 109, 'Voltorb', 'Electric', None, 40, 30, 50, 55, 55, 100, 1, 0, 'LC'),
#  (104,
#   110,
#   'Electrode',
#   'Electric',
#   None,
#   60,
#   50,
#   70,
#   80,
#   80,
#   140,
#   1,
#   0,
#   'PU'),
#  (105,
#   111,
#   'Exeggcute',
#   'Grass',
#   'Psychic',
#   60,
#   40,
#   80,
#   60,
#   45,
#   40,
#   1,
#   0,
#   'LC'),
#  (106,
#   112,
#   'Exeggutor',
#   'Grass',
#   'Psychic',
#   95,
#   95,
#   85,
#   125,
#   65,
#   55,
#   1,
#   0,
#   'PUBL'),
#  (107, 113, 'Cubone', 'Ground', None, 50, 50, 95, 40, 50, 35, 1, 0, 'LC'),
#  (108, 114, 'Marowak', 'Ground', None, 60, 80, 110, 50, 80, 45, 1, 0, 'PU'),
#  (109,
#   115,
#   'Hitmonlee',
#   'Fighting',
#   None,
#   50,
#   120,
#   53,
#   35,
#   110,
#   87,
#   1,
#   0,
#   'RU'),
#  (110,
#   116,
#   'Hitmonchan',
#   'Fighting',
#   None,
#   50,
#   105,
#   79,
#   35,
#   110,
#   76,
#   1,
#   0,
#   'NU'),
#  (111, 117, 'Lickitung', 'Normal', None, 90, 55, 75, 60, 75, 30, 1, 0, 'LC'),
#  (112, 118, 'Koffing', 'Poison', None, 40, 65, 95, 60, 45, 35, 1, 0, 'LC'),
#  (113, 119, 'Weezing', 'Poison', None, 65, 90, 120, 85, 70, 60, 1, 0, 'NU'),
#  (114, 120, 'Rhyhorn', 'Ground', 'Rock', 80, 85, 95, 30, 30, 25, 1, 0, 'LC'),
#  (115, 121, 'Rhydon', 'Ground', 'Rock', 105, 130, 120, 45, 45, 40, 1, 0, 'NU'),
#  (116, 122, 'Chansey', 'Normal', None, 250, 5, 5, 35, 105, 50, 1, 0, 'OU'),
#  (117, 123, 'Tangela', 'Grass', None, 65, 55, 115, 100, 40, 60, 1, 0, 'PU'),
#  (118, 124, 'Kangaskhan', 'Normal', None, 105, 95, 80, 40, 80, 90, 1, 0, 'NU'),
#  (119,
#   125,
#   'Mega Kangaskhan',
#   'Normal',
#   None,
#   105,
#   125,
#   100,
#   60,
#   100,
#   100,
#   1,
#   0,
#   'Uber'),
#  (120, 126, 'Horsea', 'Water', None, 30, 40, 70, 70, 25, 60, 1, 0, 'LC'),
#  (121, 127, 'Seadra', 'Water', None, 55, 65, 95, 95, 45, 85, 1, 0, 'NFE'),
#  (122, 128, 'Goldeen', 'Water', None, 45, 67, 60, 35, 50, 63, 1, 0, 'LC'),
#  (123,
#   129,
#   'Seaking',
#   'Water',
#   None,
#   80,
#   92,
#   65,
#   65,
#   80,
#   68,
#   1,
#   0,
#   'Untiered'),
#  (124, 130, 'Staryu', 'Water', None, 30, 45, 55, 70, 55, 85, 1, 0, 'LC'),
#  (125,
#   131,
#   'Starmie',
#   'Water',
#   'Psychic',
#   60,
#   75,
#   85,
#   100,
#   85,
#   115,
#   1,
#   0,
#   'OU'),
#  (126,
#   132,
#   'Mr. Mime',
#   'Psychic',
#   'Fairy',
#   40,
#   45,
#   65,
#   100,
#   120,
#   90,
#   1,
#   0,
#   'PU'),
#  (127, 133, 'Scyther', 'Bug', 'Flying', 70, 110, 80, 55, 80, 105, 1, 0, 'NU'),
#  (128, 134, 'Jynx', 'Ice', 'Psychic', 65, 50, 35, 115, 95, 95, 1, 0, 'NU'),
#  (129,
#   135,
#   'Electabuzz',
#   'Electric',
#   None,
#   65,
#   83,
#   57,
#   95,
#   85,
#   105,
#   1,
#   0,
#   'NFE'),
#  (130, 136, 'Magmar', 'Fire', None, 65, 95, 57, 100, 85, 93, 1, 0, 'NFE'),
#  (131, 137, 'Pinsir', 'Bug', None, 65, 125, 100, 55, 70, 85, 1, 0, 'NU'),
#  (132,
#   138,
#   'Mega Pinsir',
#   'Bug',
#   'Flying',
#   65,
#   155,
#   120,
#   65,
#   90,
#   105,
#   1,
#   0,
#   'OU'),
#  (133, 139, 'Tauros', 'Normal', None, 75, 100, 95, 40, 70, 110, 1, 0, 'NU'),
#  (134, 140, 'Magikarp', 'Water', None, 20, 10, 55, 15, 20, 80, 1, 0, 'LC'),
#  (135,
#   141,
#   'Gyarados',
#   'Water',
#   'Flying',
#   95,
#   125,
#   79,
#   60,
#   100,
#   81,
#   1,
#   0,
#   'UU'),
#  (136,
#   142,
#   'Mega Gyarados',
#   'Water',
#   'Dark',
#   95,
#   155,
#   109,
#   70,
#   130,
#   81,
#   1,
#   0,
#   'UUBL'),
#  (137, 143, 'Lapras', 'Water', 'Ice', 130, 85, 80, 85, 95, 60, 1, 0, 'PU'),
#  (138, 144, 'Ditto', 'Normal', None, 48, 48, 48, 48, 48, 48, 1, 0, 'Untiered'),
#  (139, 145, 'Eevee', 'Normal', None, 55, 55, 50, 45, 65, 55, 1, 0, 'LC'),
#  (140, 146, 'Vaporeon', 'Water', None, 130, 65, 60, 110, 95, 65, 1, 0, 'UU'),
#  (141, 147, 'Jolteon', 'Electric', None, 65, 65, 60, 110, 95, 130, 1, 0, 'RU'),
#  (142, 148, 'Flareon', 'Fire', None, 65, 130, 60, 95, 110, 65, 1, 0, 'PU'),
#  (143, 149, 'Porygon', 'Normal', None, 65, 60, 70, 85, 75, 40, 1, 0, 'LC'),
#  (144, 150, 'Omanyte', 'Rock', 'Water', 35, 40, 100, 90, 55, 35, 1, 0, 'LC'),
#  (145, 151, 'Omastar', 'Rock', 'Water', 70, 60, 125, 115, 70, 55, 1, 0, 'NU'),
#  (146, 152, 'Kabuto', 'Rock', 'Water', 30, 80, 90, 55, 45, 55, 1, 0, 'LC'),
#  (147, 153, 'Kabutops', 'Rock', 'Water', 60, 115, 105, 65, 70, 80, 1, 0, 'NU'),
#  (148,
#   154,
#   'Aerodactyl',
#   'Rock',
#   'Flying',
#   80,
#   105,
#   65,
#   60,
#   75,
#   130,
#   1,
#   0,
#   'RU'),
#  (149,
#   155,
#   'Mega Aerodactyl',
#   'Rock',
#   'Flying',
#   80,
#   135,
#   85,
#   70,
#   95,
#   150,
#   1,
#   0,
#   'UU'),
#  (150, 156, 'Snorlax', 'Normal', None, 160, 110, 65, 65, 110, 30, 1, 0, 'UU'),
#  (151, 157, 'Articuno', 'Ice', 'Flying', 90, 85, 100, 95, 125, 85, 1, 1, 'PU'),
#  (152,
#   158,
#   'Zapdos',
#   'Electric',
#   'Flying',
#   90,
#   90,
#   85,
#   125,
#   90,
#   100,
#   1,
#   1,
#   'OU'),
#  (153,
#   159,
#   'Moltres',
#   'Fire',
#   'Flying',
#   90,
#   100,
#   90,
#   125,
#   85,
#   90,
#   1,
#   1,
#   'RUBL'),
#  (154, 160, 'Dratini', 'Dragon', None, 41, 64, 45, 50, 50, 50, 1, 0, 'LC'),
#  (155, 161, 'Dragonair', 'Dragon', None, 61, 84, 65, 70, 70, 70, 1, 0, 'NFE'),
#  (156,
#   162,
#   'Dragonite',
#   'Dragon',
#   'Flying',
#   91,
#   134,
#   95,
#   100,
#   100,
#   80,
#   1,
#   0,
#   'OU'),
#  (157,
#   163,
#   'Mewtwo',
#   'Psychic',
#   None,
#   106,
#   110,
#   90,
#   154,
#   90,
#   130,
#   1,
#   1,
#   'Uber'),
#  (158, 166, 'Mew', 'Psychic', None, 100, 100, 100, 100, 100, 100, 1, 0, 'OU'),
#  (159, 167, 'Chikorita', 'Grass', None, 45, 49, 65, 49, 65, 45, 2, 0, 'LC'),
#  (160, 168, 'Bayleef', 'Grass', None, 60, 62, 80, 63, 80, 60, 2, 0, 'NFE'),
#  (161,
#   169,
#   'Meganium',
#   'Grass',
#   None,
#   80,
#   82,
#   100,
#   83,
#   100,
#   80,
#   2,
#   0,
#   'Untiered'),
#  (162, 170, 'Cyndaquil', 'Fire', None, 39, 52, 43, 60, 50, 65, 2, 0, 'LC'),
#  (163, 171, 'Quilava', 'Fire', None, 58, 64, 58, 80, 65, 80, 2, 0, 'NFE'),
#  (164, 172, 'Typhlosion', 'Fire', None, 78, 84, 78, 109, 85, 100, 2, 0, 'RU'),
#  (165, 173, 'Totodile', 'Water', None, 50, 65, 64, 44, 48, 43, 2, 0, 'LC'),
#  (166, 174, 'Croconaw', 'Water', None, 65, 80, 80, 59, 63, 58, 2, 0, 'NFE'),
#  (167, 175, 'Feraligatr', 'Water', None, 85, 105, 100, 79, 83, 78, 2, 0, 'UU'),
#  (168, 176, 'Sentret', 'Normal', None, 35, 46, 34, 35, 45, 20, 2, 0, 'LC'),
#  (169,
#   177,
#   'Furret',
#   'Normal',
#   None,
#   85,
#   76,
#   64,
#   45,
#   55,
#   90,
#   2,
#   0,
#   'Untiered'),
#  (170,
#   178,
#   'Hoothoot',
#   'Normal',
#   'Flying',
#   60,
#   30,
#   30,
#   36,
#   56,
#   50,
#   2,
#   0,
#   'LC'),
#  (171,
#   179,
#   'Noctowl',
#   'Normal',
#   'Flying',
#   100,
#   50,
#   50,
#   76,
#   96,
#   70,
#   2,
#   0,
#   'Untiered'),
#  (172, 180, 'Ledyba', 'Bug', 'Flying', 40, 20, 30, 40, 80, 55, 2, 0, 'LC'),
#  (173,
#   181,
#   'Ledian',
#   'Bug',
#   'Flying',
#   55,
#   35,
#   50,
#   55,
#   110,
#   85,
#   2,
#   0,
#   'Untiered'),
#  (174, 182, 'Spinarak', 'Bug', 'Poison', 40, 60, 40, 40, 40, 30, 2, 0, 'LC'),
#  (175,
#   183,
#   'Ariados',
#   'Bug',
#   'Poison',
#   70,
#   90,
#   70,
#   60,
#   60,
#   40,
#   2,
#   0,
#   'Untiered'),
#  (176, 184, 'Crobat', 'Poison', 'Flying', 85, 90, 80, 70, 80, 130, 2, 0, 'UU'),
#  (177,
#   185,
#   'Chinchou',
#   'Water',
#   'Electric',
#   75,
#   38,
#   38,
#   56,
#   56,
#   67,
#   2,
#   0,
#   'LC'),
#  (178,
#   186,
#   'Lanturn',
#   'Water',
#   'Electric',
#   125,
#   58,
#   58,
#   76,
#   76,
#   67,
#   2,
#   0,
#   'NU'),
#  (179, 187, 'Pichu', 'Electric', None, 20, 40, 15, 35, 35, 60, 2, 0, 'LC'),
#  (180, 188, 'Cleffa', 'Fairy', None, 50, 25, 28, 45, 55, 15, 2, 0, 'LC'),
#  (181,
#   189,
#   'Igglybuff',
#   'Normal',
#   'Fairy',
#   90,
#   30,
#   15,
#   40,
#   20,
#   15,
#   2,
#   0,
#   'LC'),
#  (182, 190, 'Togepi', 'Fairy', None, 35, 20, 65, 40, 65, 20, 2, 0, 'LC'),
#  (183, 191, 'Togetic', 'Fairy', 'Flying', 55, 40, 85, 80, 105, 40, 2, 0, 'RU'),
#  (184, 192, 'Natu', 'Psychic', 'Flying', 40, 50, 45, 70, 45, 70, 2, 0, 'LC'),
#  (185, 193, 'Xatu', 'Psychic', 'Flying', 65, 75, 70, 95, 70, 95, 2, 0, 'NU'),
#  (186, 194, 'Mareep', 'Electric', None, 55, 40, 40, 65, 45, 35, 2, 0, 'LC'),
#  (187, 195, 'Flaaffy', 'Electric', None, 70, 55, 55, 80, 60, 45, 2, 0, 'NFE'),
#  (188, 196, 'Ampharos', 'Electric', None, 90, 75, 85, 115, 90, 55, 2, 0, 'PU'),
#  (189,
#   197,
#   'Mega Ampharos',
#   'Electric',
#   'Dragon',
#   90,
#   95,
#   105,
#   165,
#   110,
#   45,
#   2,
#   0,
#   'UU'),
#  (190,
#   198,
#   'Bellossom',
#   'Grass',
#   None,
#   75,
#   80,
#   95,
#   90,
#   100,
#   50,
#   2,
#   0,
#   'Untiered'),
#  (191, 199, 'Marill', 'Water', 'Fairy', 70, 20, 50, 20, 50, 40, 2, 0, 'NFE'),
#  (192,
#   200,
#   'Azumarill',
#   'Water',
#   'Fairy',
#   100,
#   50,
#   80,
#   60,
#   80,
#   50,
#   2,
#   0,
#   'OU'),
#  (193,
#   201,
#   'Sudowoodo',
#   'Rock',
#   None,
#   70,
#   100,
#   115,
#   30,
#   65,
#   30,
#   2,
#   0,
#   'Untiered'),
#  (194,
#   202,
#   'Politoed',
#   'Water',
#   None,
#   90,
#   75,
#   75,
#   90,
#   100,
#   70,
#   2,
#   0,
#   'Untiered'),
#  (195, 203, 'Hoppip', 'Grass', 'Flying', 35, 35, 40, 35, 55, 50, 2, 0, 'LC'),
#  (196,
#   204,
#   'Skiploom',
#   'Grass',
#   'Flying',
#   55,
#   45,
#   50,
#   45,
#   65,
#   80,
#   2,
#   0,
#   'NFE'),
#  (197,
#   205,
#   'Jumpluff',
#   'Grass',
#   'Flying',
#   75,
#   55,
#   70,
#   55,
#   95,
#   110,
#   2,
#   0,
#   'Untiered'),
#  (198, 206, 'Aipom', 'Normal', None, 55, 70, 55, 40, 55, 85, 2, 0, 'LC'),
#  (199, 207, 'Sunkern', 'Grass', None, 30, 30, 30, 30, 30, 30, 2, 0, 'LC'),
#  (200,
#   208,
#   'Sunflora',
#   'Grass',
#   None,
#   75,
#   75,
#   55,
#   105,
#   85,
#   30,
#   2,
#   0,
#   'Untiered'),
#  (201, 209, 'Yanma', 'Bug', 'Flying', 65, 65, 45, 75, 45, 95, 2, 0, 'NFE'),
#  (202, 210, 'Wooper', 'Water', 'Ground', 55, 45, 45, 25, 25, 15, 2, 0, 'LC'),
#  (203,
#   211,
#   'Quagsire',
#   'Water',
#   'Ground',
#   95,
#   85,
#   85,
#   65,
#   65,
#   35,
#   2,
#   0,
#   'PUBL'),
#  (204, 212, 'Espeon', 'Psychic', None, 65, 65, 60, 130, 95, 110, 2, 0, 'UU'),
#  (205, 213, 'Umbreon', 'Dark', None, 95, 65, 110, 60, 130, 65, 2, 0, 'UU'),
#  (206, 214, 'Murkrow', 'Dark', 'Flying', 60, 85, 42, 85, 42, 91, 2, 0, 'NFE'),
#  (207,
#   215,
#   'Slowking',
#   'Water',
#   'Psychic',
#   95,
#   75,
#   80,
#   100,
#   110,
#   30,
#   2,
#   0,
#   'RU'),
#  (208, 216, 'Misdreavus', 'Ghost', None, 60, 60, 60, 85, 85, 85, 2, 0, 'PU'),
#  (209,
#   217,
#   'Unown',
#   'Psychic',
#   None,
#   48,
#   72,
#   48,
#   72,
#   48,
#   48,
#   2,
#   0,
#   'Untiered'),
#  (210,
#   218,
#   'Wobbuffet',
#   'Psychic',
#   None,
#   190,
#   33,
#   58,
#   33,
#   58,
#   33,
#   2,
#   0,
#   'Untiered'),
#  (211,
#   219,
#   'Girafarig',
#   'Normal',
#   'Psychic',
#   70,
#   80,
#   65,
#   90,
#   65,
#   85,
#   2,
#   0,
#   'Untiered'),
#  (212, 220, 'Pineco', 'Bug', None, 50, 65, 90, 35, 35, 15, 2, 0, 'LC'),
#  (213, 221, 'Forretress', 'Bug', 'Steel', 75, 90, 140, 60, 60, 40, 2, 0, 'UU'),
#  (214,
#   222,
#   'Dunsparce',
#   'Normal',
#   None,
#   100,
#   70,
#   70,
#   65,
#   65,
#   45,
#   2,
#   0,
#   'Untiered'),
#  (215, 223, 'Gligar', 'Ground', 'Flying', 65, 75, 105, 35, 65, 85, 2, 0, 'UU'),
#  (216, 224, 'Steelix', 'Steel', 'Ground', 75, 85, 200, 55, 65, 30, 2, 0, 'NU'),
#  (217,
#   225,
#   'Mega Steelix',
#   'Steel',
#   'Ground',
#   75,
#   125,
#   230,
#   55,
#   95,
#   30,
#   2,
#   0,
#   'RUBL'),
#  (218, 226, 'Snubbull', 'Fairy', None, 60, 80, 50, 40, 40, 30, 2, 0, 'LC'),
#  (219, 227, 'Granbull', 'Fairy', None, 90, 120, 75, 60, 60, 45, 2, 0, 'RU'),
#  (220, 228, 'Qwilfish', 'Water', 'Poison', 65, 95, 75, 55, 55, 85, 2, 0, 'RU'),
#  (221, 229, 'Scizor', 'Bug', 'Steel', 70, 130, 100, 55, 80, 65, 2, 0, 'OU'),
#  (222,
#   230,
#   'Mega Scizor',
#   'Bug',
#   'Steel',
#   70,
#   150,
#   140,
#   65,
#   100,
#   75,
#   2,
#   0,
#   'OU'),
#  (223, 231, 'Shuckle', 'Bug', 'Rock', 20, 10, 230, 10, 230, 5, 2, 0, 'RUBL'),
#  (224,
#   232,
#   'Heracross',
#   'Bug',
#   'Fighting',
#   80,
#   125,
#   75,
#   40,
#   95,
#   85,
#   2,
#   0,
#   'UU'),
#  (225,
#   233,
#   'Mega Heracross',
#   'Bug',
#   'Fighting',
#   80,
#   185,
#   115,
#   40,
#   105,
#   75,
#   2,
#   0,
#   'OU'),
#  (226, 234, 'Sneasel', 'Dark', 'Ice', 55, 95, 55, 35, 75, 115, 2, 0, 'RU'),
#  (227, 235, 'Teddiursa', 'Normal', None, 60, 80, 50, 50, 50, 40, 2, 0, 'LC'),
#  (228, 236, 'Ursaring', 'Normal', None, 90, 130, 75, 75, 75, 55, 2, 0, 'PU'),
#  (229, 237, 'Slugma', 'Fire', None, 40, 40, 40, 70, 40, 20, 2, 0, 'LC'),
#  (230,
#   238,
#   'Magcargo',
#   'Fire',
#   'Rock',
#   50,
#   50,
#   120,
#   80,
#   80,
#   30,
#   2,
#   0,
#   'Untiered'),
#  (231, 239, 'Swinub', 'Ice', 'Ground', 50, 50, 40, 30, 30, 50, 2, 0, 'LC'),
#  (232,
#   240,
#   'Piloswine',
#   'Ice',
#   'Ground',
#   100,
#   100,
#   80,
#   60,
#   60,
#   50,
#   2,
#   0,
#   'NU'),
#  (233,
#   241,
#   'Corsola',
#   'Water',
#   'Rock',
#   55,
#   55,
#   85,
#   65,
#   85,
#   35,
#   2,
#   0,
#   'Untiered'),
#  (234, 242, 'Remoraid', 'Water', None, 35, 65, 35, 65, 35, 65, 2, 0, 'LC'),
#  (235,
#   243,
#   'Octillery',
#   'Water',
#   None,
#   75,
#   105,
#   75,
#   105,
#   75,
#   45,
#   2,
#   0,
#   'Untiered'),
#  (236,
#   244,
#   'Delibird',
#   'Ice',
#   'Flying',
#   45,
#   55,
#   45,
#   65,
#   45,
#   75,
#   2,
#   0,
#   'Untiered'),
#  (237, 245, 'Mantine', 'Water', 'Flying', 65, 40, 70, 80, 140, 70, 2, 0, 'NU'),
#  (238,
#   246,
#   'Skarmory',
#   'Steel',
#   'Flying',
#   65,
#   80,
#   140,
#   40,
#   70,
#   70,
#   2,
#   0,
#   'OU'),
#  (239, 247, 'Houndour', 'Dark', 'Fire', 45, 60, 30, 80, 50, 65, 2, 0, 'LC'),
#  (240, 248, 'Houndoom', 'Dark', 'Fire', 75, 90, 50, 110, 80, 95, 2, 0, 'RU'),
#  (241,
#   249,
#   'Mega Houndoom',
#   'Dark',
#   'Fire',
#   75,
#   90,
#   90,
#   140,
#   90,
#   115,
#   2,
#   0,
#   'RUBL'),
#  (242,
#   250,
#   'Kingdra',
#   'Water',
#   'Dragon',
#   75,
#   95,
#   95,
#   95,
#   95,
#   85,
#   2,
#   0,
#   'RUBL'),
#  (243, 251, 'Phanpy', 'Ground', None, 90, 60, 60, 40, 40, 40, 2, 0, 'LC'),
#  (244, 252, 'Donphan', 'Ground', None, 90, 120, 120, 60, 60, 50, 2, 0, 'UU'),
#  (245, 253, 'Porygon2', 'Normal', None, 85, 80, 90, 105, 95, 60, 2, 0, 'UU'),
#  (246,
#   254,
#   'Stantler',
#   'Normal',
#   None,
#   73,
#   95,
#   62,
#   85,
#   65,
#   85,
#   2,
#   0,
#   'Untiered'),
#  (247, 255, 'Smeargle', 'Normal', None, 55, 20, 35, 20, 45, 75, 2, 0, 'PU'),
#  (248, 256, 'Tyrogue', 'Fighting', None, 35, 35, 35, 35, 35, 35, 2, 0, 'LC'),
#  (249,
#   257,
#   'Hitmontop',
#   'Fighting',
#   None,
#   50,
#   95,
#   95,
#   35,
#   110,
#   70,
#   2,
#   0,
#   'RU'),
#  (250, 258, 'Smoochum', 'Ice', 'Psychic', 45, 30, 15, 85, 65, 65, 2, 0, 'LC'),
#  (251, 259, 'Elekid', 'Electric', None, 45, 63, 37, 65, 55, 95, 2, 0, 'LC'),
#  (252, 260, 'Magby', 'Fire', None, 45, 75, 37, 70, 55, 83, 2, 0, 'LC'),
#  (253, 261, 'Miltank', 'Normal', None, 95, 80, 105, 40, 70, 100, 2, 0, 'NU'),
#  (254, 262, 'Blissey', 'Normal', None, 255, 10, 10, 75, 135, 55, 2, 0, 'UU'),
#  (255, 263, 'Raikou', 'Electric', None, 90, 85, 75, 115, 100, 115, 2, 1, 'OU'),
#  (256, 264, 'Entei', 'Fire', None, 115, 115, 85, 90, 75, 100, 2, 1, 'UU'),
#  (257, 265, 'Suicune', 'Water', None, 100, 75, 115, 90, 115, 85, 2, 1, 'UU'),
#  (258, 266, 'Larvitar', 'Rock', 'Ground', 50, 64, 50, 45, 50, 41, 2, 0, 'LC'),
#  (259, 267, 'Pupitar', 'Rock', 'Ground', 70, 84, 70, 65, 70, 51, 2, 0, 'NFE'),
#  (260,
#   268,
#   'Tyranitar',
#   'Rock',
#   'Dark',
#   100,
#   134,
#   110,
#   95,
#   100,
#   61,
#   2,
#   0,
#   'OU'),
#  (261,
#   269,
#   'Mega Tyranitar',
#   'Rock',
#   'Dark',
#   100,
#   164,
#   150,
#   95,
#   120,
#   71,
#   2,
#   0,
#   'OU'),
#  (262,
#   270,
#   'Lugia',
#   'Psychic',
#   'Flying',
#   106,
#   90,
#   130,
#   90,
#   154,
#   110,
#   2,
#   1,
#   'Uber'),
#  (263,
#   272,
#   'Celebi',
#   'Psychic',
#   'Grass',
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   2,
#   0,
#   'UU'),
#  (264, 273, 'Treecko', 'Grass', None, 40, 45, 35, 65, 55, 70, 3, 0, 'LC'),
#  (265, 274, 'Grovyle', 'Grass', None, 50, 65, 45, 85, 65, 95, 3, 0, 'NFE'),
#  (266, 275, 'Sceptile', 'Grass', None, 70, 85, 65, 105, 85, 120, 3, 0, 'NUBL'),
#  (267,
#   276,
#   'Mega Sceptile',
#   'Grass',
#   'Dragon',
#   70,
#   110,
#   75,
#   145,
#   85,
#   145,
#   3,
#   0,
#   'UU'),
#  (268, 277, 'Torchic', 'Fire', None, 45, 60, 40, 70, 50, 45, 3, 0, 'LC'),
#  (269,
#   278,
#   'Combusken',
#   'Fire',
#   'Fighting',
#   60,
#   85,
#   60,
#   85,
#   60,
#   55,
#   3,
#   0,
#   'PU'),
#  (270,
#   279,
#   'Blaziken',
#   'Fire',
#   'Fighting',
#   80,
#   120,
#   70,
#   110,
#   70,
#   80,
#   3,
#   0,
#   'Uber'),
#  (271,
#   280,
#   'Mega Blaziken',
#   'Fire',
#   'Fighting',
#   80,
#   160,
#   80,
#   130,
#   80,
#   100,
#   3,
#   0,
#   'Uber'),
#  (272, 281, 'Mudkip', 'Water', None, 50, 70, 50, 50, 50, 40, 3, 0, 'LC'),
#  (273,
#   282,
#   'Marshtomp',
#   'Water',
#   'Ground',
#   70,
#   85,
#   70,
#   60,
#   70,
#   50,
#   3,
#   0,
#   'NFE'),
#  (274,
#   283,
#   'Swampert',
#   'Water',
#   'Ground',
#   100,
#   110,
#   90,
#   85,
#   90,
#   60,
#   3,
#   0,
#   'UU'),
#  (275,
#   284,
#   'Mega Swampert',
#   'Water',
#   'Ground',
#   100,
#   150,
#   110,
#   95,
#   110,
#   70,
#   3,
#   0,
#   'UU'),
#  (276, 285, 'Poochyena', 'Dark', None, 35, 55, 35, 30, 30, 35, 3, 0, 'LC'),
#  (277,
#   286,
#   'Mightyena',
#   'Dark',
#   None,
#   70,
#   90,
#   70,
#   60,
#   60,
#   70,
#   3,
#   0,
#   'Untiered'),
#  (278, 287, 'Zigzagoon', 'Normal', None, 38, 30, 41, 30, 41, 60, 3, 0, 'LC'),
#  (279, 288, 'Linoone', 'Normal', None, 78, 70, 61, 50, 61, 100, 3, 0, 'PUBL'),
#  (280, 289, 'Wurmple', 'Bug', None, 45, 45, 35, 20, 30, 20, 3, 0, 'LC'),
#  (281, 290, 'Silcoon', 'Bug', None, 50, 35, 55, 25, 25, 15, 3, 0, 'NFE'),
#  (282,
#   291,
#   'Beautifly',
#   'Bug',
#   'Flying',
#   60,
#   70,
#   50,
#   100,
#   50,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (283, 292, 'Cascoon', 'Bug', None, 50, 35, 55, 25, 25, 15, 3, 0, 'NFE'),
#  (284,
#   293,
#   'Dustox',
#   'Bug',
#   'Poison',
#   60,
#   50,
#   70,
#   50,
#   90,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (285, 294, 'Lotad', 'Water', 'Grass', 40, 30, 30, 40, 50, 30, 3, 0, 'LC'),
#  (286, 295, 'Lombre', 'Water', 'Grass', 60, 50, 50, 60, 70, 50, 3, 0, 'NFE'),
#  (287, 296, 'Ludicolo', 'Water', 'Grass', 80, 70, 70, 90, 100, 70, 3, 0, 'NU'),
#  (288, 297, 'Seedot', 'Grass', None, 40, 40, 50, 30, 30, 30, 3, 0, 'LC'),
#  (289, 298, 'Nuzleaf', 'Grass', 'Dark', 70, 70, 40, 60, 40, 60, 3, 0, 'NFE'),
#  (290, 299, 'Shiftry', 'Grass', 'Dark', 90, 100, 60, 90, 60, 80, 3, 0, 'NU'),
#  (291, 300, 'Taillow', 'Normal', 'Flying', 40, 55, 30, 30, 30, 85, 3, 0, 'LC'),
#  (292,
#   301,
#   'Swellow',
#   'Normal',
#   'Flying',
#   60,
#   85,
#   60,
#   50,
#   50,
#   125,
#   3,
#   0,
#   'NU'),
#  (293, 302, 'Wingull', 'Water', 'Flying', 40, 30, 30, 55, 30, 85, 3, 0, 'LC'),
#  (294,
#   303,
#   'Pelipper',
#   'Water',
#   'Flying',
#   60,
#   50,
#   100,
#   85,
#   70,
#   65,
#   3,
#   0,
#   'PU'),
#  (295, 304, 'Ralts', 'Psychic', 'Fairy', 28, 25, 25, 45, 35, 40, 3, 0, 'LC'),
#  (296, 305, 'Kirlia', 'Psychic', 'Fairy', 38, 35, 35, 65, 55, 50, 3, 0, 'NFE'),
#  (297,
#   306,
#   'Gardevoir',
#   'Psychic',
#   'Fairy',
#   68,
#   65,
#   65,
#   125,
#   115,
#   80,
#   3,
#   0,
#   'UU'),
#  (298,
#   307,
#   'Mega Gardevoir',
#   'Psychic',
#   'Fairy',
#   68,
#   85,
#   65,
#   165,
#   135,
#   100,
#   3,
#   0,
#   'OU'),
#  (299, 308, 'Surskit', 'Bug', 'Water', 40, 30, 32, 50, 52, 65, 3, 0, 'LC'),
#  (300,
#   309,
#   'Masquerain',
#   'Bug',
#   'Flying',
#   70,
#   60,
#   62,
#   80,
#   82,
#   60,
#   3,
#   0,
#   'Untiered'),
#  (301, 310, 'Shroomish', 'Grass', None, 60, 40, 60, 40, 60, 35, 3, 0, 'LC'),
#  (302,
#   311,
#   'Breloom',
#   'Grass',
#   'Fighting',
#   60,
#   130,
#   80,
#   60,
#   60,
#   70,
#   3,
#   0,
#   'OU'),
#  (303, 312, 'Slakoth', 'Normal', None, 60, 60, 60, 35, 35, 30, 3, 0, 'LC'),
#  (304, 313, 'Vigoroth', 'Normal', None, 80, 80, 80, 55, 55, 90, 3, 0, 'PUBL'),
#  (305,
#   314,
#   'Slaking',
#   'Normal',
#   None,
#   150,
#   160,
#   100,
#   95,
#   65,
#   100,
#   3,
#   0,
#   'Untiered'),
#  (306, 315, 'Nincada', 'Bug', 'Ground', 31, 45, 90, 30, 30, 40, 3, 0, 'LC'),
#  (307, 316, 'Ninjask', 'Bug', 'Flying', 61, 90, 45, 50, 50, 160, 3, 0, 'PU'),
#  (308,
#   317,
#   'Shedinja',
#   'Bug',
#   'Ghost',
#   1,
#   90,
#   45,
#   30,
#   30,
#   40,
#   3,
#   0,
#   'Untiered'),
#  (309, 318, 'Whismur', 'Normal', None, 64, 51, 23, 51, 23, 28, 3, 0, 'LC'),
#  (310, 319, 'Loudred', 'Normal', None, 84, 71, 43, 71, 43, 48, 3, 0, 'NFE'),
#  (311, 320, 'Exploud', 'Normal', None, 104, 91, 63, 91, 73, 68, 3, 0, 'RU'),
#  (312, 321, 'Makuhita', 'Fighting', None, 72, 60, 30, 20, 30, 25, 3, 0, 'LC'),
#  (313,
#   322,
#   'Hariyama',
#   'Fighting',
#   None,
#   144,
#   120,
#   60,
#   40,
#   60,
#   50,
#   3,
#   0,
#   'NU'),
#  (314, 323, 'Azurill', 'Normal', 'Fairy', 50, 20, 40, 20, 40, 20, 3, 0, 'LC'),
#  (315, 324, 'Nosepass', 'Rock', None, 30, 45, 135, 45, 90, 30, 3, 0, 'LC'),
#  (316, 325, 'Skitty', 'Normal', None, 50, 45, 45, 35, 35, 50, 3, 0, 'LC'),
#  (317,
#   326,
#   'Delcatty',
#   'Normal',
#   None,
#   70,
#   65,
#   65,
#   55,
#   55,
#   70,
#   3,
#   0,
#   'Untiered'),
#  (318, 327, 'Sableye', 'Dark', 'Ghost', 50, 75, 75, 65, 65, 50, 3, 0, 'RUBL'),
#  (319,
#   328,
#   'Mega Sableye',
#   'Dark',
#   'Ghost',
#   50,
#   85,
#   125,
#   85,
#   115,
#   20,
#   3,
#   0,
#   'Uber'),
#  (320, 329, 'Mawile', 'Steel', 'Fairy', 50, 85, 85, 55, 55, 50, 3, 0, 'PU'),
#  (321,
#   330,
#   'Mega Mawile',
#   'Steel',
#   'Fairy',
#   50,
#   105,
#   125,
#   55,
#   95,
#   50,
#   3,
#   0,
#   'Uber'),
#  (322, 331, 'Aron', 'Steel', 'Rock', 50, 70, 100, 40, 40, 30, 3, 0, 'LC'),
#  (323, 332, 'Lairon', 'Steel', 'Rock', 60, 90, 140, 50, 50, 40, 3, 0, 'NFE'),
#  (324, 333, 'Aggron', 'Steel', 'Rock', 70, 110, 180, 60, 60, 50, 3, 0, 'NU'),
#  (325,
#   334,
#   'Mega Aggron',
#   'Steel',
#   None,
#   70,
#   140,
#   230,
#   60,
#   80,
#   50,
#   3,
#   0,
#   'UU'),
#  (326,
#   335,
#   'Meditite',
#   'Fighting',
#   'Psychic',
#   30,
#   40,
#   55,
#   40,
#   55,
#   60,
#   3,
#   0,
#   'NFE'),
#  (327,
#   336,
#   'Medicham',
#   'Fighting',
#   'Psychic',
#   60,
#   60,
#   75,
#   60,
#   75,
#   80,
#   3,
#   0,
#   'RU'),
#  (328,
#   337,
#   'Mega Medicham',
#   'Fighting',
#   'Psychic',
#   60,
#   100,
#   85,
#   80,
#   85,
#   100,
#   3,
#   0,
#   'OU'),
#  (329, 338, 'Electrike', 'Electric', None, 40, 45, 40, 65, 40, 65, 3, 0, 'LC'),
#  (330,
#   339,
#   'Manectric',
#   'Electric',
#   None,
#   70,
#   75,
#   60,
#   105,
#   60,
#   105,
#   3,
#   0,
#   'NU'),
#  (331,
#   340,
#   'Mega Manectric',
#   'Electric',
#   None,
#   70,
#   75,
#   80,
#   135,
#   80,
#   135,
#   3,
#   0,
#   'OU'),
#  (332,
#   341,
#   'Plusle',
#   'Electric',
#   None,
#   60,
#   50,
#   40,
#   85,
#   75,
#   95,
#   3,
#   0,
#   'Untiered'),
#  (333,
#   342,
#   'Minun',
#   'Electric',
#   None,
#   60,
#   40,
#   50,
#   75,
#   85,
#   95,
#   3,
#   0,
#   'Untiered'),
#  (334, 343, 'Volbeat', 'Bug', None, 65, 73, 55, 47, 75, 85, 3, 0, 'Untiered'),
#  (335, 344, 'Illumise', 'Bug', None, 65, 47, 55, 73, 75, 85, 3, 0, 'Untiered'),
#  (336, 345, 'Roselia', 'Grass', 'Poison', 50, 60, 45, 100, 80, 65, 3, 0, 'PU'),
#  (337, 346, 'Gulpin', 'Poison', None, 70, 43, 53, 43, 53, 40, 3, 0, 'LC'),
#  (338,
#   347,
#   'Swalot',
#   'Poison',
#   None,
#   100,
#   73,
#   83,
#   73,
#   83,
#   55,
#   3,
#   0,
#   'Untiered'),
#  (339, 348, 'Carvanha', 'Water', 'Dark', 45, 90, 20, 65, 20, 65, 3, 0, 'LC'),
#  (340,
#   349,
#   'Sharpedo',
#   'Water',
#   'Dark',
#   70,
#   120,
#   40,
#   95,
#   40,
#   95,
#   3,
#   0,
#   'RUBL'),
#  (341,
#   350,
#   'Mega Sharpedo',
#   'Water',
#   'Dark',
#   70,
#   140,
#   70,
#   110,
#   65,
#   105,
#   3,
#   0,
#   'UU'),
#  (342, 351, 'Wailmer', 'Water', None, 130, 70, 35, 70, 35, 60, 3, 0, 'LC'),
#  (343,
#   352,
#   'Wailord',
#   'Water',
#   None,
#   170,
#   90,
#   45,
#   90,
#   45,
#   60,
#   3,
#   0,
#   'Untiered'),
#  (344, 353, 'Numel', 'Fire', 'Ground', 60, 60, 40, 65, 45, 35, 3, 0, 'LC'),
#  (345,
#   354,
#   'Camerupt',
#   'Fire',
#   'Ground',
#   70,
#   100,
#   70,
#   105,
#   75,
#   40,
#   3,
#   0,
#   'PU'),
#  (346,
#   355,
#   'Mega Camerupt',
#   'Fire',
#   'Ground',
#   70,
#   120,
#   100,
#   145,
#   105,
#   20,
#   3,
#   0,
#   'RU'),
#  (347, 356, 'Torkoal', 'Fire', None, 70, 85, 140, 85, 70, 20, 3, 0, 'PU'),
#  (348, 357, 'Spoink', 'Psychic', None, 60, 25, 35, 70, 80, 60, 3, 0, 'LC'),
#  (349, 358, 'Grumpig', 'Psychic', None, 80, 45, 65, 90, 110, 80, 3, 0, 'PU'),
#  (350,
#   359,
#   'Spinda',
#   'Normal',
#   None,
#   60,
#   60,
#   60,
#   60,
#   60,
#   60,
#   3,
#   0,
#   'Untiered'),
#  (351, 360, 'Trapinch', 'Ground', None, 45, 100, 45, 45, 45, 10, 3, 0, 'LC'),
#  (352,
#   361,
#   'Vibrava',
#   'Ground',
#   'Dragon',
#   50,
#   70,
#   50,
#   50,
#   50,
#   70,
#   3,
#   0,
#   'NFE'),
#  (353,
#   362,
#   'Flygon',
#   'Ground',
#   'Dragon',
#   80,
#   100,
#   80,
#   80,
#   80,
#   100,
#   3,
#   0,
#   'RU'),
#  (354, 363, 'Cacnea', 'Grass', None, 50, 85, 40, 85, 40, 35, 3, 0, 'LC'),
#  (355, 364, 'Cacturne', 'Grass', 'Dark', 70, 115, 60, 115, 60, 55, 3, 0, 'PU'),
#  (356, 365, 'Swablu', 'Normal', 'Flying', 45, 40, 60, 40, 75, 50, 3, 0, 'LC'),
#  (357,
#   366,
#   'Altaria',
#   'Dragon',
#   'Flying',
#   75,
#   70,
#   90,
#   70,
#   105,
#   80,
#   3,
#   0,
#   'PU'),
#  (358,
#   367,
#   'Mega Altaria',
#   'Dragon',
#   'Fairy',
#   75,
#   110,
#   110,
#   110,
#   105,
#   80,
#   3,
#   0,
#   'UUBL'),
#  (359, 368, 'Zangoose', 'Normal', None, 73, 115, 60, 60, 60, 90, 3, 0, 'NU'),
#  (360,
#   369,
#   'Seviper',
#   'Poison',
#   None,
#   73,
#   100,
#   60,
#   100,
#   60,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (361,
#   370,
#   'Lunatone',
#   'Rock',
#   'Psychic',
#   70,
#   55,
#   65,
#   95,
#   85,
#   70,
#   3,
#   0,
#   'Untiered'),
#  (362,
#   371,
#   'Solrock',
#   'Rock',
#   'Psychic',
#   70,
#   95,
#   85,
#   55,
#   65,
#   70,
#   3,
#   0,
#   'Untiered'),
#  (363, 372, 'Barboach', 'Water', 'Ground', 50, 48, 43, 46, 41, 60, 3, 0, 'LC'),
#  (364,
#   373,
#   'Whiscash',
#   'Water',
#   'Ground',
#   110,
#   78,
#   73,
#   76,
#   71,
#   60,
#   3,
#   0,
#   'Untiered'),
#  (365, 374, 'Corphish', 'Water', None, 43, 80, 65, 50, 35, 35, 3, 0, 'LC'),
#  (366, 375, 'Crawdaunt', 'Water', 'Dark', 63, 120, 85, 90, 55, 55, 3, 0, 'UU'),
#  (367, 376, 'Baltoy', 'Ground', 'Psychic', 40, 40, 55, 40, 70, 55, 3, 0, 'LC'),
#  (368,
#   377,
#   'Claydol',
#   'Ground',
#   'Psychic',
#   60,
#   70,
#   105,
#   70,
#   120,
#   75,
#   3,
#   0,
#   'NU'),
#  (369, 378, 'Lileep', 'Rock', 'Grass', 66, 41, 77, 61, 87, 23, 3, 0, 'LC'),
#  (370, 379, 'Cradily', 'Rock', 'Grass', 86, 81, 97, 81, 107, 43, 3, 0, 'NU'),
#  (371, 380, 'Anorith', 'Rock', 'Bug', 45, 95, 50, 40, 50, 75, 3, 0, 'LC'),
#  (372, 381, 'Armaldo', 'Rock', 'Bug', 75, 125, 100, 70, 80, 45, 3, 0, 'PU'),
#  (373, 382, 'Feebas', 'Water', None, 20, 15, 20, 10, 55, 80, 3, 0, 'LC'),
#  (374, 383, 'Milotic', 'Water', None, 95, 60, 79, 100, 125, 81, 3, 0, 'UU'),
#  (375,
#   384,
#   'Castform',
#   'Normal',
#   None,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   3,
#   0,
#   'Untiered'),
#  (376, 385, 'Kecleon', 'Normal', None, 60, 90, 70, 60, 120, 40, 3, 0, 'NU'),
#  (377, 386, 'Shuppet', 'Ghost', None, 44, 75, 35, 63, 33, 45, 3, 0, 'LC'),
#  (378,
#   387,
#   'Banette',
#   'Ghost',
#   None,
#   64,
#   115,
#   65,
#   83,
#   63,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (379,
#   388,
#   'Mega Banette',
#   'Ghost',
#   None,
#   64,
#   165,
#   75,
#   93,
#   83,
#   75,
#   3,
#   0,
#   'RU'),
#  (380, 389, 'Duskull', 'Ghost', None, 20, 40, 90, 30, 90, 25, 3, 0, 'LC'),
#  (381, 390, 'Dusclops', 'Ghost', None, 40, 70, 130, 60, 130, 25, 3, 0, 'NFE'),
#  (382,
#   391,
#   'Tropius',
#   'Grass',
#   'Flying',
#   99,
#   68,
#   83,
#   72,
#   87,
#   51,
#   3,
#   0,
#   'Untiered'),
#  (383,
#   392,
#   'Chimecho',
#   'Psychic',
#   None,
#   65,
#   50,
#   70,
#   95,
#   80,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (384, 393, 'Absol', 'Dark', None, 65, 130, 60, 75, 60, 75, 3, 0, 'RU'),
#  (385, 394, 'Mega Absol', 'Dark', None, 65, 150, 60, 115, 60, 115, 3, 0, 'UU'),
#  (386, 395, 'Wynaut', 'Psychic', None, 95, 23, 48, 23, 48, 23, 3, 0, 'LC'),
#  (387, 396, 'Snorunt', 'Ice', None, 50, 50, 50, 50, 50, 50, 3, 0, 'LC'),
#  (388, 397, 'Glalie', 'Ice', None, 80, 80, 80, 80, 80, 80, 3, 0, 'Untiered'),
#  (389, 398, 'Mega Glalie', 'Ice', None, 80, 120, 80, 120, 80, 100, 3, 0, 'RU'),
#  (390, 399, 'Spheal', 'Ice', 'Water', 70, 40, 50, 55, 50, 25, 3, 0, 'LC'),
#  (391, 400, 'Sealeo', 'Ice', 'Water', 90, 60, 70, 75, 70, 45, 3, 0, 'NFE'),
#  (392,
#   401,
#   'Walrein',
#   'Ice',
#   'Water',
#   110,
#   80,
#   90,
#   95,
#   90,
#   65,
#   3,
#   0,
#   'Untiered'),
#  (393, 402, 'Clamperl', 'Water', None, 35, 64, 85, 74, 55, 32, 3, 0, 'LC'),
#  (394,
#   403,
#   'Huntail',
#   'Water',
#   None,
#   55,
#   104,
#   105,
#   94,
#   75,
#   52,
#   3,
#   0,
#   'Untiered'),
#  (395, 404, 'Gorebyss', 'Water', None, 55, 84, 105, 114, 75, 52, 3, 0, 'PU'),
#  (396,
#   405,
#   'Relicanth',
#   'Water',
#   'Rock',
#   100,
#   90,
#   130,
#   45,
#   65,
#   55,
#   3,
#   0,
#   'PU'),
#  (397,
#   406,
#   'Luvdisc',
#   'Water',
#   None,
#   43,
#   30,
#   55,
#   40,
#   65,
#   97,
#   3,
#   0,
#   'Untiered'),
#  (398, 407, 'Bagon', 'Dragon', None, 45, 75, 60, 40, 30, 50, 3, 0, 'LC'),
#  (399, 408, 'Shelgon', 'Dragon', None, 65, 95, 100, 60, 50, 50, 3, 0, 'NFE'),
#  (400,
#   409,
#   'Salamence',
#   'Dragon',
#   'Flying',
#   95,
#   135,
#   80,
#   110,
#   80,
#   100,
#   3,
#   0,
#   'UUBL'),
#  (401,
#   410,
#   'Mega Salamence',
#   'Dragon',
#   'Flying',
#   95,
#   145,
#   130,
#   120,
#   90,
#   120,
#   3,
#   0,
#   'Uber'),
#  (402, 411, 'Beldum', 'Steel', 'Psychic', 40, 55, 80, 35, 60, 30, 3, 0, 'LC'),
#  (403, 412, 'Metang', 'Steel', 'Psychic', 60, 75, 100, 55, 80, 50, 3, 0, 'PU'),
#  (404,
#   413,
#   'Metagross',
#   'Steel',
#   'Psychic',
#   80,
#   135,
#   130,
#   95,
#   90,
#   70,
#   3,
#   0,
#   'UU'),
#  (405,
#   414,
#   'Mega Metagross',
#   'Steel',
#   'Psychic',
#   80,
#   145,
#   150,
#   105,
#   110,
#   110,
#   3,
#   0,
#   'OU'),
#  (406, 415, 'Regirock', 'Rock', None, 80, 100, 200, 50, 100, 50, 3, 1, 'NU'),
#  (407, 416, 'Regice', 'Ice', None, 80, 50, 100, 100, 200, 50, 3, 1, 'PU'),
#  (408, 417, 'Registeel', 'Steel', None, 80, 75, 150, 75, 150, 50, 3, 1, 'RU'),
#  (409,
#   418,
#   'Latias',
#   'Dragon',
#   'Psychic',
#   80,
#   80,
#   90,
#   110,
#   130,
#   110,
#   3,
#   1,
#   'OU'),
#  (410,
#   419,
#   'Mega Latias',
#   'Dragon',
#   'Psychic',
#   80,
#   100,
#   120,
#   140,
#   150,
#   110,
#   3,
#   1,
#   'OU'),
#  (411,
#   420,
#   'Latios',
#   'Dragon',
#   'Psychic',
#   80,
#   90,
#   80,
#   130,
#   110,
#   110,
#   3,
#   1,
#   'OU'),
#  (412,
#   421,
#   'Mega Latios',
#   'Dragon',
#   'Psychic',
#   80,
#   130,
#   100,
#   160,
#   120,
#   110,
#   3,
#   1,
#   'OU'),
#  (413, 422, 'Kyogre', 'Water', None, 100, 100, 90, 150, 140, 90, 3, 1, 'Uber'),
#  (414,
#   424,
#   'Groudon',
#   'Ground',
#   None,
#   100,
#   150,
#   140,
#   100,
#   90,
#   90,
#   3,
#   1,
#   'Uber'),
#  (415,
#   426,
#   'Rayquaza',
#   'Dragon',
#   'Flying',
#   105,
#   150,
#   90,
#   150,
#   90,
#   95,
#   3,
#   1,
#   'Uber'),
#  (416,
#   427,
#   'Mega Rayquaza',
#   'Dragon',
#   'Flying',
#   105,
#   180,
#   100,
#   180,
#   100,
#   115,
#   3,
#   1,
#   'AG'),
#  (417,
#   428,
#   'Jirachi',
#   'Steel',
#   'Psychic',
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   3,
#   1,
#   'OU'),
#  (418, 433, 'Turtwig', 'Grass', None, 55, 68, 64, 45, 55, 31, 4, 0, 'LC'),
#  (419, 434, 'Grotle', 'Grass', None, 75, 89, 85, 55, 65, 36, 4, 0, 'NFE'),
#  (420,
#   435,
#   'Torterra',
#   'Grass',
#   'Ground',
#   95,
#   109,
#   105,
#   75,
#   85,
#   56,
#   4,
#   0,
#   'NU'),
#  (421, 436, 'Chimchar', 'Fire', None, 44, 58, 44, 58, 44, 61, 4, 0, 'LC'),
#  (422,
#   437,
#   'Monferno',
#   'Fire',
#   'Fighting',
#   64,
#   78,
#   52,
#   78,
#   52,
#   81,
#   4,
#   0,
#   'PU'),
#  (423,
#   438,
#   'Infernape',
#   'Fire',
#   'Fighting',
#   76,
#   104,
#   71,
#   104,
#   71,
#   108,
#   4,
#   0,
#   'UU'),
#  (424, 439, 'Piplup', 'Water', None, 53, 51, 53, 61, 56, 40, 4, 0, 'LC'),
#  (425, 440, 'Prinplup', 'Water', None, 64, 66, 68, 81, 76, 50, 4, 0, 'PU'),
#  (426,
#   441,
#   'Empoleon',
#   'Water',
#   'Steel',
#   84,
#   86,
#   88,
#   111,
#   101,
#   60,
#   4,
#   0,
#   'UU'),
#  (427, 442, 'Starly', 'Normal', 'Flying', 40, 55, 30, 30, 30, 60, 4, 0, 'LC'),
#  (428,
#   443,
#   'Staravia',
#   'Normal',
#   'Flying',
#   55,
#   75,
#   50,
#   40,
#   40,
#   80,
#   4,
#   0,
#   'NFE'),
#  (429,
#   444,
#   'Staraptor',
#   'Normal',
#   'Flying',
#   85,
#   120,
#   70,
#   50,
#   60,
#   100,
#   4,
#   0,
#   'UUBL'),
#  (430, 445, 'Bidoof', 'Normal', None, 59, 45, 40, 35, 40, 31, 4, 0, 'LC'),
#  (431,
#   446,
#   'Bibarel',
#   'Normal',
#   'Water',
#   79,
#   85,
#   60,
#   55,
#   60,
#   71,
#   4,
#   0,
#   'Untiered'),
#  (432, 447, 'Kricketot', 'Bug', None, 37, 25, 41, 25, 41, 25, 4, 0, 'LC'),
#  (433,
#   448,
#   'Kricketune',
#   'Bug',
#   None,
#   77,
#   85,
#   51,
#   55,
#   51,
#   65,
#   4,
#   0,
#   'Untiered'),
#  (434, 449, 'Shinx', 'Electric', None, 45, 65, 34, 40, 34, 45, 4, 0, 'LC'),
#  (435, 450, 'Luxio', 'Electric', None, 60, 85, 49, 60, 49, 60, 4, 0, 'NFE'),
#  (436,
#   451,
#   'Luxray',
#   'Electric',
#   None,
#   80,
#   120,
#   79,
#   95,
#   79,
#   70,
#   4,
#   0,
#   'Untiered'),
#  (437, 452, 'Budew', 'Grass', 'Poison', 40, 30, 35, 50, 70, 55, 4, 0, 'LC'),
#  (438,
#   453,
#   'Roserade',
#   'Grass',
#   'Poison',
#   60,
#   70,
#   65,
#   125,
#   105,
#   90,
#   4,
#   0,
#   'UU'),
#  (439, 454, 'Cranidos', 'Rock', None, 67, 125, 40, 30, 30, 58, 4, 0, 'LC'),
#  (440, 455, 'Rampardos', 'Rock', None, 97, 165, 60, 65, 50, 58, 4, 0, 'PU'),
#  (441, 456, 'Shieldon', 'Rock', 'Steel', 30, 42, 118, 42, 88, 30, 4, 0, 'LC'),
#  (442,
#   457,
#   'Bastiodon',
#   'Rock',
#   'Steel',
#   60,
#   52,
#   168,
#   47,
#   138,
#   30,
#   4,
#   0,
#   'Untiered'),
#  (443, 458, 'Burmy', 'Bug', None, 40, 29, 45, 29, 45, 36, 4, 0, 'LC'),
#  (444,
#   462,
#   'Mothim',
#   'Bug',
#   'Flying',
#   70,
#   94,
#   50,
#   94,
#   50,
#   66,
#   4,
#   0,
#   'Untiered'),
#  (445, 463, 'Combee', 'Bug', 'Flying', 30, 30, 42, 30, 42, 70, 4, 0, 'LC'),
#  (446,
#   464,
#   'Vespiquen',
#   'Bug',
#   'Flying',
#   70,
#   80,
#   102,
#   80,
#   102,
#   40,
#   4,
#   0,
#   'Untiered'),
#  (447,
#   465,
#   'Pachirisu',
#   'Electric',
#   None,
#   60,
#   45,
#   70,
#   45,
#   90,
#   95,
#   4,
#   0,
#   'Untiered'),
#  (448, 466, 'Buizel', 'Water', None, 55, 65, 35, 60, 30, 85, 4, 0, 'LC'),
#  (449, 467, 'Floatzel', 'Water', None, 85, 105, 55, 85, 50, 115, 4, 0, 'PU'),
#  (450, 468, 'Cherubi', 'Grass', None, 45, 35, 45, 62, 53, 35, 4, 0, 'LC'),
#  (451,
#   469,
#   'Cherrim',
#   'Grass',
#   None,
#   70,
#   60,
#   70,
#   87,
#   78,
#   85,
#   4,
#   0,
#   'Untiered'),
#  (452, 470, 'Shellos', 'Water', None, 76, 48, 48, 57, 62, 34, 4, 0, 'LC'),
#  (453,
#   471,
#   'Gastrodon',
#   'Water',
#   'Ground',
#   111,
#   83,
#   68,
#   92,
#   82,
#   39,
#   4,
#   0,
#   'NU'),
#  (454, 472, 'Ambipom', 'Normal', None, 75, 100, 66, 60, 66, 115, 4, 0, 'RU'),
#  (455,
#   473,
#   'Drifloon',
#   'Ghost',
#   'Flying',
#   90,
#   50,
#   34,
#   60,
#   44,
#   70,
#   4,
#   0,
#   'NFE'),
#  (456,
#   474,
#   'Drifblim',
#   'Ghost',
#   'Flying',
#   150,
#   80,
#   44,
#   90,
#   54,
#   80,
#   4,
#   0,
#   'PU'),
#  (457, 475, 'Buneary', 'Normal', None, 55, 66, 44, 44, 56, 85, 4, 0, 'LC'),
#  (458,
#   476,
#   'Lopunny',
#   'Normal',
#   None,
#   65,
#   76,
#   84,
#   54,
#   96,
#   105,
#   4,
#   0,
#   'Untiered'),
#  (459,
#   477,
#   'Mega Lopunny',
#   'Normal',
#   'Fighting',
#   65,
#   136,
#   94,
#   54,
#   96,
#   135,
#   4,
#   0,
#   'OU'),
#  (460, 478, 'Mismagius', 'Ghost', None, 60, 60, 60, 105, 105, 105, 4, 0, 'NU'),
#  (461,
#   479,
#   'Honchkrow',
#   'Dark',
#   'Flying',
#   100,
#   125,
#   52,
#   105,
#   52,
#   71,
#   4,
#   0,
#   'RUBL'),
#  (462, 480, 'Glameow', 'Normal', None, 49, 55, 42, 42, 37, 85, 4, 0, 'LC'),
#  (463,
#   481,
#   'Purugly',
#   'Normal',
#   None,
#   71,
#   82,
#   64,
#   64,
#   59,
#   112,
#   4,
#   0,
#   'Untiered'),
#  (464, 482, 'Chingling', 'Psychic', None, 45, 30, 50, 65, 50, 45, 4, 0, 'LC'),
#  (465, 483, 'Stunky', 'Poison', 'Dark', 63, 63, 47, 41, 41, 74, 4, 0, 'LC'),
#  (466, 484, 'Skuntank', 'Poison', 'Dark', 103, 93, 67, 71, 61, 84, 4, 0, 'NU'),
#  (467, 485, 'Bronzor', 'Steel', 'Psychic', 57, 24, 86, 24, 86, 23, 4, 0, 'LC'),
#  (468,
#   486,
#   'Bronzong',
#   'Steel',
#   'Psychic',
#   67,
#   89,
#   116,
#   79,
#   116,
#   33,
#   4,
#   0,
#   'RU'),
#  (469, 487, 'Bonsly', 'Rock', None, 50, 80, 95, 10, 45, 10, 4, 0, 'LC'),
#  (470,
#   488,
#   'Mime Jr.',
#   'Psychic',
#   'Fairy',
#   20,
#   25,
#   45,
#   70,
#   90,
#   60,
#   4,
#   0,
#   'LC'),
#  (471, 489, 'Happiny', 'Normal', None, 100, 5, 5, 15, 65, 30, 4, 0, 'LC'),
#  (472, 490, 'Chatot', 'Normal', 'Flying', 76, 65, 45, 92, 42, 91, 4, 0, 'PU'),
#  (473,
#   491,
#   'Spiritomb',
#   'Ghost',
#   'Dark',
#   50,
#   92,
#   108,
#   92,
#   108,
#   35,
#   4,
#   0,
#   'RU'),
#  (474, 492, 'Gible', 'Dragon', 'Ground', 58, 70, 45, 40, 45, 42, 4, 0, 'LC'),
#  (475, 493, 'Gabite', 'Dragon', 'Ground', 68, 90, 65, 50, 55, 82, 4, 0, 'PU'),
#  (476,
#   494,
#   'Garchomp',
#   'Dragon',
#   'Ground',
#   108,
#   130,
#   95,
#   80,
#   85,
#   102,
#   4,
#   0,
#   'OU'),
#  (477,
#   495,
#   'Mega Garchomp',
#   'Dragon',
#   'Ground',
#   108,
#   170,
#   115,
#   120,
#   95,
#   92,
#   4,
#   0,
#   'OU'),
#  (478, 496, 'Munchlax', 'Normal', None, 135, 85, 40, 40, 85, 5, 4, 0, 'LC'),
#  (479, 497, 'Riolu', 'Fighting', None, 40, 70, 40, 35, 40, 60, 4, 0, 'LC'),
#  (480,
#   498,
#   'Lucario',
#   'Fighting',
#   'Steel',
#   70,
#   110,
#   70,
#   115,
#   70,
#   90,
#   4,
#   0,
#   'UU'),
#  (481,
#   499,
#   'Mega Lucario',
#   'Fighting',
#   'Steel',
#   70,
#   145,
#   88,
#   140,
#   70,
#   112,
#   4,
#   0,
#   'Uber'),
#  (482, 500, 'Hippopotas', 'Ground', None, 68, 72, 78, 38, 42, 32, 4, 0, 'LC'),
#  (483,
#   501,
#   'Hippowdon',
#   'Ground',
#   None,
#   108,
#   112,
#   118,
#   68,
#   72,
#   47,
#   4,
#   0,
#   'OU'),
#  (484, 502, 'Skorupi', 'Poison', 'Bug', 40, 50, 90, 30, 55, 65, 4, 0, 'LC'),
#  (485, 503, 'Drapion', 'Poison', 'Dark', 70, 90, 110, 60, 75, 95, 4, 0, 'RU'),
#  (486,
#   504,
#   'Croagunk',
#   'Poison',
#   'Fighting',
#   48,
#   61,
#   40,
#   61,
#   40,
#   50,
#   4,
#   0,
#   'LC'),
#  (487,
#   505,
#   'Toxicroak',
#   'Poison',
#   'Fighting',
#   83,
#   106,
#   65,
#   86,
#   65,
#   85,
#   4,
#   0,
#   'UU'),
#  (488,
#   506,
#   'Carnivine',
#   'Grass',
#   None,
#   74,
#   100,
#   72,
#   90,
#   72,
#   46,
#   4,
#   0,
#   'Untiered'),
#  (489, 507, 'Finneon', 'Water', None, 49, 49, 56, 49, 61, 66, 4, 0, 'LC'),
#  (490, 508, 'Lumineon', 'Water', None, 69, 69, 76, 69, 86, 91, 4, 0, 'PU'),
#  (491, 509, 'Mantyke', 'Water', 'Flying', 45, 20, 50, 60, 120, 50, 4, 0, 'LC'),
#  (492, 510, 'Snover', 'Grass', 'Ice', 60, 62, 50, 62, 60, 40, 4, 0, 'LC'),
#  (493, 511, 'Abomasnow', 'Grass', 'Ice', 90, 92, 75, 92, 85, 60, 4, 0, 'NU'),
#  (494,
#   512,
#   'Mega Abomasnow',
#   'Grass',
#   'Ice',
#   90,
#   132,
#   105,
#   132,
#   105,
#   30,
#   4,
#   0,
#   'RUBL'),
#  (495, 513, 'Weavile', 'Dark', 'Ice', 70, 120, 65, 45, 85, 125, 4, 0, 'OU'),
#  (496,
#   514,
#   'Magnezone',
#   'Electric',
#   'Steel',
#   70,
#   70,
#   115,
#   130,
#   90,
#   60,
#   4,
#   0,
#   'OU'),
#  (497, 515, 'Lickilicky', 'Normal', None, 110, 85, 95, 80, 95, 50, 4, 0, 'PU'),
#  (498,
#   516,
#   'Rhyperior',
#   'Ground',
#   'Rock',
#   115,
#   140,
#   130,
#   55,
#   55,
#   40,
#   4,
#   0,
#   'RU'),
#  (499,
#   517,
#   'Tangrowth',
#   'Grass',
#   None,
#   100,
#   100,
#   125,
#   110,
#   50,
#   50,
#   4,
#   0,
#   'OU'),
#  (500,
#   518,
#   'Electivire',
#   'Electric',
#   None,
#   75,
#   123,
#   67,
#   95,
#   85,
#   95,
#   4,
#   0,
#   'NU'),
#  (501, 519, 'Magmortar', 'Fire', None, 75, 95, 67, 125, 95, 83, 4, 0, 'NU'),
#  (502,
#   520,
#   'Togekiss',
#   'Fairy',
#   'Flying',
#   85,
#   50,
#   95,
#   120,
#   115,
#   80,
#   4,
#   0,
#   'UUBL'),
#  (503, 521, 'Yanmega', 'Bug', 'Flying', 86, 76, 86, 116, 56, 95, 4, 0, 'RUBL'),
#  (504, 522, 'Leafeon', 'Grass', None, 65, 110, 130, 60, 65, 95, 4, 0, 'PU'),
#  (505,
#   523,
#   'Glaceon',
#   'Ice',
#   None,
#   65,
#   60,
#   110,
#   130,
#   95,
#   65,
#   4,
#   0,
#   'Untiered'),
#  (506,
#   524,
#   'Gliscor',
#   'Ground',
#   'Flying',
#   75,
#   95,
#   125,
#   45,
#   75,
#   95,
#   4,
#   0,
#   'OU'),
#  (507,
#   525,
#   'Mamoswine',
#   'Ice',
#   'Ground',
#   110,
#   130,
#   80,
#   70,
#   60,
#   80,
#   4,
#   0,
#   'UU'),
#  (508,
#   527,
#   'Gallade',
#   'Psychic',
#   'Fighting',
#   68,
#   125,
#   65,
#   65,
#   115,
#   80,
#   4,
#   0,
#   'RU'),
#  (509,
#   528,
#   'Mega Gallade',
#   'Psychic',
#   'Fighting',
#   68,
#   165,
#   95,
#   65,
#   115,
#   110,
#   4,
#   0,
#   'UUBL'),
#  (510,
#   529,
#   'Probopass',
#   'Rock',
#   'Steel',
#   60,
#   55,
#   145,
#   75,
#   150,
#   40,
#   4,
#   0,
#   'PU'),
#  (511, 530, 'Dusknoir', 'Ghost', None, 45, 100, 135, 65, 135, 45, 4, 0, 'PU'),
#  (512, 531, 'Froslass', 'Ice', 'Ghost', 70, 80, 70, 80, 70, 110, 4, 0, 'RUBL'),
#  (513, 532, 'Rotom', 'Electric', 'Ghost', 50, 50, 77, 95, 77, 91, 4, 0, 'NU'),
#  (514, 538, 'Uxie', 'Psychic', None, 75, 75, 130, 75, 130, 95, 4, 1, 'RU'),
#  (515,
#   539,
#   'Mesprit',
#   'Psychic',
#   None,
#   80,
#   105,
#   105,
#   105,
#   105,
#   80,
#   4,
#   1,
#   'NU'),
#  (516, 540, 'Azelf', 'Psychic', None, 75, 125, 70, 125, 70, 115, 4, 1, 'OU'),
#  (517,
#   541,
#   'Dialga',
#   'Steel',
#   'Dragon',
#   100,
#   120,
#   120,
#   150,
#   100,
#   90,
#   4,
#   1,
#   'Uber'),
#  (518,
#   542,
#   'Palkia',
#   'Water',
#   'Dragon',
#   90,
#   120,
#   100,
#   150,
#   120,
#   100,
#   4,
#   1,
#   'Uber'),
#  (519, 543, 'Heatran', 'Fire', 'Steel', 91, 90, 106, 130, 106, 77, 4, 1, 'OU'),
#  (520,
#   544,
#   'Regigigas',
#   'Normal',
#   None,
#   110,
#   160,
#   110,
#   80,
#   110,
#   100,
#   4,
#   1,
#   'Untiered'),
#  (521,
#   547,
#   'Cresselia',
#   'Psychic',
#   None,
#   120,
#   70,
#   120,
#   75,
#   130,
#   85,
#   4,
#   0,
#   'UU'),
#  (522, 548, 'Phione', 'Water', None, 80, 80, 80, 80, 80, 80, 4, 0, 'Untiered'),
#  (523,
#   549,
#   'Manaphy',
#   'Water',
#   None,
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   4,
#   0,
#   'OU'),
#  (524, 550, 'Darkrai', 'Dark', None, 70, 90, 90, 135, 90, 125, 4, 1, 'Uber'),
#  (525,
#   553,
#   'Arceus',
#   'Normal',
#   None,
#   120,
#   120,
#   120,
#   120,
#   120,
#   120,
#   4,
#   1,
#   'Uber'),
#  (526,
#   554,
#   'Victini',
#   'Psychic',
#   'Fire',
#   100,
#   100,
#   100,
#   100,
#   100,
#   100,
#   5,
#   1,
#   'UUBL'),
#  (527, 555, 'Snivy', 'Grass', None, 45, 45, 55, 45, 55, 63, 5, 0, 'LC'),
#  (528, 556, 'Servine', 'Grass', None, 60, 60, 75, 60, 75, 83, 5, 0, 'NFE'),
#  (529, 557, 'Serperior', 'Grass', None, 75, 75, 95, 75, 95, 113, 5, 0, 'OU'),
#  (530, 558, 'Tepig', 'Fire', None, 65, 63, 45, 45, 45, 45, 5, 0, 'LC'),
#  (531,
#   559,
#   'Pignite',
#   'Fire',
#   'Fighting',
#   90,
#   93,
#   55,
#   70,
#   55,
#   55,
#   5,
#   0,
#   'NFE'),
#  (532,
#   560,
#   'Emboar',
#   'Fire',
#   'Fighting',
#   110,
#   123,
#   65,
#   100,
#   65,
#   65,
#   5,
#   0,
#   'RU'),
#  (533, 561, 'Oshawott', 'Water', None, 55, 55, 45, 63, 45, 45, 5, 0, 'LC'),
#  (534, 562, 'Dewott', 'Water', None, 75, 75, 60, 83, 60, 60, 5, 0, 'NFE'),
# ...
#   'Normal',
#   'Fairy',
#   103,
#   60,
#   126,
#   80,
#   126,
#   50,
#   5,
#   0,
#   'NU'),
#  (565, 593, 'Timburr', 'Fighting', None, 75, 80, 55, 25, 35, 35, 5, 0, 'LC'),
#  (566, 594, 'Gurdurr', 'Fighting', None, 85, 105, 85, 40, 50, 40, 5, 0, 'NU'),
#  (567,
#   595,
#   'Conkeldurr',
#   'Fighting',
#   None,
#   105,
#   140,
#   95,
#   55,
#   65,
#   45,
#   5,
#   0,
#   'UUBL'),
#  (568, 596, 'Tympole', 'Water', None, 50, 50, 40, 50, 40, 64, 5, 0, 'LC'),
#  (569,
#   597,
#   'Palpitoad',
#   'Water',
#   'Ground',
#   75,
#   65,
#   55,
#   65,
#   55,
#   69,
#   5,
#   0,
#   'NFE'),
#  (570,
#   598,
#   'Seismitoad',
#   'Water',
#   'Ground',
#   105,
#   95,
#   75,
#   85,
#   75,
#   74,
#   5,
#   0,
#   'RU'),
#  (571, 599, 'Throh', 'Fighting', None, 120, 100, 85, 30, 85, 45, 5, 0, 'PUBL'),
#  (572, 600, 'Sawk', 'Fighting', None, 75, 125, 75, 30, 75, 85, 5, 0, 'RU'),
#  (573, 601, 'Sewaddle', 'Bug', 'Grass', 45, 53, 70, 40, 60, 42, 5, 0, 'LC'),
#  (574, 602, 'Swadloon', 'Bug', 'Grass', 55, 63, 90, 50, 80, 42, 5, 0, 'NFE'),
#  (575, 603, 'Leavanny', 'Bug', 'Grass', 75, 103, 80, 70, 80, 92, 5, 0, 'PU'),
#  (576, 604, 'Venipede', 'Bug', 'Poison', 30, 45, 59, 30, 39, 57, 5, 0, 'LC'),
#  (577,
#   605,
#   'Whirlipede',
#   'Bug',
#   'Poison',
#   40,
#   55,
#   99,
#   40,
#   79,
#   47,
#   5,
#   0,
#   'NFE'),
#  (578,
#   606,
#   'Scolipede',
#   'Bug',
#   'Poison',
#   60,
#   100,
#   89,
#   55,
#   69,
#   112,
#   5,
#   0,
#   'UUBL'),
#  (579, 607, 'Cottonee', 'Grass', 'Fairy', 40, 27, 60, 37, 50, 66, 5, 0, 'LC'),
#  (580,
#   608,
#   'Whimsicott',
#   'Grass',
#   'Fairy',
#   60,
#   67,
#   85,
#   77,
#   75,
#   116,
#   5,
#   0,
#   'UU'),
#  (581, 609, 'Petilil', 'Grass', None, 45, 35, 50, 70, 50, 30, 5, 0, 'LC'),
#  (582, 610, 'Lilligant', 'Grass', None, 70, 60, 75, 110, 75, 90, 5, 0, 'NU'),
#  (583, 611, 'Basculin', 'Water', None, 70, 92, 65, 80, 55, 98, 5, 0, 'PU'),
#  (584, 612, 'Sandile', 'Ground', 'Dark', 50, 72, 35, 35, 35, 65, 5, 0, 'LC'),
#  (585, 613, 'Krokorok', 'Ground', 'Dark', 60, 82, 45, 45, 45, 74, 5, 0, 'NFE'),
#  (586,
#   614,
#   'Krookodile',
#   'Ground',
#   'Dark',
#   95,
#   117,
#   80,
#   65,
#   70,
#   92,
#   5,
#   0,
#   'UU'),
#  (587, 615, 'Darumaka', 'Fire', None, 70, 90, 45, 15, 45, 50, 5, 0, 'LC'),
#  (588,
#   618,
#   'Maractus',
#   'Grass',
#   None,
#   75,
#   86,
#   67,
#   106,
#   67,
#   60,
#   5,
#   0,
#   'Untiered'),
#  (589, 619, 'Dwebble', 'Bug', 'Rock', 50, 65, 85, 35, 35, 55, 5, 0, 'LC'),
#  (590, 620, 'Crustle', 'Bug', 'Rock', 70, 95, 125, 65, 75, 45, 5, 0, 'PU'),
#  (591, 621, 'Scraggy', 'Dark', 'Fighting', 50, 75, 70, 35, 70, 48, 5, 0, 'LC'),
#  (592,
#   622,
#   'Scrafty',
#   'Dark',
#   'Fighting',
#   65,
#   90,
#   115,
#   45,
#   115,
#   58,
#   5,
#   0,
#   'RU'),
#  (593,
#   623,
#   'Sigilyph',
#   'Psychic',
#   'Flying',
#   72,
#   58,
#   80,
#   103,
#   80,
#   97,
#   5,
#   0,
#   'RU'),
#  (594, 624, 'Yamask', 'Ghost', None, 38, 30, 85, 55, 65, 30, 5, 0, 'LC'),
#  (595, 625, 'Cofagrigus', 'Ghost', None, 58, 50, 145, 95, 105, 30, 5, 0, 'RU'),
#  (596, 626, 'Tirtouga', 'Water', 'Rock', 54, 78, 103, 53, 45, 22, 5, 0, 'LC'),
#  (597,
#   627,
#   'Carracosta',
#   'Water',
#   'Rock',
#   74,
#   108,
#   133,
#   83,
#   65,
#   32,
#   5,
#   0,
#   'PUBL'),
#  (598, 628, 'Archen', 'Rock', 'Flying', 55, 112, 45, 74, 45, 70, 5, 0, 'LC'),
#  (599,
#   629,
#   'Archeops',
#   'Rock',
#   'Flying',
#   75,
#   140,
#   65,
#   112,
#   65,
#   110,
#   5,
#   0,
#   'NU'),
#  (600, 630, 'Trubbish', 'Poison', None, 50, 50, 62, 40, 62, 65, 5, 0, 'LC'),
#  (601, 631, 'Garbodor', 'Poison', None, 80, 95, 82, 60, 82, 75, 5, 0, 'NU'),
#  (602, 632, 'Zorua', 'Dark', None, 40, 65, 40, 80, 40, 65, 5, 0, 'LC'),
#  (603, 633, 'Zoroark', 'Dark', None, 60, 105, 60, 120, 60, 105, 5, 0, 'RUBL'),
#  (604, 634, 'Minccino', 'Normal', None, 55, 50, 40, 40, 40, 75, 5, 0, 'LC'),
#  (605, 635, 'Cinccino', 'Normal', None, 75, 95, 60, 65, 60, 115, 5, 0, 'RU'),
#  (606, 636, 'Gothita', 'Psychic', None, 45, 30, 50, 55, 65, 45, 5, 0, 'LC'),
#  (607, 637, 'Gothorita', 'Psychic', None, 60, 45, 70, 75, 85, 55, 5, 0, 'NFE'),
#  (608,
#   638,
#   'Gothitelle',
#   'Psychic',
#   None,
#   70,
#   55,
#   95,
#   95,
#   110,
#   65,
#   5,
#   0,
#   'Untiered'),
#  (609, 639, 'Solosis', 'Psychic', None, 45, 30, 40, 105, 50, 20, 5, 0, 'LC'),
#  (610, 640, 'Duosion', 'Psychic', None, 65, 40, 50, 125, 60, 30, 5, 0, 'NFE'),
#  (611,
#   641,
#   'Reuniclus',
#   'Psychic',
#   None,
#   110,
#   65,
#   75,
#   125,
#   85,
#   30,
#   5,
#   0,
#   'UU'),
#  (612, 642, 'Ducklett', 'Water', 'Flying', 62, 44, 50, 44, 50, 55, 5, 0, 'LC'),
#  (613, 643, 'Swanna', 'Water', 'Flying', 75, 87, 63, 87, 63, 98, 5, 0, 'PU'),
#  (614, 644, 'Vanillite', 'Ice', None, 36, 50, 50, 65, 60, 44, 5, 0, 'LC'),
#  (615, 645, 'Vanillish', 'Ice', None, 51, 65, 65, 80, 75, 59, 5, 0, 'NFE'),
#  (616,
#   646,
#   'Vanilluxe',
#   'Ice',
#   None,
#   71,
#   95,
#   85,
#   110,
#   95,
#   79,
#   5,
#   0,
#   'Untiered'),
#  (617, 647, 'Deerling', 'Normal', 'Grass', 60, 60, 50, 40, 50, 75, 5, 0, 'LC'),
#  (618,
#   648,
#   'Sawsbuck',
#   'Normal',
#   'Grass',
#   80,
#   100,
#   70,
#   60,
#   70,
#   95,
#   5,
#   0,
#   'Untiered'),
#  (619,
#   649,
#   'Emolga',
#   'Electric',
#   'Flying',
#   55,
#   75,
#   60,
#   75,
#   60,
#   103,
#   5,
#   0,
#   'Untiered'),
#  (620, 650, 'Karrablast', 'Bug', None, 50, 75, 45, 40, 45, 60, 5, 0, 'LC'),
#  (621,
#   651,
#   'Escavalier',
#   'Bug',
#   'Steel',
#   70,
#   135,
#   105,
#   60,
#   105,
#   20,
#   5,
#   0,
#   'RU'),
#  (622, 652, 'Foongus', 'Grass', 'Poison', 69, 55, 45, 55, 55, 15, 5, 0, 'LC'),
#  (623,
#   653,
#   'Amoonguss',
#   'Grass',
#   'Poison',
#   114,
#   85,
#   70,
#   85,
#   80,
#   30,
#   5,
#   0,
#   'OU'),
#  (624, 654, 'Frillish', 'Water', 'Ghost', 55, 40, 50, 65, 85, 40, 5, 0, 'LC'),
#  (625,
#   655,
#   'Jellicent',
#   'Water',
#   'Ghost',
#   100,
#   60,
#   70,
#   85,
#   105,
#   60,
#   5,
#   0,
#   'RU'),
#  (626, 656, 'Alomomola', 'Water', None, 165, 75, 80, 40, 45, 65, 5, 0, 'RU'),
#  (627, 657, 'Joltik', 'Bug', 'Electric', 50, 47, 50, 57, 50, 65, 5, 0, 'LC'),
#  (628,
#   658,
#   'Galvantula',
#   'Bug',
#   'Electric',
#   70,
#   77,
#   60,
#   97,
#   60,
#   108,
#   5,
#   0,
#   'UU'),
#  (629, 659, 'Ferroseed', 'Grass', 'Steel', 44, 50, 91, 24, 86, 10, 5, 0, 'NU'),
#  (630,
#   660,
#   'Ferrothorn',
#   'Grass',
#   'Steel',
#   74,
#   94,
#   131,
#   54,
#   116,
#   20,
#   5,
#   0,
#   'OU'),
#  (631, 661, 'Klink', 'Steel', None, 40, 55, 70, 45, 60, 30, 5, 0, 'LC'),
#  (632, 662, 'Klang', 'Steel', None, 60, 80, 95, 70, 85, 50, 5, 0, 'NFE'),
#  (633, 663, 'Klinklang', 'Steel', None, 60, 100, 115, 70, 85, 90, 5, 0, 'NU'),
#  (634, 664, 'Tynamo', 'Electric', None, 35, 55, 40, 45, 40, 60, 5, 0, 'LC'),
#  (635,
#   665,
#   'Eelektrik',
#   'Electric',
#   None,
#   65,
#   85,
#   70,
#   75,
#   70,
#   40,
#   5,
#   0,
#   'NFE'),
#  (636,
#   666,
#   'Eelektross',
#   'Electric',
#   None,
#   85,
#   115,
#   80,
#   105,
#   80,
#   50,
#   5,
#   0,
#   'RU'),
#  (637, 667, 'Elgyem', 'Psychic', None, 55, 55, 55, 85, 55, 30, 5, 0, 'LC'),
#  (638, 668, 'Beheeyem', 'Psychic', None, 75, 75, 75, 125, 95, 40, 5, 0, 'PU'),
#  (639, 669, 'Litwick', 'Ghost', 'Fire', 50, 30, 55, 65, 55, 20, 5, 0, 'LC'),
#  (640, 670, 'Lampent', 'Ghost', 'Fire', 60, 40, 60, 95, 60, 55, 5, 0, 'NFE'),
#  (641,
#   671,
#   'Chandelure',
#   'Ghost',
#   'Fire',
#   60,
#   55,
#   90,
#   145,
#   90,
#   80,
#   5,
#   0,
#   'UU'),
#  (642, 672, 'Axew', 'Dragon', None, 46, 87, 60, 30, 40, 57, 5, 0, 'LC'),
#  (643, 673, 'Fraxure', 'Dragon', None, 66, 117, 70, 40, 50, 67, 5, 0, 'NFE'),
#  (644, 674, 'Haxorus', 'Dragon', None, 76, 147, 90, 60, 70, 97, 5, 0, 'UU'),
#  (645, 675, 'Cubchoo', 'Ice', None, 55, 70, 40, 60, 40, 40, 5, 0, 'LC'),
#  (646, 676, 'Beartic', 'Ice', None, 95, 110, 80, 70, 80, 50, 5, 0, 'Untiered'),
#  (647, 677, 'Cryogonal', 'Ice', None, 70, 50, 30, 95, 135, 105, 5, 0, 'PU'),
#  (648, 678, 'Shelmet', 'Bug', None, 50, 40, 85, 40, 65, 25, 5, 0, 'LC'),
#  (649, 679, 'Accelgor', 'Bug', None, 80, 70, 40, 100, 60, 145, 5, 0, 'RU'),
#  (650,
#   680,
#   'Stunfisk',
#   'Ground',
#   'Electric',
#   109,
#   66,
#   84,
#   81,
#   99,
#   32,
#   5,
#   0,
#   'PU'),
#  (651, 681, 'Mienfoo', 'Fighting', None, 45, 85, 50, 55, 50, 65, 5, 0, 'LC'),
#  (652,
#   682,
#   'Mienshao',
#   'Fighting',
#   None,
#   65,
#   125,
#   60,
#   95,
#   60,
#   105,
#   5,
#   0,
#   'UU'),
#  (653, 683, 'Druddigon', 'Dragon', None, 77, 120, 90, 60, 90, 48, 5, 0, 'RU'),
#  (654, 684, 'Golett', 'Ground', 'Ghost', 59, 74, 50, 35, 50, 35, 5, 0, 'LC'),
#  (655, 685, 'Golurk', 'Ground', 'Ghost', 89, 124, 80, 55, 80, 55, 5, 0, 'NU'),
#  (656, 686, 'Pawniard', 'Dark', 'Steel', 45, 85, 70, 40, 40, 60, 5, 0, 'PU'),
#  (657, 687, 'Bisharp', 'Dark', 'Steel', 65, 125, 100, 60, 70, 70, 5, 0, 'OU'),
#  (658, 688, 'Bouffalant', 'Normal', None, 95, 110, 95, 40, 95, 55, 5, 0, 'PU'),
#  (659, 689, 'Rufflet', 'Normal', 'Flying', 70, 83, 50, 37, 50, 60, 5, 0, 'LC'),
#  (660,
#   690,
#   'Braviary',
#   'Normal',
#   'Flying',
#   100,
#   123,
#   75,
#   57,
#   75,
#   80,
#   5,
#   0,
#   'RU'),
#  (661, 691, 'Vullaby', 'Dark', 'Flying', 70, 55, 75, 45, 65, 60, 5, 0, 'PU'),
#  (662,
#   692,
#   'Mandibuzz',
#   'Dark',
#   'Flying',
#   110,
#   65,
#   105,
#   55,
#   95,
#   80,
#   5,
#   0,
#   'UU'),
#  (663,
#   693,
#   'Heatmor',
#   'Fire',
#   None,
#   85,
#   97,
#   66,
#   105,
#   66,
#   65,
#   5,
#   0,
#   'Untiered'),
#  (664, 694, 'Durant', 'Bug', 'Steel', 58, 109, 112, 48, 48, 109, 5, 0, 'RUBL'),
#  (665, 695, 'Deino', 'Dark', 'Dragon', 52, 65, 50, 45, 50, 38, 5, 0, 'LC'),
#  (666, 696, 'Zweilous', 'Dark', 'Dragon', 72, 85, 70, 65, 70, 58, 5, 0, 'NFE'),
#  (667,
#   697,
#   'Hydreigon',
#   'Dark',
#   'Dragon',
#   92,
#   105,
#   90,
#   125,
#   90,
#   98,
#   5,
#   0,
#   'UU'),
#  (668, 698, 'Larvesta', 'Bug', 'Fire', 55, 85, 55, 50, 55, 60, 5, 0, 'LC'),
#  (669,
#   699,
#   'Volcarona',
#   'Bug',
#   'Fire',
#   85,
#   60,
#   65,
#   135,
#   105,
#   100,
#   5,
#   0,
#   'UUBL'),
#  (670,
#   700,
#   'Cobalion',
#   'Steel',
#   'Fighting',
#   91,
#   90,
#   129,
#   90,
#   72,
#   108,
#   5,
#   1,
#   'UU'),
#  (671,
#   701,
#   'Terrakion',
#   'Rock',
#   'Fighting',
#   91,
#   129,
#   90,
#   72,
#   90,
#   108,
#   5,
#   1,
#   'UUBL'),
#  (672,
#   702,
#   'Virizion',
#   'Grass',
#   'Fighting',
#   91,
#   90,
#   72,
#   90,
#   129,
#   108,
#   5,
#   1,
#   'RU'),
#  (673,
#   707,
#   'Reshiram',
#   'Dragon',
#   'Fire',
#   100,
#   120,
#   100,
#   150,
#   120,
#   90,
#   5,
#   1,
#   'Uber'),
#  (674,
#   708,
#   'Zekrom',
#   'Dragon',
#   'Electric',
#   100,
#   150,
#   120,
#   120,
#   100,
#   90,
#   5,
#   1,
#   'Uber'),
#  (675,
#   711,
#   'Kyurem',
#   'Dragon',
#   'Ice',
#   125,
#   130,
#   90,
#   130,
#   90,
#   95,
#   5,
#   1,
#   'RUBL'),
#  (676,
#   718,
#   'Genesect',
#   'Bug',
#   'Steel',
#   71,
#   120,
#   95,
#   120,
#   95,
#   99,
#   5,
#   0,
#   'Uber'),
#  (677, 719, 'Chespin', 'Grass', None, 56, 61, 65, 48, 45, 38, 6, 0, 'LC'),
#  (678, 720, 'Quilladin', 'Grass', None, 61, 78, 95, 56, 58, 57, 6, 0, 'NFE'),
#  (679,
#   721,
#   'Chesnaught',
#   'Grass',
#   'Fighting',
#   88,
#   107,
#   122,
#   74,
#   75,
#   64,
#   6,
#   0,
#   'UU'),
#  (680, 722, 'Fennekin', 'Fire', None, 40, 45, 40, 62, 60, 60, 6, 0, 'LC'),
#  (681, 723, 'Braixen', 'Fire', None, 59, 59, 58, 90, 70, 73, 6, 0, 'NFE'),
#  (682,
#   724,
#   'Delphox',
#   'Fire',
#   'Psychic',
#   75,
#   69,
#   72,
#   114,
#   100,
#   104,
#   6,
#   0,
#   'RU'),
#  (683, 725, 'Froakie', 'Water', None, 41, 56, 40, 62, 44, 71, 6, 0, 'LC'),
#  (684, 726, 'Frogadier', 'Water', None, 54, 63, 52, 83, 56, 97, 6, 0, 'NFE'),
#  (685,
#   727,
#   'Greninja',
#   'Water',
#   'Dark',
#   72,
#   95,
#   67,
#   103,
#   71,
#   122,
#   6,
#   0,
#   'Uber'),
#  (686, 728, 'Bunnelby', 'Normal', None, 38, 36, 38, 32, 36, 57, 6, 0, 'LC'),
#  (687,
#   729,
#   'Diggersby',
#   'Normal',
#   'Ground',
#   85,
#   56,
#   77,
#   50,
#   77,
#   78,
#   6,
#   0,
#   'UUBL'),
#  (688,
#   730,
#   'Fletchling',
#   'Normal',
#   'Flying',
#   45,
#   50,
#   43,
#   40,
#   38,
#   62,
#   6,
#   0,
#   'LC'),
#  (689,
#   731,
#   'Fletchinder',
#   'Fire',
#   'Flying',
#   62,
#   73,
#   55,
#   56,
#   52,
#   84,
#   6,
#   0,
#   'RU'),
#  (690,
#   732,
#   'Talonflame',
#   'Fire',
#   'Flying',
#   78,
#   81,
#   71,
#   74,
#   69,
#   126,
#   6,
#   0,
#   'OU'),
#  (691, 733, 'Scatterbug', 'Bug', None, 38, 35, 40, 27, 25, 35, 6, 0, 'LC'),
#  (692, 734, 'Spewpa', 'Bug', None, 45, 22, 60, 27, 30, 29, 6, 0, 'NFE'),
#  (693, 735, 'Vivillon', 'Bug', 'Flying', 80, 52, 50, 90, 50, 89, 6, 0, 'NU'),
#  (694, 736, 'Litleo', 'Fire', 'Normal', 62, 50, 58, 73, 54, 72, 6, 0, 'LC'),
#  (695, 737, 'Pyroar', 'Fire', 'Normal', 86, 68, 72, 109, 66, 106, 6, 0, 'NU'),
#  (696, 739, 'Floette', 'Fairy', None, 54, 45, 47, 75, 98, 52, 6, 0, 'NFE'),
#  (697, 740, 'Florges', 'Fairy', None, 78, 65, 68, 112, 154, 75, 6, 0, 'UU'),
#  (698, 741, 'Skiddo', 'Grass', None, 66, 65, 48, 62, 57, 52, 6, 0, 'LC'),
#  (699,
#   742,
#   'Gogoat',
#   'Grass',
#   None,
#   123,
#   100,
#   62,
#   97,
#   81,
#   68,
#   6,
#   0,
#   'Untiered'),
#  (700, 743, 'Pancham', 'Fighting', None, 67, 82, 62, 46, 48, 43, 6, 0, 'LC'),
#  (701,
#   744,
#   'Pangoro',
#   'Fighting',
#   'Dark',
#   95,
#   124,
#   78,
#   69,
#   71,
#   58,
#   6,
#   0,
#   'RUBL'),
#  (702,
#   745,
#   'Furfrou',
#   'Normal',
#   None,
#   75,
#   80,
#   60,
#   65,
#   90,
#   102,
#   6,
#   0,
#   'Untiered'),
#  (703, 746, 'Espurr', 'Psychic', None, 62, 48, 54, 63, 60, 68, 6, 0, 'LC'),
#  (704, 749, 'Honedge', 'Steel', 'Ghost', 45, 80, 100, 35, 37, 28, 6, 0, 'LC'),
#  (705,
#   750,
#   'Doublade',
#   'Steel',
#   'Ghost',
#   59,
#   110,
#   150,
#   45,
#   49,
#   35,
#   6,
#   0,
#   'UU'),
#  (706, 753, 'Spritzee', 'Fairy', None, 78, 52, 60, 63, 65, 23, 6, 0, 'LC'),
#  (707, 754, 'Aromatisse', 'Fairy', None, 101, 72, 72, 99, 89, 29, 6, 0, 'RU'),
#  (708, 755, 'Swirlix', 'Fairy', None, 62, 48, 66, 59, 57, 49, 6, 0, 'NFE'),
#  (709, 756, 'Slurpuff', 'Fairy', None, 82, 80, 86, 85, 75, 72, 6, 0, 'UUBL'),
#  (710, 757, 'Inkay', 'Dark', 'Psychic', 53, 54, 53, 37, 46, 45, 6, 0, 'LC'),
#  (711, 758, 'Malamar', 'Dark', 'Psychic', 86, 92, 88, 68, 75, 73, 6, 0, 'NU'),
#  (712, 759, 'Binacle', 'Rock', 'Water', 42, 52, 67, 39, 56, 50, 6, 0, 'LC'),
#  (713,
#   760,
#   'Barbaracle',
#   'Rock',
#   'Water',
#   72,
#   105,
#   115,
#   54,
#   86,
#   68,
#   6,
#   0,
#   'NU'),
#  (714, 761, 'Skrelp', 'Poison', 'Water', 50, 60, 60, 60, 60, 30, 6, 0, 'LC'),
#  (715,
#   762,
#   'Dragalge',
#   'Poison',
#   'Dragon',
#   65,
#   75,
#   90,
#   97,
#   123,
#   44,
#   6,
#   0,
#   'RUBL'),
#  (716, 763, 'Clauncher', 'Water', None, 50, 53, 62, 58, 63, 44, 6, 0, 'LC'),
#  (717, 764, 'Clawitzer', 'Water', None, 71, 73, 88, 120, 89, 59, 6, 0, 'RU'),
#  (718,
#   765,
#   'Helioptile',
#   'Electric',
#   'Normal',
#   44,
#   38,
#   33,
#   61,
#   43,
#   70,
#   6,
#   0,
#   'LC'),
#  (719,
#   766,
#   'Heliolisk',
#   'Electric',
#   'Normal',
#   62,
#   55,
#   52,
#   109,
#   94,
#   109,
#   6,
#   0,
#   'UU'),
#  (720, 767, 'Tyrunt', 'Rock', 'Dragon', 58, 89, 77, 45, 45, 48, 6, 0, 'LC'),
#  (721,
#   768,
#   'Tyrantrum',
#   'Rock',
#   'Dragon',
#   82,
#   121,
#   119,
#   69,
#   59,
#   71,
#   6,
#   0,
#   'RUBL'),
#  (722, 769, 'Amaura', 'Rock', 'Ice', 77, 59, 50, 67, 63, 46, 6, 0, 'LC'),
#  (723, 770, 'Aurorus', 'Rock', 'Ice', 123, 77, 72, 99, 92, 58, 6, 0, 'NU'),
#  (724, 771, 'Sylveon', 'Fairy', None, 95, 65, 65, 110, 130, 60, 6, 0, 'UU'),
#  (725,
#   772,
#   'Hawlucha',
#   'Fighting',
#   'Flying',
#   78,
#   92,
#   75,
#   74,
#   63,
#   118,
#   6,
#   0,
#   'UUBL'),
#  (726,
#   773,
#   'Dedenne',
#   'Electric',
#   'Fairy',
#   67,
#   58,
#   57,
#   81,
#   67,
#   101,
#   6,
#   0,
#   'Untiered'),
#  (727,
#   774,
#   'Carbink',
#   'Rock',
#   'Fairy',
#   50,
#   50,
#   150,
#   50,
#   150,
#   50,
#   6,
#   0,
#   'Untiered'),
#  (728, 775, 'Goomy', 'Dragon', None, 45, 50, 35, 55, 75, 40, 6, 0, 'LC'),
#  (729, 776, 'Sliggoo', 'Dragon', None, 68, 75, 53, 83, 113, 60, 6, 0, 'NFE'),
#  (730, 777, 'Goodra', 'Dragon', None, 90, 100, 70, 110, 150, 80, 6, 0, 'UU'),
#  (731, 778, 'Klefki', 'Steel', 'Fairy', 57, 80, 91, 80, 87, 75, 6, 0, 'UU'),
#  (732, 779, 'Phantump', 'Ghost', 'Grass', 43, 70, 48, 50, 60, 38, 6, 0, 'LC'),
#  (733,
#   780,
#   'Trevenant',
#   'Ghost',
#   'Grass',
#   85,
#   110,
#   76,
#   65,
#   82,
#   56,
#   6,
#   0,
#   'PU'),
#  (734, 789, 'Bergmite', 'Ice', None, 55, 69, 85, 32, 35, 28, 6, 0, 'LC'),
#  (735, 790, 'Avalugg', 'Ice', None, 95, 117, 184, 44, 46, 28, 6, 0, 'PU'),
#  (736, 791, 'Noibat', 'Flying', 'Dragon', 40, 30, 35, 45, 40, 55, 6, 0, 'LC'),
#  (737,
#   792,
#   'Noivern',
#   'Flying',
#   'Dragon',
#   85,
#   70,
#   80,
#   97,
#   80,
#   123,
#   6,
#   0,
#   'RUBL'),
#  (738, 793, 'Xerneas', 'Fairy', None, 126, 131, 95, 131, 98, 99, 6, 1, 'Uber'),
#  (739,
#   794,
#   'Yveltal',
#   'Dark',
#   'Flying',
#   126,
#   131,
#   95,
#   131,
#   98,
#   99,
#   6,
#   1,
#   'Uber'),
#  (740,
#   796,
#   'Diancie',
#   'Rock',
#   'Fairy',
#   50,
#   100,
#   150,
#   100,
#   150,
#   50,
#   6,
#   1,
#   'RU'),
#  (741,
#   797,
#   'Mega Diancie',
#   'Rock',
#   'Fairy',
#   50,
#   160,
#   110,
#   160,
#   110,
#   110,
#   6,
#   1,
#   'OU'),
#  (742,
#   799,
#   'Hoopa Unbound',
#   'Psychic',
#   'Dark',
#   80,
#   160,
#   60,
#   170,
#   130,
#   80,
#   6,
#   1,
#   'Uber'),
#  (743,
#   800,
#   'Volcanion',
#   'Fire',
#   'Water',
#   80,
#   110,
#   120,
#   130,
#   90,
#   70,
#   6,
#   1,
#   'OU')]

# %%
conn.close()

# %%
#Data Exploration by Crystal Butler

# %%
pokemon_df.head()
# Out:
#    _ID  Number           Name Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# 0    0       1      Bulbasaur  Grass  Poison  45      49       49      65
# 1    1       2        Ivysaur  Grass  Poison  60      62       63      80
# 2    2       3       Venusaur  Grass  Poison  80      82       83     100
# 3    3       4  Mega Venusaur  Grass  Poison  80     100      123     122
# 4    4       5     Charmander   Fire     NaN  39      52       43      60
#
#    Sp_Def  Speed  Generation  Legendary Tier
# 0      65     45           1      False   LC
# 1      80     60           1      False  NFE
# 2     100     80           1      False   RU
# 3     120     80           1      False   OU
# 4      50     65           1      False   LC

# %%
battles_df = pd.read_csv("Resources/combats.csv")

# %%
battles_df = battles_df.sort_values('First_pokemon')

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner
# 15176              1             372     372
# 45814              1             462     462
# 17362              1               6       6
# 15251              1             649     649
# 4883               1             285       1

# %%
initial_value = 1
battles_df['Battle_number'] = range(initial_value, len(battles_df) +initial_value)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5

# %%
battles_df['Did_the_first_pokemon_win?'] = (battles_df['First_pokemon'] == battles_df['Winner']).astype(int)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           0
# 45814                           0
# 17362                           0
# 15251                           0
# 4883                            1

# %%
battles2_df = battles_df.copy()

# %%
battles2_df = battles2_df.iloc[:,[1,0,2,3]]

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5

# %%
battles2_df['Did_the_first_pokemon_win?'] = (battles2_df['Second_pokemon'] == battles2_df['Winner']).astype(int)

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number  \
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
battles2_df.rename(columns = {'Second_pokemon':'First_pokemon', 'First_pokemon':'Second_pokemon'}, inplace = True)

# %%
battles2_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176            372               1     372              1
# 45814            462               1     462              2
# 17362              6               1       6              3
# 15251            649               1     649              4
# 4883             285               1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
all_battles_df = pd.concat([battles_df, battles2_df], axis=0)

# %%
all_battles_df = all_battles_df.sort_values('Battle_number')

# %%
all_battles_df.dtypes
# Out:
# First_pokemon                 int64
# Second_pokemon                int64
# Winner                        int64
# Battle_number                 int64
# Did_the_first_pokemon_win?    int64
# dtype: object

# %%
merged_df = pd.merge(all_battles_df,pokemon_df, how='inner', left_on=['First_pokemon'], right_on = ['Number'])
merged_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner  Battle_number  \
# 0              1             372     372              1
# 1              1             462     462              2
# 2              1               6       6              3
# 3              1             649     649              4
# 4              1             285       1              5
#
#    Did_the_first_pokemon_win?  _ID  Number       Name Type_1  Type_2  HP  \
# 0                           0    0       1  Bulbasaur  Grass  Poison  45
# 1                           0    0       1  Bulbasaur  Grass  Poison  45
# 2                           0    0       1  Bulbasaur  Grass  Poison  45
# 3                           0    0       1  Bulbasaur  Grass  Poison  45
# 4                           1    0       1  Bulbasaur  Grass  Poison  45
#
#    Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary Tier
# 0      49       49      65      65     45           1      False   LC
# 1      49       49      65      65     45           1      False   LC
# 2      49       49      65      65     45           1      False   LC
# 3      49       49      65      65     45           1      False   LC
# 4      49       49      65      65     45           1      False   LC

# %%
merged_df = merged_df.iloc[:,[3,0,7,1,2,4]]

# %%
merged_df.rename(columns = {'Name':'First_name'},inplace = True)

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon First_name  Second_pokemon  Winner  \
# 0              1              1  Bulbasaur             372     372
# 1              2              1  Bulbasaur             462     462
# 2              3              1  Bulbasaur               6       6
# 3              4              1  Bulbasaur             649     649
# 4              5              1  Bulbasaur             285       1
#
#    Did_the_first_pokemon_win?
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           1

# %%
merged_df = pd.merge(merged_df,pokemon_df, how='inner', left_on=['Second_pokemon'], right_on = ['Number'])

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon  First_name  Second_pokemon  Winner  \
# 0              1              1   Bulbasaur             372     372
# 1          23232            638  Gothitelle             372     638
# 2          24480            391     Tropius             372     372
# 3          23218            558       Tepig             372     372
# 4          19353            311     Breloom             372     311
#
#    Did_the_first_pokemon_win?  _ID  Number      Name Type_1  Type_2  HP  \
# 0                           0  363     372  Barboach  Water  Ground  50
# 1                           1  363     372  Barboach  Water  Ground  50
# 2                           0  363     372  Barboach  Water  Ground  50
# 3                           0  363     372  Barboach  Water  Ground  50
# 4                           1  363     372  Barboach  Water  Ground  50
#
#    Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary Tier
# 0      48       43      46      41     60           3      False   LC
# 1      48       43      46      41     60           3      False   LC
# 2      48       43      46      41     60           3      False   LC
# 3      48       43      46      41     60           3      False   LC
# 4      48       43      46      41     60           3      False   LC

# %%
merged_df.rename(columns = {'Name':'Second_name'},inplace = True)

# %%
merged_df = merged_df.iloc[:,[0,1,2,3,8,4,5]]

# %%
merged_df = merged_df.sort_values('Battle_number')

# %%
merged_df.head()
# Out:
#        Battle_number  First_pokemon  First_name  Second_pokemon Second_name  \
# 0                  1              1   Bulbasaur             372    Barboach
# 14008              1            372    Barboach               1   Bulbasaur
# 14009              2            462      Mothim               1   Bulbasaur
# 140                2              1   Bulbasaur             462      Mothim
# 14010              3              6  Charmeleon               1   Bulbasaur
#
#        Winner  Did_the_first_pokemon_win?
# 0         372                           0
# 14008     372                           1
# 14009     462                           1
# 140       462                           0
# 14010       6                           1

# %%
winner_df_names = merged_df.iloc[:,[0,2,4,6]]

# %%
winner_df_names.head()
# Out:
#        Battle_number  First_name Second_name  Did_the_first_pokemon_win?
# 0                  1   Bulbasaur    Barboach                           0
# 14008              1    Barboach   Bulbasaur                           1
# 14009              2      Mothim   Bulbasaur                           1
# 140                2   Bulbasaur      Mothim                           0
# 14010              3  Charmeleon   Bulbasaur                           1

# %%
#merging pokemon_df and merged_df dataframe, so First Name can have it's attributes associated with the pokemon that have battled
merged_w_tiers = pd.merge(pokemon_df,merged_df, how='left', left_on=['Name'], right_on=['First_name'])

# %%
#viewing dataframe
merged_w_tiers.head()
# Out:
#    _ID  Number       Name Type_1  Type_2  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 1    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 2    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 3    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 4    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
#
#    ...  Generation  Legendary  Tier Battle_number  First_pokemon  First_name  \
# 0  ...           1      False    LC           1.0            1.0   Bulbasaur
# 1  ...           1      False    LC           2.0            1.0   Bulbasaur
# 2  ...           1      False    LC           3.0            1.0   Bulbasaur
# 3  ...           1      False    LC           4.0            1.0   Bulbasaur
# 4  ...           1      False    LC           5.0            1.0   Bulbasaur
#
#   Second_pokemon  Second_name Winner  Did_the_first_pokemon_win?
# 0          372.0     Barboach  372.0                         0.0
# 1          462.0       Mothim  462.0                         0.0
# 2            6.0   Charmeleon    6.0                         0.0
# 3          649.0       Emolga  649.0                         0.0
# 4          285.0    Poochyena    1.0                         1.0
#
# [5 rows x 21 columns]

# %%
#merging pokemon_df and merged_w_tiers dataframe, so Second Name can have it's attributes as well
merged_w_tiers2 = pd.merge(pokemon_df,merged_w_tiers, how='left', left_on=['Name'], right_on=['Second_name']).sort_values('Battle_number')

# %%
#viewing columns for renaming
merged_w_tiers2.columns
# Out:
# Index(['_ID_x', 'Number_x', 'Name_x', 'Type_1_x', 'Type_2_x', 'HP_x',
#        'Attack_x', 'Defense_x', 'Sp_Atk_x', 'Sp_Def_x', 'Speed_x',
#        'Generation_x', 'Legendary_x', 'Tier_x', '_ID_y', 'Number_y', 'Name_y',
#        'Type_1_y', 'Type_2_y', 'HP_y', 'Attack_y', 'Defense_y', 'Sp_Atk_y',
#        'Sp_Def_y', 'Speed_y', 'Generation_y', 'Legendary_y', 'Tier_y',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win?'],
#       dtype='object')

# %%
#Renaming columns to reflect which attributes go to which Pokemon (First or Second)
merged_w_tiers2 = merged_w_tiers2.rename(columns={'Number_x':'Number_Second', 'Name_x':'Second_Name', 'Type_1_x':'Type_1_Second', 'Type_2_x':'Type_2_Second', 'HP_x':'HP_Second', 'Attack_x':'Attack_Second',
       'Defense_x':'Defense_Second', 'Sp_Atk_x':'Sp_Atk_Second', 'Sp_Def_x':'Sp_Def_Second', 'Speed_x':'Speed_Second', 'Generation_x':'Generation_Second',
       'Legendary_x':'Legendary_Second', 'Tier_x':'Tier_Second', 'Number_y':'Number_First', 'Name_y':'First_Name', 'Type_1_y':'Type_1_First', 'Type_2_y':'Type_2_First',
       'HP_y':'HP_First', 'Attack_y':'Attack_First', 'Defense_y':'Defense_First', 'Sp_Atk_y':'Sp_Atk_First', 'Sp_Def_y':'Sp_Def_First', 'Speed_y':'Speed_First',
       'Generation_y':'Generation_First', 'Legendary_y':'Legendary_First', 'Tier_y':'Tier_First', 'Did_the_first_pokemon_win?':'Did_the_first_pokemon_win' })
merged_w_tiers2
# Out:
#        _ID_x  Number_Second  Second_Name Type_1_Second Type_2_Second  \
# 65         0              1    Bulbasaur         Grass        Poison
# 42104    363            372     Barboach         Water        Ground
# 79         0              1    Bulbasaur         Grass        Poison
# 51724    444            462       Mothim           Bug        Flying
# 0          0              1    Bulbasaur         Grass        Poison
# ...      ...            ...          ...           ...           ...
# 47791    410            419  Mega Latias        Dragon       Psychic
# 53730    461            479    Honchkrow          Dark        Flying
# 61445    528            556      Servine         Grass           NaN
# 68469    588            618     Maractus         Grass           NaN
# 72650    625            655    Jellicent         Water         Ghost
#
#        HP_Second  Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  \
# 65            45             49              49             65             65
# 42104         50             48              43             46             41
# 79            45             49              49             65             65
# 51724         70             94              50             94             50
# 0             45             49              49             65             65
# ...          ...            ...             ...            ...            ...
# 47791         80            100             120            140            150
# 53730        100            125              52            105             52
# 61445         60             60              75             60             75
# 68469         75             86              67            106             67
# 72650        100             60              70             85            105
#
#        ...  Generation_First  Legendary_First  Tier_First Battle_number  \
# 65     ...               3.0            False          LC           1.0
# 42104  ...               1.0            False          LC           1.0
# 79     ...               4.0            False    Untiered           2.0
# 51724  ...               1.0            False          LC           2.0
# 0      ...               1.0            False         NFE           3.0
# ...    ...               ...              ...         ...           ...
# 47791  ...               NaN              NaN         NaN           NaN
# 53730  ...               NaN              NaN         NaN           NaN
# 61445  ...               NaN              NaN         NaN           NaN
# 68469  ...               NaN              NaN         NaN           NaN
# 72650  ...               NaN              NaN         NaN           NaN
#
#        First_pokemon  First_name Second_pokemon Second_name Winner  \
# 65             372.0    Barboach            1.0   Bulbasaur  372.0
# 42104            1.0   Bulbasaur          372.0    Barboach  372.0
# 79             462.0      Mothim            1.0   Bulbasaur  462.0
# 51724            1.0   Bulbasaur          462.0      Mothim  462.0
# 0                6.0  Charmeleon            1.0   Bulbasaur    6.0
# ...              ...         ...            ...         ...    ...
# 47791            NaN         NaN            NaN         NaN    NaN
# 53730            NaN         NaN            NaN         NaN    NaN
# 61445            NaN         NaN            NaN         NaN    NaN
# 68469            NaN         NaN            NaN         NaN    NaN
# 72650            NaN         NaN            NaN         NaN    NaN
#
#        Did_the_first_pokemon_win
# 65                           1.0
# 42104                        0.0
# 79                           1.0
# 51724                        0.0
# 0                            1.0
# ...                          ...
# 47791                        NaN
# 53730                        NaN
# 61445                        NaN
# 68469                        NaN
# 72650                        NaN
#
# [86739 rows x 35 columns]

# %%
#Sorting by Battle Number
merged_w_tiers2 = merged_w_tiers2.sort_values('Battle_number')

# %%
#Filtering to just Pokemon without battles
orphan_pokemon = merged_w_tiers2[merged_w_tiers2['Battle_number'].isnull()]

# %%
#Dataframe of Pokemon that haven't battled

orphan_pokemon.head()
# Out:
#       _ID_x  Number_Second Second_Name Type_1_Second Type_2_Second  HP_Second  \
# 1057      9             12   Blastoise         Water           NaN         79
# 3442     30             33   Sandshrew        Ground           NaN         50
# 4635     41             46  Wigglytuff        Normal         Fairy        140
# 6830     60             66     Poliwag         Water           NaN         40
# 8109     72             78  Victreebel         Grass        Poison         80
#
#       Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  ...  \
# 1057             83             100             85            105  ...
# 3442             75              85             20             30  ...
# 4635             70              45             85             50  ...
# 6830             50              40             40             40  ...
# 8109            105              65            100             70  ...
#
#       Generation_First  Legendary_First  Tier_First Battle_number  \
# 1057               NaN              NaN         NaN           NaN
# 3442               NaN              NaN         NaN           NaN
# 4635               NaN              NaN         NaN           NaN
# 6830               NaN              NaN         NaN           NaN
# 8109               NaN              NaN         NaN           NaN
#
#       First_pokemon  First_name Second_pokemon Second_name Winner  \
# 1057            NaN         NaN            NaN         NaN    NaN
# 3442            NaN         NaN            NaN         NaN    NaN
# 4635            NaN         NaN            NaN         NaN    NaN
# 6830            NaN         NaN            NaN         NaN    NaN
# 8109            NaN         NaN            NaN         NaN    NaN
#
#       Did_the_first_pokemon_win
# 1057                        NaN
# 3442                        NaN
# 4635                        NaN
# 6830                        NaN
# 8109                        NaN
#
# [5 rows x 35 columns]

# %%
#filtering out Pokemon that haven't battled
merged_reduced =merged_w_tiers2.dropna(subset=['Battle_number']).sort_values('Battle_number')

# %%
#Dataframe with only Pokemon that were involved in a battle

merged_reduced.head()
# Out:
#        _ID_x  Number_Second Second_Name Type_1_Second Type_2_Second  \
# 65         0              1   Bulbasaur         Grass        Poison
# 42104    363            372    Barboach         Water        Ground
# 79         0              1   Bulbasaur         Grass        Poison
# 51724    444            462      Mothim           Bug        Flying
# 0          0              1   Bulbasaur         Grass        Poison
#
#        HP_Second  Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  \
# 65            45             49              49             65             65
# 42104         50             48              43             46             41
# 79            45             49              49             65             65
# 51724         70             94              50             94             50
# 0             45             49              49             65             65
#
#        ...  Generation_First  Legendary_First  Tier_First Battle_number  \
# 65     ...               3.0            False          LC           1.0
# 42104  ...               1.0            False          LC           1.0
# 79     ...               4.0            False    Untiered           2.0
# 51724  ...               1.0            False          LC           2.0
# 0      ...               1.0            False         NFE           3.0
#
#        First_pokemon  First_name Second_pokemon Second_name Winner  \
# 65             372.0    Barboach            1.0   Bulbasaur  372.0
# 42104            1.0   Bulbasaur          372.0    Barboach  372.0
# 79             462.0      Mothim            1.0   Bulbasaur  462.0
# 51724            1.0   Bulbasaur          462.0      Mothim  462.0
# 0                6.0  Charmeleon            1.0   Bulbasaur    6.0
#
#        Did_the_first_pokemon_win
# 65                           1.0
# 42104                        0.0
# 79                           1.0
# 51724                        0.0
# 0                            1.0
#
# [5 rows x 35 columns]

# %%
merged_reduced.columns
# Out:
# Index(['_ID_x', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '_ID_y', 'Number_First',
#        'First_Name', 'Type_1_First', 'Type_2_First', 'HP_First',
#        'Attack_First', 'Defense_First', 'Sp_Atk_First', 'Sp_Def_First',
#        'Speed_First', 'Generation_First', 'Legendary_First', 'Tier_First',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
merged_reduced[['Number_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second', 'Number_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win']] = merged_reduced[['Number_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second', 'Number_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win']].astype(int)

# %%
merged_reduced.columns
# Out:
# Index(['_ID_x', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '_ID_y', 'Number_First',
#        'First_Name', 'Type_1_First', 'Type_2_First', 'HP_First',
#        'Attack_First', 'Defense_First', 'Sp_Atk_First', 'Sp_Def_First',
#        'Speed_First', 'Generation_First', 'Legendary_First', 'Tier_First',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
final_df = merged_reduced[['Number_First', 'First_Name',
       'Type_1_First', 'Type_2_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Legendary_First', 'Tier_First','Number_Second', 'Second_Name', 'Type_1_Second', 'Type_2_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
       'Legendary_Second', 'Tier_Second',  'Battle_number',
       'Did_the_first_pokemon_win']]

# %%
final_df.head()
# Out:
#        Number_First  First_Name Type_1_First Type_2_First  HP_First  \
# 65              372    Barboach        Water       Ground        50
# 42104             1   Bulbasaur        Grass       Poison        45
# 79              462      Mothim          Bug       Flying        70
# 51724             1   Bulbasaur        Grass       Poison        45
# 0                 6  Charmeleon         Fire          NaN        58
#
#        Attack_First  Defense_First  Sp_Atk_First  Sp_Def_First  Speed_First  \
# 65               48             43            46            41           60
# 42104            49             49            65            65           45
# 79               94             50            94            50           66
# 51724            49             49            65            65           45
# 0                64             58            80            65           80
#
#        ...  Attack_Second Defense_Second Sp_Atk_Second  Sp_Def_Second  \
# 65     ...             49             49            65             65
# 42104  ...             48             43            46             41
# 79     ...             49             49            65             65
# 51724  ...             94             50            94             50
# 0      ...             49             49            65             65
#
#       Speed_Second Generation_Second Legendary_Second  Tier_Second  \
# 65              45                 1            False           LC
# 42104           60                 3            False           LC
# 79              45                 1            False           LC
# 51724           66                 4            False     Untiered
# 0               45                 1            False           LC
#
#        Battle_number  Did_the_first_pokemon_win
# 65                 1                          1
# 42104              1                          0
# 79                 2                          1
# 51724              2                          0
# 0                  3                          1
#
# [5 rows x 28 columns]

# %%
final_df.dtypes
# Out:
# Number_First                  int64
# First_Name                   object
# Type_1_First                 object
# Type_2_First                 object
# HP_First                      int64
# Attack_First                  int64
# Defense_First                 int64
# Sp_Atk_First                  int64
# Sp_Def_First                  int64
# Speed_First                   int64
# Generation_First              int64
# Legendary_First              object
# Tier_First                   object
# Number_Second                 int64
# Second_Name                  object
# Type_1_Second                object
# Type_2_Second                object
# HP_Second                     int64
# Attack_Second                 int64
# Defense_Second                int64
# Sp_Atk_Second                 int64
# Sp_Def_Second                 int64
# Speed_Second                  int64
# Generation_Second             int64
# Legendary_Second               bool
# Tier_Second                  object
# Battle_number                 int64
# Did_the_first_pokemon_win     int64
# dtype: object

# %%
final_df.index.name = "_ID"

# %%
final_df.columns
# Out:
# Index(['Number_First', 'First_Name', 'Type_1_First', 'Type_2_First',
#        'HP_First', 'Attack_First', 'Defense_First', 'Sp_Atk_First',
#        'Sp_Def_First', 'Speed_First', 'Generation_First', 'Legendary_First',
#        'Tier_First', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', 'Battle_number',
#        'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
final_df.to_csv("Resources/final_df.csv")

# %%
# sqlite setup by Lea Jinks

# %%
database_path = "Resources/pokemon.sqlite"
Path(database_path).touch()

# %%
conn = sqlite3.connect(database_path)
c = conn.cursor()

# %%
c.execute('''DROP TABLE IF EXISTS pokemon;''')

# %%
c.execute('''CREATE TABLE pokemon(
    _ID INT NOT NULL PRIMARY KEY,
    Number_First INT NOT NULL,
  	First_Name VARCHAR(40) NOT NULL,
    Type_1_First VARCHAR(40),
	Type_2_First VARCHAR(40),
	HP_First INT NOT NULL,
	Attack_First INT NOT NULL,
	Defense_First INT NOT NULL,
	Sp_Atk_First INT NOT NULL,
	Sp_Def_First INT NOT NULL,
	Speed_First INT NOT NULL,
	Generation_First INT NOT NULL,
	Legendary_First VARCHAR(40),
	Tier_First VARCHAR(40) NOT NULL,
	Number_Second INT NOT NULL,
	Second_Name VARCHAR(40) NOT NULL,
	Type_1_Second VARCHAR(40),
	Type_2_Second VARCHAR(40),
	HP_Second INT NOT NULL,
	Attack_Second INT NOT NULL,
	Defense_Second INT NOT NULL,
	Sp_Atk_Second INT NOT NULL,
	Sp_Def_Second INT NOT NULL,
	Speed_Second INT NOT NULL,
	Generation_Second INT NOT NULL,
	Legendary_Second VARCHAR(40),
	Tier_Second VARCHAR(40) NOT NULL,
	Battle_number INT NOT NULL,
    Did_the_first_pokemon_win INT NOT NULL
   	);''')

# %%
poke_df = pd.read_csv("Resources/final_df.csv")

# %%
poke_df.head()
# Out:
#      _ID  Number_First  First_Name Type_1_First Type_2_First  HP_First  \
# 0     65           372    Barboach        Water       Ground        50
# 1  42104             1   Bulbasaur        Grass       Poison        45
# 2     79           462      Mothim          Bug       Flying        70
# 3  51724             1   Bulbasaur        Grass       Poison        45
# 4      0             6  Charmeleon         Fire          NaN        58
#
#    Attack_First  Defense_First  Sp_Atk_First  Sp_Def_First  ...  \
# 0            48             43            46            41  ...
# 1            49             49            65            65  ...
# 2            94             50            94            50  ...
# 3            49             49            65            65  ...
# 4            64             58            80            65  ...
#
#    Attack_Second  Defense_Second  Sp_Atk_Second Sp_Def_Second  Speed_Second  \
# 0             49              49             65            65            45
# 1             48              43             46            41            60
# 2             49              49             65            65            45
# 3             94              50             94            50            66
# 4             49              49             65            65            45
#
#   Generation_Second Legendary_Second Tier_Second  Battle_number  \
# 0                 1            False          LC              1
# 1                 3            False          LC              1
# 2                 1            False          LC              2
# 3                 4            False    Untiered              2
# 4                 1            False          LC              3
#
#    Did_the_first_pokemon_win
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          1
#
# [5 rows x 29 columns]

# %%
poke_df.to_sql("pokemon", conn, if_exists='append', index = False)

# %%
c.execute('''SELECT * from pokemon''').fetchall()
# Out:
# [(65,
#   372,
#   'Barboach',
#   'Water',
#   'Ground',
#   50,
#   48,
#   43,
#   46,
#   41,
#   60,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   1,
#   1),
#  (42104,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   372,
#   'Barboach',
#   'Water',
#   'Ground',
#   50,
#   48,
#   43,
#   46,
#   41,
#   60,
#   3,
#   '0',
#   'LC',
#   1,
#   0),
#  (79,
#   462,
#   'Mothim',
#   'Bug',
#   'Flying',
#   70,
#   94,
#   50,
#   94,
#   50,
#   66,
#   4,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   2,
#   1),
#  (51724,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   462,
#   'Mothim',
#   'Bug',
#   'Flying',
#   70,
#   94,
#   50,
#   94,
#   50,
#   66,
#   4,
#   '0',
#   'Untiered',
#   2,
#   0),
#  (0,
#   6,
#   'Charmeleon',
#   'Fire',
#   None,
#   58,
#   64,
#   58,
#   80,
#   65,
#   80,
#   1,
#   '0',
#   'NFE',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   3,
#   1),
#  (579,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   6,
#   'Charmeleon',
#   'Fire',
#   None,
#   58,
#   64,
#   58,
#   80,
#   65,
#   80,
#   1,
#   '0',
#   'NFE',
#   3,
#   0),
#  (71971,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   649,
#   'Emolga',
#   'Electric',
#   'Flying',
#   55,
#   75,
#   60,
#   75,
#   60,
#   103,
#   5,
#   '0',
#   'Untiered',
#   4,
#   0),
#  (108,
#   649,
#   'Emolga',
#   'Electric',
#   'Flying',
#   55,
#   75,
#   60,
#   75,
#   60,
#   103,
#   5,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   4,
#   1),
#  (46,
#   285,
#   'Poochyena',
#   'Dark',
#   None,
#   35,
#   55,
#   35,
#   30,
#   30,
#   35,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   5,
#   0),
#  (31871,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   285,
#   'Poochyena',
#   'Dark',
#   None,
#   35,
#   55,
#   35,
#   30,
#   30,
#   35,
#   3,
#   '0',
#   'LC',
#   5,
#   1),
#  (63210,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   572,
#   'Simisage',
#   'Grass',
#   None,
#   75,
#   98,
#   63,
#   98,
#   63,
#   101,
#   5,
#   '0',
#   'Untiered',
#   6,
#   0),
#  (96,
#   572,
#   'Simisage',
#   'Grass',
#   None,
#   75,
#   98,
#   63,
#   98,
#   63,
#   101,
#   5,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   6,
#   1),
#  (63,
#   364,
#   'Cacturne',
#   'Grass',
#   'Dark',
#   70,
#   115,
#   60,
#   115,
#   60,
#   55,
#   3,
#   '0',
#   'PU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   7,
#   1),
#  (41149,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   364,
#   'Cacturne',
#   'Grass',
#   'Dark',
#   70,
#   115,
#   60,
#   115,
#   60,
#   55,
#   3,
#   '0',
#   'PU',
#   7,
#   0),
#  (40,
#   249,
#   'Mega Houndoom',
#   'Dark',
#   'Fire',
#   75,
#   90,
#   90,
#   140,
#   90,
#   115,
#   2,
#   '0',
#   'RUBL',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   8,
#   1),
#  (27644,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   249,
#   'Mega Houndoom',
#   'Dark',
#   'Fire',
#   75,
#   90,
#   90,
#   140,
#   90,
#   115,
#   2,
#   '0',
#   'RUBL',
#   8,
#   0),
#  (113,
#   679,
#   'Accelgor',
#   'Bug',
#   None,
#   80,
#   70,
#   40,
#   100,
#   60,
#   145,
#   5,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   9,
#   1),
#  (75407,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   679,
#   'Accelgor',
#   'Bug',
#   None,
#   80,
#   70,
#   40,
#   100,
#   60,
#   145,
#   5,
#   '0',
#   'RU',
#   9,
#   0),
#  (17607,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   161,
#   'Dragonair',
#   'Dragon',
#   None,
#   61,
#   84,
#   65,
#   70,
#   70,
#   70,
#   1,
#   '0',
#   'NFE',
#   10,
#   0),
#  (23,
#   161,
#   'Dragonair',
#   'Dragon',
#   None,
#   61,
#   84,
#   65,
#   70,
#   70,
#   70,
#   1,
#   '0',
#   'NFE',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   10,
#   1),
#  (36401,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   324,
#   'Nosepass',
#   'Rock',
#   None,
#   30,
#   45,
#   135,
#   45,
#   90,
#   30,
#   3,
#   '0',
#   'LC',
#   11,
#   1),
#  (55,
#   324,
#   'Nosepass',
#   'Rock',
#   None,
#   30,
#   45,
#   135,
#   45,
#   90,
#   30,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   11,
#   0),
#  (106,
#   638,
#   'Gothitelle',
#   'Psychic',
#   None,
#   70,
#   55,
#   95,
#   95,
#   110,
#   65,
#   5,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   12,
#   1),
#  (70722,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   638,
#   'Gothitelle',
#   'Psychic',
#   None,
#   70,
#   55,
#   95,
#   95,
#   110,
#   65,
#   5,
#   '0',
#   'Untiered',
#   12,
#   0),
#  (54067,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   483,
#   'Stunky',
#   'Poison',
#   'Dark',
#   63,
#   63,
#   47,
#   41,
#   41,
#   74,
#   4,
#   '0',
#   'LC',
#   13,
#   0),
#  (82,
#   483,
#   'Stunky',
#   'Poison',
#   'Dark',
#   63,
#   63,
#   47,
#   41,
#   41,
#   74,
#   4,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   13,
#   1),
#  (76371,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   14,
#   0),
#  (116,
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   14,
#   1),
#  (92,
#   557,
#   'Serperior',
#   'Grass',
#   None,
#   75,
#   75,
#   95,
#   75,
#   95,
#   113,
#   5,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   15,
#   1),
#  (61446,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   557,
#   'Serperior',
#   'Grass',
#   None,
#   75,
#   75,
#   95,
#   75,
#   95,
#   113,
#   5,
#   '0',
#   'OU',
#   15,
#   0),
#  (73368,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   662,
#   'Klang',
#   'Steel',
#   None,
#   60,
#   80,
#   95,
#   70,
#   85,
#   50,
#   5,
#   '0',
#   'NFE',
#   16,
#   0),
#  (110,
#   662,
#   'Klang',
#   'Steel',
#   None,
#   60,
#   80,
#   95,
#   70,
#   85,
#   50,
#   5,
#   '0',
#   'NFE',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   16,
#   1),
#  (11901,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   112,
#   'Exeggutor',
#   'Grass',
#   'Psychic',
#   95,
#   95,
#   85,
#   125,
#   65,
#   55,
#   1,
#   '0',
#   'PUBL',
#   17,
#   0),
#  (15,
#   112,
#   'Exeggutor',
#   'Grass',
#   'Psychic',
#   95,
#   95,
#   85,
#   125,
#   65,
#   55,
#   1,
#   '0',
#   'PUBL',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   17,
#   1),
#  (76372,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   18,
#   0),
#  (117,
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   18,
#   1),
#  (51,
#   307,
#   'Mega Gardevoir',
#   'Psychic',
#   'Fairy',
#   68,
#   85,
#   65,
#   165,
#   135,
#   100,
#   3,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   19,
#   1),
#  (34482,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   307,
#   'Mega Gardevoir',
#   'Psychic',
#   'Fairy',
#   68,
#   85,
#   65,
#   165,
#   135,
#   100,
#   3,
#   '0',
#   'OU',
#   19,
#   0),
#  (70,
#   391,
#   'Tropius',
#   'Grass',
#   'Flying',
#   99,
#   68,
#   83,
#   72,
#   87,
#   51,
#   3,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   20,
#   1),
#  (44411,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   391,
#   'Tropius',
#   'Grass',
#   'Flying',
#   99,
#   68,
#   83,
#   72,
#   87,
#   51,
#   3,
#   '0',
#   'Untiered',
#   20,
#   0),
#  (14117,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   131,
#   'Starmie',
#   'Water',
#   'Psychic',
#   60,
#   75,
#   85,
#   100,
#   85,
#   115,
#   1,
#   '0',
#   'OU',
#   21,
#   0),
#  (20,
#   131,
#   'Starmie',
#   'Water',
#   'Psychic',
#   60,
#   75,
#   85,
#   100,
#   85,
#   115,
#   1,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   21,
#   1),
#  (57526,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   513,
#   'Weavile',
#   'Dark',
#   'Ice',
#   70,
#   120,
#   65,
#   45,
#   85,
#   125,
#   4,
#   '0',
#   'OU',
#   22,
#   0),
#  (88,
#   513,
#   'Weavile',
#   'Dark',
#   'Ice',
#   70,
#   120,
#   65,
#   45,
#   85,
#   125,
#   4,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   22,
#   1),
#  (20144,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   185,
#   'Chinchou',
#   'Water',
#   'Electric',
#   75,
#   38,
#   38,
#   56,
#   56,
#   67,
#   2,
#   '0',
#   'LC',
#   24,
#   0),
#  (26,
#   185,
#   'Chinchou',
#   'Water',
#   'Electric',
#   75,
#   38,
#   38,
#   56,
#   56,
#   67,
#   2,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   24,
#   1),
#  (9,
#   75,
#   'Machamp',
#   'Fighting',
#   None,
#   90,
#   130,
#   80,
#   65,
#   85,
#   55,
#   1,
#   '0',
#   'UU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   25,
#   1),
#  (7779,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   75,
#   'Machamp',
#   'Fighting',
#   None,
#   90,
#   130,
#   80,
#   65,
#   85,
#   55,
#   1,
#   '0',
#   'UU',
#   25,
#   0),
#  (21139,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   194,
#   'Mareep',
#   'Electric',
#   None,
#   55,
#   40,
#   40,
#   65,
#   45,
#   35,
#   2,
#   '0',
#   'LC',
#   26,
#   1),
#  (29,
#   194,
#   'Mareep',
#   'Electric',
#   None,
#   55,
#   40,
#   40,
#   65,
#   45,
#   35,
#   2,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   26,
#   0),
#  (25,
#   178,
#   'Hoothoot',
#   'Normal',
#   'Flying',
#   60,
#   30,
#   30,
#   36,
#   56,
#   50,
#   2,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   28,
#   1),
#  (19436,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   178,
#   'Hoothoot',
#   'Normal',
#   'Flying',
#   60,
#   30,
#   30,
#   36,
#   56,
#   50,
#   2,
#   '0',
#   'LC',
#   28,
#   0),
#  (47,
#   302,
#   'Wingull',
#   'Water',
#   'Flying',
#   40,
#   30,
#   30,
#   55,
#   30,
#   85,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   29,
#   0),
#  (33866,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   302,
#   'Wingull',
#   'Water',
#   'Flying',
#   40,
#   30,
#   30,
#   55,
#   30,
#   85,
#   3,
#   '0',
#   'LC',
#   29,
#   1),
#  (41,
#   252,
#   'Donphan',
#   'Ground',
#   None,
#   90,
#   120,
#   120,
#   60,
#   60,
#   50,
#   2,
#   '0',
#   'UU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   30,
#   1),
#  (28026,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   252,
#   'Donphan',
#   'Ground',
#   None,
#   90,
#   120,
#   120,
#   60,
#   60,
#   50,
#   2,
#   '0',
#   'UU',
#   30,
#   0),
#  (2586,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   26,
#   'Raticate',
#   'Normal',
#   None,
#   55,
#   81,
#   60,
#   50,
#   70,
#   97,
#   1,
#   '0',
#   'Untiered',
#   31,
#   0),
#  (3,
#   26,
#   'Raticate',
#   'Normal',
#   None,
#   55,
#   81,
#   60,
#   50,
#   70,
#   97,
#   1,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   31,
#   1),
#  (86,
#   506,
#   'Carnivine',
#   'Grass',
#   None,
#   74,
#   100,
#   72,
#   90,
#   72,
#   46,
#   4,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   32,
#   1),
#  (56726,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   506,
#   'Carnivine',
#   'Grass',
#   None,
#   74,
#   100,
#   72,
#   90,
#   72,
#   46,
#   4,
#   '0',
#   'Untiered',
#   32,
#   0),
#  (56,
#   337,
#   'Mega Medicham',
#   'Fighting',
#   'Psychic',
#   60,
#   100,
#   85,
#   80,
#   85,
#   100,
#   3,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   33,
#   1),
#  (38008,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   337,
#   'Mega Medicham',
#   'Fighting',
#   'Psychic',
#   60,
#   100,
#   85,
#   80,
#   85,
#   100,
#   3,
#   '0',
#   'OU',
#   33,
#   0),
#  (93,
#   558,
#   'Tepig',
#   'Fire',
#   None,
#   65,
#   63,
#   45,
#   45,
#   45,
#   45,
#   5,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   34,
#   1),
#  (61566,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   558,
#   'Tepig',
#   'Fire',
#   None,
#   65,
#   63,
#   45,
#   45,
#   45,
#   45,
#   5,
#   '0',
#   'LC',
#   34,
#   0),
#  (7,
#   54,
#   'Venonat',
#   'Bug',
#   'Poison',
#   60,
#   55,
#   50,
#   40,
#   55,
#   45,
#   1,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   35,
#   1),
#  (5540,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   54,
#   'Venonat',
#   'Bug',
#   'Poison',
#   60,
#   55,
#   50,
#   40,
#   55,
#   45,
#   1,
#   '0',
#   'LC',
#   35,
#   0),
#  (24135,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   219,
#   'Girafarig',
#   'Normal',
#   'Psychic',
#   70,
#   80,
#   65,
#   90,
#   65,
#   85,
#   2,
#   '0',
#   'Untiered',
#   36,
#   0),
#  (36,
#   219,
#   'Girafarig',
#   'Normal',
#   'Psychic',
#   70,
#   80,
#   65,
#   90,
#   65,
#   85,
#   2,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   36,
#   1),
#  (27,
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   37,
#   0),
#  (20684,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   37,
#   1),
#  (125,
#   779,
#   'Phantump',
#   'Ghost',
#   'Grass',
#   43,
#   70,
#   48,
#   50,
#   60,
#   38,
#   6,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   38,
#   0),
#  (85291,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   779,
#   'Phantump',
#   'Ghost',
#   'Grass',
#   43,
#   70,
#   48,
#   50,
#   60,
#   38,
#   6,
#   '0',
#   'LC',
#   38,
#   1),
#  (34973,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   311,
#   'Breloom',
#   'Grass',
#   'Fighting',
#   60,
#   130,
#   80,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'OU',
#   39,
#   0),
#  (52,
#   311,
#   'Breloom',
#   'Grass',
#   'Fighting',
#   60,
#   130,
#   80,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   39,
#   1),
#  (70013,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   632,
#   'Zorua',
#   'Dark',
#   None,
#   40,
#   65,
#   40,
#   80,
#   40,
#   65,
#   5,
#   '0',
#   'LC',
#   40,
#   0),
#  (104,
#   632,
#   'Zorua',
#   'Dark',
#   None,
#   40,
#   65,
#   40,
#   80,
#   40,
#   65,
#   5,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   40,
#   1),
#  (4,
#   37,
#   'Nidoqueen',
#   'Poison',
#   'Ground',
#   90,
#   92,
#   87,
#   75,
#   85,
#   76,
#   1,
#   '0',
#   'UU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   41,
#   1),
#  (3683,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   37,
#   'Nidoqueen',
#   'Poison',
#   'Ground',
#   90,
#   92,
#   87,
#   75,
#   85,
#   76,
#   1,
#   '0',
#   'UU',
#   41,
#   0),
#  (54644,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   488,
#   'Mime Jr.',
#   'Psychic',
#   'Fairy',
#   20,
#   25,
#   45,
#   70,
#   90,
#   60,
#   4,
#   '0',
#   'LC',
#   42,
#   0),
#  (83,
#   488,
#   'Mime Jr.',
#   'Psychic',
#   'Fairy',
#   20,
#   25,
#   45,
#   70,
#   90,
#   60,
#   4,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   42,
#   1),
#  (83784,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   766,
#   'Heliolisk',
#   'Electric',
#   'Normal',
#   62,
#   55,
#   52,
#   109,
#   94,
#   109,
#   6,
#   '0',
#   'UU',
#   43,
#   0),
#  (124,
#   766,
#   'Heliolisk',
#   'Electric',
#   'Normal',
#   62,
#   55,
#   52,
#   109,
#   94,
#   109,
#   6,
#   '0',
#   'UU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   43,
#   1),
#  (60,
#   351,
#   'Wailmer',
#   'Water',
#   None,
#   130,
#   70,
#   35,
#   70,
#   35,
#   60,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   44,
#   1),
#  (39665,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   351,
#   'Wailmer',
#   'Water',
#   None,
#   130,
#   70,
#   35,
#   70,
#   35,
#   60,
#   3,
#   '0',
#   'LC',
#   44,
#   0),
#  (22,
#   153,
#   'Kabutops',
#   'Rock',
#   'Water',
#   60,
#   115,
#   105,
#   65,
#   70,
#   80,
#   1,
#   '0',
#   'NU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   45,
#   1),
#  (16656,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   153,
#   'Kabutops',
#   'Rock',
#   'Water',
#   60,
#   115,
#   105,
#   65,
#   70,
#   80,
#   1,
#   '0',
#   'NU',
#   45,
#   0),
#  (100,
#   604,
#   'Venipede',
#   'Bug',
#   'Poison',
#   30,
#   45,
#   59,
#   30,
#   39,
#   57,
#   5,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   46,
#   1),
#  (67095,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   604,
#   'Venipede',
#   'Bug',
#   'Poison',
#   30,
#   45,
#   59,
#   30,
#   39,
#   57,
#   5,
#   '0',
#   'LC',
#   46,
#   0),
#  (25114,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   227,
#   'Granbull',
#   'Fairy',
#   None,
#   90,
#   120,
#   75,
#   60,
#   60,
#   45,
#   2,
#   '0',
#   'RU',
#   47,
#   0),
#  (37,
#   227,
#   'Granbull',
#   'Fairy',
#   None,
#   90,
#   120,
#   75,
#   60,
#   60,
#   45,
#   2,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   47,
#   1),
#  (26553,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   240,
#   'Piloswine',
#   'Ice',
#   'Ground',
#   100,
#   100,
#   80,
#   60,
#   60,
#   50,
#   2,
#   '0',
#   'NU',
#   48,
#   0),
#  (39,
#   240,
#   'Piloswine',
#   'Ice',
#   'Ground',
#   100,
#   100,
#   80,
#   60,
#   60,
#   50,
#   2,
#   '0',
#   'NU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   48,
#   1),
#  (85,
#   503,
#   'Drapion',
#   'Poison',
#   'Dark',
#   70,
#   90,
#   110,
#   60,
#   75,
#   95,
#   4,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   49,
#   1),
#  (56380,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   503,
#   'Drapion',
#   'Poison',
#   'Dark',
#   70,
#   90,
#   110,
#   60,
#   75,
#   95,
#   4,
#   '0',
#   'RU',
#   49,
#   0),
#  (7780,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   75,
#   'Machamp',
#   'Fighting',
#   None,
#   90,
#   130,
#   80,
#   65,
#   85,
#   55,
#   1,
#   '0',
#   'UU',
#   51,
#   0),
#  (10,
#   75,
#   'Machamp',
#   'Fighting',
#   None,
#   90,
#   130,
#   80,
#   65,
#   85,
#   55,
#   1,
#   '0',
#   'UU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   51,
#   1),
#  (67,
#   381,
#   'Armaldo',
#   'Rock',
#   'Bug',
#   75,
#   125,
#   100,
#   70,
#   80,
#   45,
#   3,
#   '0',
#   'PU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   52,
#   1),
#  (43247,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   381,
#   'Armaldo',
#   'Rock',
#   'Bug',
#   75,
#   125,
#   100,
#   70,
#   80,
#   45,
#   3,
#   '0',
#   'PU',
#   52,
#   0),
#  (24,
#   162,
#   'Dragonite',
#   'Dragon',
#   'Flying',
#   91,
#   134,
#   95,
#   100,
#   100,
#   80,
#   1,
#   '0',
#   'OU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   53,
#   1),
#  (17712,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   162,
#   'Dragonite',
#   'Dragon',
#   'Flying',
#   91,
#   134,
#   95,
#   100,
#   100,
#   80,
#   1,
#   '0',
#   'OU',
#   53,
#   0),
#  (12,
#   84,
#   'Ponyta',
#   'Fire',
#   None,
#   50,
#   85,
#   55,
#   65,
#   65,
#   90,
#   1,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   54,
#   1),
#  (8736,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   84,
#   'Ponyta',
#   'Fire',
#   None,
#   50,
#   85,
#   55,
#   65,
#   65,
#   90,
#   1,
#   '0',
#   'LC',
#   54,
#   0),
#  (98,
#   579,
#   'Pidove',
#   'Normal',
#   'Flying',
#   50,
#   55,
#   50,
#   36,
#   30,
#   43,
#   5,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   55,
#   0),
#  (64048,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   579,
#   'Pidove',
#   'Normal',
#   'Flying',
#   50,
#   55,
#   50,
#   36,
#   30,
#   43,
#   5,
#   '0',
#   'LC',
#   55,
#   1),
#  (59,
#   346,
#   'Gulpin',
#   'Poison',
#   None,
#   70,
#   43,
#   53,
#   43,
#   53,
#   40,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   57,
#   0),
#  (39099,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   346,
#   'Gulpin',
#   'Poison',
#   None,
#   70,
#   43,
#   53,
#   43,
#   53,
#   40,
#   3,
#   '0',
#   'LC',
#   57,
#   1),
#  (57,
#   338,
#   'Electrike',
#   'Electric',
#   None,
#   40,
#   45,
#   40,
#   65,
#   40,
#   65,
#   3,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   58,
#   1),
#  (38127,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   338,
#   'Electrike',
#   'Electric',
#   None,
#   40,
#   45,
#   40,
#   65,
#   40,
#   65,
#   3,
#   '0',
#   'LC',
#   58,
#   0),
#  (28,
#   191,
#   'Togetic',
#   'Fairy',
#   'Flying',
#   55,
#   40,
#   85,
#   80,
#   105,
#   40,
#   2,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   59,
#   0),
#  (20797,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   191,
#   'Togetic',
#   'Fairy',
#   'Flying',
#   55,
#   40,
#   85,
#   80,
#   105,
#   40,
#   2,
#   '0',
#   'RU',
#   59,
#   1),
#  (47290,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   415,
#   'Regirock',
#   'Rock',
#   None,
#   80,
#   100,
#   200,
#   50,
#   100,
#   50,
#   3,
#   '1',
#   'NU',
#   60,
#   0),
#  (72,
#   415,
#   'Regirock',
#   'Rock',
#   None,
#   80,
#   100,
#   200,
#   50,
#   100,
#   50,
#   3,
#   '1',
#   'NU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   60,
#   1),
#  (23647,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   215,
#   'Slowking',
#   'Water',
#   'Psychic',
#   95,
#   75,
#   80,
#   100,
#   110,
#   30,
#   2,
#   '0',
#   'RU',
#   61,
#   1),
#  (32,
#   215,
#   'Slowking',
#   'Water',
#   'Psychic',
#   95,
#   75,
#   80,
#   100,
#   110,
#   30,
#   2,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   61,
#   0),
#  (58643,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   523,
#   'Glaceon',
#   'Ice',
#   None,
#   65,
#   60,
#   110,
#   130,
#   95,
#   65,
#   4,
#   '0',
#   'Untiered',
#   62,
#   0),
#  (90,
#   523,
#   'Glaceon',
#   'Ice',
#   None,
#   65,
#   60,
#   110,
#   130,
#   95,
#   65,
#   4,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   62,
#   1),
#  (107,
#   643,
#   'Swanna',
#   'Water',
#   'Flying',
#   75,
#   87,
#   63,
#   87,
#   63,
#   98,
#   5,
#   '0',
#   'PU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   63,
#   1),
#  (71314,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   643,
#   'Swanna',
#   'Water',
#   'Flying',
#   75,
#   87,
#   63,
#   87,
#   63,
#   98,
#   5,
#   '0',
#   'PU',
#   63,
#   0),
#  (69,
#   385,
#   'Kecleon',
#   'Normal',
#   None,
#   60,
#   90,
#   70,
#   60,
#   120,
#   40,
#   3,
#   '0',
#   'NU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   64,
#   0),
#  (43698,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   385,
#   'Kecleon',
#   'Normal',
#   None,
#   60,
#   90,
#   70,
#   60,
#   120,
#   40,
#   3,
#   '0',
#   'NU',
#   64,
#   1),
#  (23896,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   217,
#   'Unown',
#   'Psychic',
#   None,
#   48,
#   72,
#   48,
#   72,
#   48,
#   48,
#   2,
#   '0',
#   'Untiered',
#   65,
#   0),
#  (35,
#   217,
#   'Unown',
#   'Psychic',
#   None,
#   48,
#   72,
#   48,
#   72,
#   48,
#   48,
#   2,
#   '0',
#   'Untiered',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   65,
#   1),
#  (5,
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   66,
#   1),
#  (4276,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   66,
#   0),
#  (84,
#   493,
#   'Gabite',
#   'Dragon',
#   'Ground',
#   68,
#   90,
#   65,
#   50,
#   55,
#   82,
#   4,
#   '0',
#   'PU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   67,
#   1),
#  (55227,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   493,
#   'Gabite',
#   'Dragon',
#   'Ground',
#   68,
#   90,
#   65,
#   50,
#   55,
#   82,
#   4,
#   '0',
#   'PU',
#   67,
#   0),
#  (16,
#   115,
#   'Hitmonlee',
#   'Fighting',
#   None,
#   50,
#   120,
#   53,
#   35,
#   110,
#   87,
#   1,
#   '0',
#   'RU',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   69,
#   1),
#  (12240,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   115,
#   'Hitmonlee',
#   'Fighting',
#   None,
#   50,
#   120,
#   53,
#   35,
#   110,
#   87,
#   1,
#   '0',
#   'RU',
#   69,
#   0),
#  (76032,
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   684,
#   'Golett',
#   'Ground',
#   'Ghost',
#   59,
#   74,
#   50,
#   35,
#   50,
#   35,
#   5,
#   '0',
#   'LC',
#   70,
#   1),
#  (115,
#   684,
#   'Golett',
#   'Ground',
#   'Ghost',
#   59,
#   74,
#   50,
#   35,
#   50,
#   35,
#   5,
#   '0',
#   'LC',
#   1,
#   'Bulbasaur',
#   'Grass',
#   'Poison',
#   45,
#   49,
#   49,
#   65,
#   65,
#   45,
#   1,
#   '0',
#   'LC',
#   70,
#   0),
#  (159,
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   71,
#   1),
#  (23499,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   71,
#   0),
#  (132,
#   34,
#   'Sandslash',
#   'Ground',
#   None,
#   75,
#   100,
#   110,
#   45,
#   55,
#   65,
#   1,
#   '0',
#   'NU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   72,
#   1),
#  (3443,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   34,
#   'Sandslash',
#   'Ground',
#   None,
#   75,
#   100,
#   110,
#   45,
#   55,
#   65,
#   1,
#   '0',
#   'NU',
#   72,
#   0),
#  (134,
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   73,
#   1),
#  (4277,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   73,
#   0),
#  (150,
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   74,
#   0),
#  (20685,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   74,
#   1),
#  (182,
#   396,
#   'Snorunt',
#   'Ice',
#   None,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   3,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   76,
#   0),
#  (45028,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   396,
#   'Snorunt',
#   'Ice',
#   None,
#   50,
#   50,
#   50,
#   50,
#   50,
#   50,
#   3,
#   '0',
#   'LC',
#   76,
#   1),
#  (20798,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   191,
#   'Togetic',
#   'Fairy',
#   'Flying',
#   55,
#   40,
#   85,
#   80,
#   105,
#   40,
#   2,
#   '0',
#   'RU',
#   77,
#   1),
#  (152,
#   191,
#   'Togetic',
#   'Fairy',
#   'Flying',
#   55,
#   40,
#   85,
#   80,
#   105,
#   40,
#   2,
#   '0',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   77,
#   0),
#  (56833,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   507,
#   'Finneon',
#   'Water',
#   None,
#   49,
#   49,
#   56,
#   49,
#   61,
#   66,
#   4,
#   '0',
#   'LC',
#   78,
#   0),
#  (197,
#   507,
#   'Finneon',
#   'Water',
#   None,
#   49,
#   49,
#   56,
#   49,
#   61,
#   66,
#   4,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   78,
#   1),
#  (208,
#   594,
#   'Gurdurr',
#   'Fighting',
#   None,
#   85,
#   105,
#   85,
#   40,
#   50,
#   40,
#   5,
#   '0',
#   'NU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   80,
#   0),
#  (65880,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   594,
#   'Gurdurr',
#   'Fighting',
#   None,
#   85,
#   105,
#   85,
#   40,
#   50,
#   40,
#   5,
#   '0',
#   'NU',
#   80,
#   1),
#  (221,
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   81,
#   1),
#  (76373,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   687,
#   'Bisharp',
#   'Dark',
#   'Steel',
#   65,
#   125,
#   100,
#   60,
#   70,
#   70,
#   5,
#   '0',
#   'OU',
#   81,
#   0),
#  (80466,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   733,
#   'Scatterbug',
#   'Bug',
#   None,
#   38,
#   35,
#   40,
#   27,
#   25,
#   35,
#   6,
#   '0',
#   'LC',
#   82,
#   1),
#  (227,
#   733,
#   'Scatterbug',
#   'Bug',
#   None,
#   38,
#   35,
#   40,
#   27,
#   25,
#   35,
#   6,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   82,
#   0),
#  (223,
#   702,
#   'Virizion',
#   'Grass',
#   'Fighting',
#   91,
#   90,
#   72,
#   90,
#   129,
#   108,
#   5,
#   '1',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   83,
#   1),
#  (78200,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   702,
#   'Virizion',
#   'Grass',
#   'Fighting',
#   91,
#   90,
#   72,
#   90,
#   129,
#   108,
#   5,
#   '1',
#   'RU',
#   83,
#   0),
#  (23243,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   212,
#   'Espeon',
#   'Psychic',
#   None,
#   65,
#   65,
#   60,
#   130,
#   95,
#   110,
#   2,
#   '0',
#   'UU',
#   84,
#   0),
#  (157,
#   212,
#   'Espeon',
#   'Psychic',
#   None,
#   65,
#   65,
#   60,
#   130,
#   95,
#   110,
#   2,
#   '0',
#   'UU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   84,
#   1),
#  (68470,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   619,
#   'Dwebble',
#   'Bug',
#   'Rock',
#   50,
#   65,
#   85,
#   35,
#   35,
#   55,
#   5,
#   '0',
#   'LC',
#   85,
#   1),
#  (215,
#   619,
#   'Dwebble',
#   'Bug',
#   'Rock',
#   50,
#   65,
#   85,
#   35,
#   35,
#   55,
#   5,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   85,
#   0),
#  (13184,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   123,
#   'Tangela',
#   'Grass',
#   None,
#   65,
#   55,
#   115,
#   100,
#   40,
#   60,
#   1,
#   '0',
#   'PU',
#   86,
#   0),
#  (143,
#   123,
#   'Tangela',
#   'Grass',
#   None,
#   65,
#   55,
#   115,
#   100,
#   40,
#   60,
#   1,
#   '0',
#   'PU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   86,
#   1),
#  (20686,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   87,
#   1),
#  (151,
#   190,
#   'Togepi',
#   'Fairy',
#   None,
#   35,
#   20,
#   65,
#   40,
#   65,
#   20,
#   2,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   87,
#   0),
#  (5400,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   53,
#   'Parasect',
#   'Bug',
#   'Grass',
#   60,
#   95,
#   80,
#   60,
#   80,
#   30,
#   1,
#   '0',
#   'Untiered',
#   88,
#   1),
#  (135,
#   53,
#   'Parasect',
#   'Bug',
#   'Grass',
#   60,
#   95,
#   80,
#   60,
#   80,
#   30,
#   1,
#   '0',
#   'Untiered',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   88,
#   0),
#  (160,
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   89,
#   1),
#  (23500,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   89,
#   0),
#  (55101,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   492,
#   'Gible',
#   'Dragon',
#   'Ground',
#   58,
#   70,
#   45,
#   40,
#   45,
#   42,
#   4,
#   '0',
#   'LC',
#   90,
#   1),
#  (194,
#   492,
#   'Gible',
#   'Dragon',
#   'Ground',
#   58,
#   70,
#   45,
#   40,
#   45,
#   42,
#   4,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   90,
#   0),
#  (67645,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   609,
#   'Petilil',
#   'Grass',
#   None,
#   45,
#   35,
#   50,
#   70,
#   50,
#   30,
#   5,
#   '0',
#   'LC',
#   91,
#   1),
#  (212,
#   609,
#   'Petilil',
#   'Grass',
#   None,
#   45,
#   35,
#   50,
#   70,
#   50,
#   30,
#   5,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   91,
#   0),
#  (145,
#   142,
#   'Mega Gyarados',
#   'Water',
#   'Dark',
#   95,
#   155,
#   109,
#   70,
#   130,
#   81,
#   1,
#   '0',
#   'UUBL',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   92,
#   1),
#  (15447,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   142,
#   'Mega Gyarados',
#   'Water',
#   'Dark',
#   95,
#   155,
#   109,
#   70,
#   130,
#   81,
#   1,
#   '0',
#   'UUBL',
#   92,
#   0),
#  (128,
#   5,
#   'Charmander',
#   'Fire',
#   None,
#   39,
#   52,
#   43,
#   60,
#   50,
#   65,
#   1,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   93,
#   1),
#  (475,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   5,
#   'Charmander',
#   'Fire',
#   None,
#   39,
#   52,
#   43,
#   60,
#   50,
#   65,
#   1,
#   '0',
#   'LC',
#   93,
#   0),
#  (231,
#   756,
#   'Slurpuff',
#   'Fairy',
#   None,
#   82,
#   80,
#   86,
#   85,
#   75,
#   72,
#   6,
#   '0',
#   'UUBL',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   94,
#   1),
#  (82553,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   756,
#   'Slurpuff',
#   'Fairy',
#   None,
#   82,
#   80,
#   86,
#   85,
#   75,
#   72,
#   6,
#   '0',
#   'UUBL',
#   94,
#   0),
#  (196,
#   505,
#   'Toxicroak',
#   'Poison',
#   'Fighting',
#   83,
#   106,
#   65,
#   86,
#   65,
#   85,
#   4,
#   '0',
#   'UU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   95,
#   1),
#  (56601,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   505,
#   'Toxicroak',
#   'Poison',
#   'Fighting',
#   83,
#   106,
#   65,
#   86,
#   65,
#   85,
#   4,
#   '0',
#   'UU',
#   95,
#   0),
#  (16657,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   153,
#   'Kabutops',
#   'Rock',
#   'Water',
#   60,
#   115,
#   105,
#   65,
#   70,
#   80,
#   1,
#   '0',
#   'NU',
#   96,
#   0),
#  (147,
#   153,
#   'Kabutops',
#   'Rock',
#   'Water',
#   60,
#   115,
#   105,
#   65,
#   70,
#   80,
#   1,
#   '0',
#   'NU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   96,
#   1),
#  (216,
#   623,
#   'Sigilyph',
#   'Psychic',
#   'Flying',
#   72,
#   58,
#   80,
#   103,
#   80,
#   97,
#   5,
#   '0',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   98,
#   1),
#  (68921,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   623,
#   'Sigilyph',
#   'Psychic',
#   'Flying',
#   72,
#   58,
#   80,
#   103,
#   80,
#   97,
#   5,
#   '0',
#   'RU',
#   98,
#   0),
#  (237,
#   796,
#   'Diancie',
#   'Rock',
#   'Fairy',
#   50,
#   100,
#   150,
#   100,
#   150,
#   50,
#   6,
#   '1',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   99,
#   0),
#  (86269,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   796,
#   'Diancie',
#   'Rock',
#   'Fairy',
#   50,
#   100,
#   150,
#   100,
#   150,
#   50,
#   6,
#   '1',
#   'RU',
#   99,
#   1),
#  (222,
#   693,
#   'Heatmor',
#   'Fire',
#   None,
#   85,
#   97,
#   66,
#   105,
#   66,
#   65,
#   5,
#   '0',
#   'Untiered',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   100,
#   1),
#  (77111,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   693,
#   'Heatmor',
#   'Fire',
#   None,
#   85,
#   97,
#   66,
#   105,
#   66,
#   65,
#   5,
#   '0',
#   'Untiered',
#   100,
#   0),
#  (10638,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   101,
#   'Haunter',
#   'Ghost',
#   'Poison',
#   45,
#   50,
#   45,
#   115,
#   55,
#   95,
#   1,
#   '0',
#   'NU',
#   101,
#   0),
#  (139,
#   101,
#   'Haunter',
#   'Ghost',
#   'Poison',
#   45,
#   50,
#   45,
#   115,
#   55,
#   95,
#   1,
#   '0',
#   'NU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   101,
#   1),
#  (204,
#   573,
#   'Pansear',
#   'Fire',
#   None,
#   50,
#   53,
#   48,
#   53,
#   48,
#   64,
#   5,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   102,
#   1),
#  (63332,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   573,
#   'Pansear',
#   'Fire',
#   None,
#   50,
#   53,
#   48,
#   53,
#   48,
#   64,
#   5,
#   '0',
#   'LC',
#   102,
#   0),
#  (18813,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   173,
#   'Totodile',
#   'Water',
#   None,
#   50,
#   65,
#   64,
#   44,
#   48,
#   43,
#   2,
#   '0',
#   'LC',
#   103,
#   1),
#  (148,
#   173,
#   'Totodile',
#   'Water',
#   None,
#   50,
#   65,
#   64,
#   44,
#   48,
#   43,
#   2,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   103,
#   0),
#  (80467,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   733,
#   'Scatterbug',
#   'Bug',
#   None,
#   38,
#   35,
#   40,
#   27,
#   25,
#   35,
#   6,
#   '0',
#   'LC',
#   104,
#   1),
#  (228,
#   733,
#   'Scatterbug',
#   'Bug',
#   None,
#   38,
#   35,
#   40,
#   27,
#   25,
#   35,
#   6,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   104,
#   0),
#  (50692,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   450,
#   'Luxio',
#   'Electric',
#   None,
#   60,
#   85,
#   49,
#   60,
#   49,
#   60,
#   4,
#   '0',
#   'NFE',
#   105,
#   0),
#  (190,
#   450,
#   'Luxio',
#   'Electric',
#   None,
#   60,
#   85,
#   49,
#   60,
#   49,
#   60,
#   4,
#   '0',
#   'NFE',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   105,
#   1),
#  (201,
#   560,
#   'Emboar',
#   'Fire',
#   'Fighting',
#   110,
#   123,
#   65,
#   100,
#   65,
#   65,
#   5,
#   '0',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   106,
#   1),
#  (61821,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   560,
#   'Emboar',
#   'Fire',
#   'Fighting',
#   110,
#   123,
#   65,
#   100,
#   65,
#   65,
#   5,
#   '0',
#   'RU',
#   106,
#   0),
#  (146,
#   143,
#   'Lapras',
#   'Water',
#   'Ice',
#   130,
#   85,
#   80,
#   85,
#   95,
#   60,
#   1,
#   '0',
#   'PU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   107,
#   1),
#  (15571,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   143,
#   'Lapras',
#   'Water',
#   'Ice',
#   130,
#   85,
#   80,
#   85,
#   95,
#   60,
#   1,
#   '0',
#   'PU',
#   107,
#   0),
#  (189,
#   442,
#   'Starly',
#   'Normal',
#   'Flying',
#   40,
#   55,
#   30,
#   30,
#   30,
#   60,
#   4,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   108,
#   1),
#  (49715,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   442,
#   'Starly',
#   'Normal',
#   'Flying',
#   40,
#   55,
#   30,
#   30,
#   30,
#   60,
#   4,
#   '0',
#   'LC',
#   108,
#   0),
#  (51496,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   457,
#   'Bastiodon',
#   'Rock',
#   'Steel',
#   60,
#   52,
#   168,
#   47,
#   138,
#   30,
#   4,
#   '0',
#   'Untiered',
#   109,
#   0),
#  (192,
#   457,
#   'Bastiodon',
#   'Rock',
#   'Steel',
#   60,
#   52,
#   168,
#   47,
#   138,
#   30,
#   4,
#   '0',
#   'Untiered',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   109,
#   1),
#  (10165,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   97,
#   'Muk',
#   'Poison',
#   None,
#   105,
#   105,
#   75,
#   65,
#   100,
#   50,
#   1,
#   '0',
#   'PU',
#   110,
#   1),
#  (138,
#   97,
#   'Muk',
#   'Poison',
#   None,
#   105,
#   105,
#   75,
#   65,
#   100,
#   50,
#   1,
#   '0',
#   'PU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   110,
#   0),
#  (234,
#   774,
#   'Carbink',
#   'Rock',
#   'Fairy',
#   50,
#   50,
#   150,
#   50,
#   150,
#   50,
#   6,
#   '0',
#   'Untiered',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   111,
#   0),
#  (84712,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   774,
#   'Carbink',
#   'Rock',
#   'Fairy',
#   50,
#   50,
#   150,
#   50,
#   150,
#   50,
#   6,
#   '0',
#   'Untiered',
#   111,
#   1),
#  (166,
#   289,
#   'Wurmple',
#   'Bug',
#   None,
#   45,
#   45,
#   35,
#   20,
#   30,
#   20,
#   3,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   113,
#   0),
#  (32321,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   289,
#   'Wurmple',
#   'Bug',
#   None,
#   45,
#   45,
#   35,
#   20,
#   30,
#   20,
#   3,
#   '0',
#   'LC',
#   113,
#   1),
#  (183,
#   398,
#   'Mega Glalie',
#   'Ice',
#   None,
#   80,
#   120,
#   80,
#   120,
#   80,
#   100,
#   3,
#   '0',
#   'RU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   114,
#   1),
#  (45264,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   398,
#   'Mega Glalie',
#   'Ice',
#   None,
#   80,
#   120,
#   80,
#   120,
#   80,
#   100,
#   3,
#   '0',
#   'RU',
#   114,
#   0),
#  (66241,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   597,
#   'Palpitoad',
#   'Water',
#   'Ground',
#   75,
#   65,
#   55,
#   65,
#   55,
#   69,
#   5,
#   '0',
#   'NFE',
#   115,
#   0),
#  (209,
#   597,
#   'Palpitoad',
#   'Water',
#   'Ground',
#   75,
#   65,
#   55,
#   65,
#   55,
#   69,
#   5,
#   '0',
#   'NFE',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   115,
#   1),
#  (67646,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   609,
#   'Petilil',
#   'Grass',
#   None,
#   45,
#   35,
#   50,
#   70,
#   50,
#   30,
#   5,
#   '0',
#   'LC',
#   116,
#   1),
#  (213,
#   609,
#   'Petilil',
#   'Grass',
#   None,
#   45,
#   35,
#   50,
#   70,
#   50,
#   30,
#   5,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   116,
#   0),
#  (44771,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   394,
#   'Mega Absol',
#   'Dark',
#   None,
#   65,
#   150,
#   60,
#   115,
#   60,
#   115,
#   3,
#   '0',
#   'UU',
#   117,
#   0),
#  (180,
#   394,
#   'Mega Absol',
#   'Dark',
#   None,
#   65,
#   150,
#   60,
#   115,
#   60,
#   115,
#   3,
#   '0',
#   'UU',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   117,
#   1),
#  (39316,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   348,
#   'Carvanha',
#   'Water',
#   'Dark',
#   45,
#   90,
#   20,
#   65,
#   20,
#   65,
#   3,
#   '0',
#   'LC',
#   119,
#   0),
#  (176,
#   348,
#   'Carvanha',
#   'Water',
#   'Dark',
#   45,
#   90,
#   20,
#   65,
#   20,
#   65,
#   3,
#   '0',
#   'LC',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   119,
#   1),
#  (163,
#   279,
#   'Blaziken',
#   'Fire',
#   'Fighting',
#   80,
#   120,
#   70,
#   110,
#   70,
#   80,
#   3,
#   '0',
#   'Uber',
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   121,
#   1),
#  (31126,
#   2,
#   'Ivysaur',
#   'Grass',
#   'Poison',
#   60,
#   62,
#   63,
#   80,
#   80,
#   60,
#   1,
#   '0',
#   'NFE',
#   279,
#   'Blaziken',
#   'Fire',
#   'Fighting',
#   80,
#   120,
#   70,
#   110,
#   70,
#   80,
#   3,
#   '0',
#   'Uber',
#   121,
#   0),
#  (137,
#   96,
#   'Grimer',
#   'Poison',
#   None,
#   80,
#   80,
#   50,
#   40,
#   50,
#   25,
#   1,
#   '0',
#   'LC',
#   2,
# ...
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   574,
#   'Simisear',
#   'Fire',
#   None,
#   75,
#   98,
#   63,
#   98,
#   63,
#   101,
#   5,
#   '0',
#   'Untiered',
#   634,
#   0),
#  (1017,
#   574,
#   'Simisear',
#   'Fire',
#   None,
#   75,
#   98,
#   63,
#   98,
#   63,
#   101,
#   5,
#   '0',
#   'Untiered',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   634,
#   1),
#  (5036,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   50,
#   'Gloom',
#   'Grass',
#   'Poison',
#   60,
#   65,
#   70,
#   85,
#   75,
#   40,
#   1,
#   '0',
#   'NFE',
#   636,
#   1),
#  (929,
#   50,
#   'Gloom',
#   'Grass',
#   'Poison',
#   60,
#   65,
#   70,
#   85,
#   75,
#   40,
#   1,
#   '0',
#   'NFE',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   636,
#   0),
#  (963,
#   263,
#   'Raikou',
#   'Electric',
#   None,
#   90,
#   85,
#   75,
#   115,
#   100,
#   115,
#   2,
#   '1',
#   'OU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   637,
#   1),
#  (29376,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   263,
#   'Raikou',
#   'Electric',
#   None,
#   90,
#   85,
#   75,
#   115,
#   100,
#   115,
#   2,
#   '1',
#   'OU',
#   637,
#   0),
#  (53250,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   475,
#   'Buneary',
#   'Normal',
#   None,
#   55,
#   66,
#   44,
#   44,
#   56,
#   85,
#   4,
#   '0',
#   'LC',
#   638,
#   0),
#  (1001,
#   475,
#   'Buneary',
#   'Normal',
#   None,
#   55,
#   66,
#   44,
#   44,
#   56,
#   85,
#   4,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   638,
#   1),
#  (1030,
#   651,
#   'Escavalier',
#   'Bug',
#   'Steel',
#   70,
#   135,
#   105,
#   60,
#   105,
#   20,
#   5,
#   '0',
#   'RU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   639,
#   1),
#  (72191,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   651,
#   'Escavalier',
#   'Bug',
#   'Steel',
#   70,
#   135,
#   105,
#   60,
#   105,
#   20,
#   5,
#   '0',
#   'RU',
#   639,
#   0),
#  (34976,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   311,
#   'Breloom',
#   'Grass',
#   'Fighting',
#   60,
#   130,
#   80,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'OU',
#   641,
#   0),
#  (976,
#   311,
#   'Breloom',
#   'Grass',
#   'Fighting',
#   60,
#   130,
#   80,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'OU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   641,
#   1),
#  (932,
#   70,
#   'Kadabra',
#   'Psychic',
#   None,
#   40,
#   35,
#   30,
#   120,
#   70,
#   105,
#   1,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   642,
#   1),
#  (7172,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   70,
#   'Kadabra',
#   'Psychic',
#   None,
#   40,
#   35,
#   30,
#   120,
#   70,
#   105,
#   1,
#   '0',
#   'PU',
#   642,
#   0),
#  (10735,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   102,
#   'Gengar',
#   'Ghost',
#   'Poison',
#   60,
#   65,
#   60,
#   130,
#   75,
#   110,
#   1,
#   '0',
#   'OU',
#   643,
#   0),
#  (939,
#   102,
#   'Gengar',
#   'Ghost',
#   'Poison',
#   60,
#   65,
#   60,
#   130,
#   75,
#   110,
#   1,
#   '0',
#   'OU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   643,
#   1),
#  (978,
#   312,
#   'Slakoth',
#   'Normal',
#   None,
#   60,
#   60,
#   60,
#   35,
#   35,
#   30,
#   3,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   645,
#   0),
#  (35091,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   312,
#   'Slakoth',
#   'Normal',
#   None,
#   60,
#   60,
#   60,
#   35,
#   35,
#   30,
#   3,
#   '0',
#   'LC',
#   645,
#   1),
#  (969,
#   286,
#   'Mightyena',
#   'Dark',
#   None,
#   70,
#   90,
#   70,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'Untiered',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   646,
#   1),
#  (31980,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   286,
#   'Mightyena',
#   'Dark',
#   None,
#   70,
#   90,
#   70,
#   60,
#   60,
#   70,
#   3,
#   '0',
#   'Untiered',
#   646,
#   0),
#  (956,
#   243,
#   'Octillery',
#   'Water',
#   None,
#   75,
#   105,
#   75,
#   105,
#   75,
#   45,
#   2,
#   '0',
#   'Untiered',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   647,
#   0),
#  (26926,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   243,
#   'Octillery',
#   'Water',
#   None,
#   75,
#   105,
#   75,
#   105,
#   75,
#   45,
#   2,
#   '0',
#   'Untiered',
#   647,
#   1),
#  (966,
#   274,
#   'Grovyle',
#   'Grass',
#   None,
#   50,
#   65,
#   45,
#   85,
#   65,
#   95,
#   3,
#   '0',
#   'NFE',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   648,
#   1),
#  (30528,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   274,
#   'Grovyle',
#   'Grass',
#   None,
#   50,
#   65,
#   45,
#   85,
#   65,
#   95,
#   3,
#   '0',
#   'NFE',
#   648,
#   0),
#  (1052,
#   790,
#   'Avalugg',
#   'Ice',
#   None,
#   95,
#   117,
#   184,
#   44,
#   46,
#   28,
#   6,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   650,
#   0),
#  (85684,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   790,
#   'Avalugg',
#   'Ice',
#   None,
#   95,
#   117,
#   184,
#   44,
#   46,
#   28,
#   6,
#   '0',
#   'PU',
#   650,
#   1),
#  (997,
#   456,
#   'Shieldon',
#   'Rock',
#   'Steel',
#   30,
#   42,
#   118,
#   42,
#   88,
#   30,
#   4,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   651,
#   0),
#  (51378,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   456,
#   'Shieldon',
#   'Rock',
#   'Steel',
#   30,
#   42,
#   118,
#   42,
#   88,
#   30,
#   4,
#   '0',
#   'LC',
#   651,
#   1),
#  (936,
#   80,
#   'Tentacruel',
#   'Water',
#   'Poison',
#   80,
#   70,
#   65,
#   80,
#   120,
#   100,
#   1,
#   '0',
#   'UU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   652,
#   1),
#  (8260,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   80,
#   'Tentacruel',
#   'Water',
#   'Poison',
#   80,
#   70,
#   65,
#   80,
#   120,
#   100,
#   1,
#   '0',
#   'UU',
#   652,
#   0),
#  (944,
#   109,
#   'Voltorb',
#   'Electric',
#   None,
#   40,
#   30,
#   50,
#   55,
#   55,
#   100,
#   1,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   653,
#   1),
#  (11557,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   109,
#   'Voltorb',
#   'Electric',
#   None,
#   40,
#   30,
#   50,
#   55,
#   55,
#   100,
#   1,
#   '0',
#   'LC',
#   653,
#   0),
#  (39431,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   349,
#   'Sharpedo',
#   'Water',
#   'Dark',
#   70,
#   120,
#   40,
#   95,
#   40,
#   95,
#   3,
#   '0',
#   'RUBL',
#   654,
#   0),
#  (983,
#   349,
#   'Sharpedo',
#   'Water',
#   'Dark',
#   70,
#   120,
#   40,
#   95,
#   40,
#   95,
#   3,
#   '0',
#   'RUBL',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   654,
#   1),
#  (27518,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   248,
#   'Houndoom',
#   'Dark',
#   'Fire',
#   75,
#   90,
#   50,
#   110,
#   80,
#   95,
#   2,
#   '0',
#   'RU',
#   655,
#   0),
#  (957,
#   248,
#   'Houndoom',
#   'Dark',
#   'Fire',
#   75,
#   90,
#   50,
#   110,
#   80,
#   95,
#   2,
#   '0',
#   'RU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   655,
#   1),
#  (1023,
#   601,
#   'Sewaddle',
#   'Bug',
#   'Grass',
#   45,
#   53,
#   70,
#   40,
#   60,
#   42,
#   5,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   656,
#   0),
#  (66741,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   601,
#   'Sewaddle',
#   'Bug',
#   'Grass',
#   45,
#   53,
#   70,
#   40,
#   60,
#   42,
#   5,
#   '0',
#   'LC',
#   656,
#   1),
#  (1037,
#   685,
#   'Golurk',
#   'Ground',
#   'Ghost',
#   89,
#   124,
#   80,
#   55,
#   80,
#   55,
#   5,
#   '0',
#   'NU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   657,
#   1),
#  (76153,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   685,
#   'Golurk',
#   'Ground',
#   'Ghost',
#   89,
#   124,
#   80,
#   55,
#   80,
#   55,
#   5,
#   '0',
#   'NU',
#   657,
#   0),
#  (1000,
#   474,
#   'Drifblim',
#   'Ghost',
#   'Flying',
#   150,
#   80,
#   44,
#   90,
#   54,
#   80,
#   4,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   658,
#   1),
#  (53138,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   474,
#   'Drifblim',
#   'Ghost',
#   'Flying',
#   150,
#   80,
#   44,
#   90,
#   54,
#   80,
#   4,
#   '0',
#   'PU',
#   658,
#   0),
#  (66742,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   601,
#   'Sewaddle',
#   'Bug',
#   'Grass',
#   45,
#   53,
#   70,
#   40,
#   60,
#   42,
#   5,
#   '0',
#   'LC',
#   659,
#   1),
#  (1024,
#   601,
#   'Sewaddle',
#   'Bug',
#   'Grass',
#   45,
#   53,
#   70,
#   40,
#   60,
#   42,
#   5,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   659,
#   0),
#  (40672,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   360,
#   'Trapinch',
#   'Ground',
#   None,
#   45,
#   100,
#   45,
#   45,
#   45,
#   10,
#   3,
#   '0',
#   'LC',
#   660,
#   1),
#  (985,
#   360,
#   'Trapinch',
#   'Ground',
#   None,
#   45,
#   100,
#   45,
#   45,
#   45,
#   10,
#   3,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   660,
#   0),
#  (991,
#   405,
#   'Relicanth',
#   'Water',
#   'Rock',
#   100,
#   90,
#   130,
#   45,
#   65,
#   55,
#   3,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   661,
#   0),
#  (46083,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   405,
#   'Relicanth',
#   'Water',
#   'Rock',
#   100,
#   90,
#   130,
#   45,
#   65,
#   55,
#   3,
#   '0',
#   'PU',
#   661,
#   1),
#  (961,
#   261,
#   'Miltank',
#   'Normal',
#   None,
#   95,
#   80,
#   105,
#   40,
#   70,
#   100,
#   2,
#   '0',
#   'NU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   662,
#   1),
#  (29141,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   261,
#   'Miltank',
#   'Normal',
#   None,
#   95,
#   80,
#   105,
#   40,
#   70,
#   100,
#   2,
#   '0',
#   'NU',
#   662,
#   0),
#  (62540,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   566,
#   'Lillipup',
#   'Normal',
#   None,
#   45,
#   60,
#   45,
#   25,
#   45,
#   55,
#   5,
#   '0',
#   'LC',
#   663,
#   1),
#  (1015,
#   566,
#   'Lillipup',
#   'Normal',
#   None,
#   45,
#   60,
#   45,
#   25,
#   45,
#   55,
#   5,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   663,
#   0),
#  (35583,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   316,
#   'Ninjask',
#   'Bug',
#   'Flying',
#   61,
#   90,
#   45,
#   50,
#   50,
#   160,
#   3,
#   '0',
#   'PU',
#   664,
#   0),
#  (979,
#   316,
#   'Ninjask',
#   'Bug',
#   'Flying',
#   61,
#   90,
#   45,
#   50,
#   50,
#   160,
#   3,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   664,
#   1),
#  (23502,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   665,
#   0),
#  (951,
#   214,
#   'Murkrow',
#   'Dark',
#   'Flying',
#   60,
#   85,
#   42,
#   85,
#   42,
#   91,
#   2,
#   '0',
#   'NFE',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   665,
#   1),
#  (4278,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   666,
#   0),
#  (928,
#   43,
#   'Vulpix',
#   'Fire',
#   None,
#   38,
#   41,
#   40,
#   50,
#   65,
#   65,
#   1,
#   '0',
#   'LC',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   666,
#   1),
#  (84250,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   770,
#   'Aurorus',
#   'Rock',
#   'Ice',
#   123,
#   77,
#   72,
#   99,
#   92,
#   58,
#   6,
#   '0',
#   'NU',
#   667,
#   0),
#  (1049,
#   770,
#   'Aurorus',
#   'Rock',
#   'Ice',
#   123,
#   77,
#   72,
#   99,
#   92,
#   58,
#   6,
#   '0',
#   'NU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   667,
#   1),
#  (1034,
#   668,
#   'Beheeyem',
#   'Psychic',
#   None,
#   75,
#   75,
#   75,
#   125,
#   95,
#   40,
#   5,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   668,
#   0),
#  (74092,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   668,
#   'Beheeyem',
#   'Psychic',
#   None,
#   75,
#   75,
#   75,
#   125,
#   95,
#   40,
#   5,
#   '0',
#   'PU',
#   668,
#   1),
#  (43586,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   384,
#   'Castform',
#   'Normal',
#   None,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   3,
#   '0',
#   'Untiered',
#   669,
#   0),
#  (989,
#   384,
#   'Castform',
#   'Normal',
#   None,
#   70,
#   70,
#   70,
#   70,
#   70,
#   70,
#   3,
#   '0',
#   'Untiered',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   669,
#   1),
#  (1050,
#   771,
#   'Sylveon',
#   'Fairy',
#   None,
#   95,
#   65,
#   65,
#   110,
#   130,
#   60,
#   6,
#   '0',
#   'UU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   670,
#   1),
#  (84371,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   771,
#   'Sylveon',
#   'Fairy',
#   None,
#   95,
#   65,
#   65,
#   110,
#   130,
#   60,
#   6,
#   '0',
#   'UU',
#   670,
#   0),
#  (43700,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   385,
#   'Kecleon',
#   'Normal',
#   None,
#   60,
#   90,
#   70,
#   60,
#   120,
#   40,
#   3,
#   '0',
#   'NU',
#   671,
#   1),
#  (990,
#   385,
#   'Kecleon',
#   'Normal',
#   None,
#   60,
#   90,
#   70,
#   60,
#   120,
#   40,
#   3,
#   '0',
#   'NU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   671,
#   0),
#  (946,
#   156,
#   'Snorlax',
#   'Normal',
#   None,
#   160,
#   110,
#   65,
#   65,
#   110,
#   30,
#   1,
#   '0',
#   'UU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   672,
#   0),
#  (17015,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   156,
#   'Snorlax',
#   'Normal',
#   None,
#   160,
#   110,
#   65,
#   65,
#   110,
#   30,
#   1,
#   '0',
#   'UU',
#   672,
#   1),
#  (76267,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   686,
#   'Pawniard',
#   'Dark',
#   'Steel',
#   45,
#   85,
#   70,
#   40,
#   40,
#   60,
#   5,
#   '0',
#   'PU',
#   673,
#   0),
#  (1038,
#   686,
#   'Pawniard',
#   'Dark',
#   'Steel',
#   45,
#   85,
#   70,
#   40,
#   40,
#   60,
#   5,
#   '0',
#   'PU',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   673,
#   1),
#  (60239,
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   542,
#   'Palkia',
#   'Water',
#   'Dragon',
#   90,
#   120,
#   100,
#   150,
#   120,
#   100,
#   4,
#   '1',
#   'Uber',
#   674,
#   0),
#  (1010,
#   542,
#   'Palkia',
#   'Water',
#   'Dragon',
#   90,
#   120,
#   100,
#   150,
#   120,
#   100,
#   4,
#   '1',
#   'Uber',
#   11,
#   'Wartortle',
#   'Water',
#   None,
#   59,
#   63,
#   80,
#   65,
#   80,
#   58,
#   1,
#   '0',
#   'NFE',
#   674,
#   1),
#  ...]

# %%
conn.close()
