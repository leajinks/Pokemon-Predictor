# %%
# Run this file first to scrape Pokemon tier data from smogon.com, combine the data with pokemon and battle stats from Kaggle, and generate a sqlite db

# %%
# Import relevant libraries
import requests
import re
import json
import pandas as pd
import numpy as np

# %%
# Web scraping by Lea Jinks

# %%
# this cell modified from https://stackoverflow.com/q/60017438/19966544
response = requests.get('https://www.smogon.com/dex/xy/pokemon/')

# pull JSON from response text via regex
data = "".join(re.findall(r'dexSettings = (\{.*\})', response.text))

# parse JSON
data = json.loads(data)

# query JSON to return relevant info
data = data.get('injectRpcs', [])[1][1].get('pokemon')

# %%
# make list of pokemon names
name_list = []
for row in data:
  name = row.get('name')

  # make names match original csv by removing hyphens and 
  x = name.split('-')
  if "Mega" in x:
    x.reverse()
    result = " ".join(x)
  else:
    result = " ".join(x)
  name_list.append(result)

# make list of tiers
tier_list = []
for row in data:
  tier_list.append(row.get('formats'))

# %%
# create df with name and tier values
tier_df = pd.DataFrame(name_list, columns = ["Name"])
tier_df.insert(1, "Tier", tier_list)
tier_df['Tier'] = tier_df['Tier'].str[0]
tier_df
# Out:
#                    Name  Tier
# 0             Bulbasaur    LC
# 1               Ivysaur   NFE
# 2              Venusaur    RU
# 3            Charmander    LC
# 4            Charmeleon   NFE
# ..                  ...   ...
# 876      Darmanitan Zen    UU
# 877     Mega Kangaskhan  Uber
# 878  Meloetta Pirouette    RU
# 879     Mega Aerodactyl    UU
# 880      Mega Blastoise    UU
#
# [881 rows x 2 columns]

# %%
# import kaggle pokemon info dataset
pokemon_df = pd.read_csv('Resources/pokemon.csv')
pokemon_df
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# 1         80     60           1      False
# 2        100     80           1      False
# 3        120     80           1      False
# 4         50     65           1      False
# ..       ...    ...         ...        ...
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True
#
# [800 rows x 12 columns]

# %%
# standardize pokenames and combine df's 
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Forme', '')
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Size', '')
pokemon_df['Name'] = pokemon_df['Name'].str.replace('Mode', '')

# %%
# merge kaggle data with scraped tiers data
pokemon_df = pokemon_df.merge(tier_df, on='Name')

# %%
# export to json for JS formatting
pokemon_df.to_json('Resources/pokemon_with_tiers.json', orient="records", indent=4)

# %%
pokemon_df = pokemon_df.reset_index()

# %%
# rename columns to be compatible with sqlite
pokemon_df = pokemon_df.rename(columns={'#': 'Number', 'index':'_ID', 'Type 1':'Type_1', 'Type 2':'Type_2', "Sp. Atk": "Sp_Atk", 'Sp. Def': 'Sp_Def' })
pokemon_df
# Out:
#      _ID  Number           Name   Type_1  Type_2   HP  Attack  Defense  \
# 0      0       1      Bulbasaur    Grass  Poison   45      49       49
# 1      1       2        Ivysaur    Grass  Poison   60      62       63
# 2      2       3       Venusaur    Grass  Poison   80      82       83
# 3      3       4  Mega Venusaur    Grass  Poison   80     100      123
# 4      4       5     Charmander     Fire     NaN   39      52       43
# ..   ...     ...            ...      ...     ...  ...     ...      ...
# 739  739     794        Yveltal     Dark  Flying  126     131       95
# 740  740     796        Diancie     Rock   Fairy   50     100      150
# 741  741     797   Mega Diancie     Rock   Fairy   50     160      110
# 742  742     799  Hoopa Unbound  Psychic    Dark   80     160       60
# 743  743     800      Volcanion     Fire   Water   80     110      120
#
#      Sp_Atk  Sp_Def  Speed  Generation  Legendary  Tier
# 0        65      65     45           1      False    LC
# 1        80      80     60           1      False   NFE
# 2       100     100     80           1      False    RU
# 3       122     120     80           1      False    OU
# 4        60      50     65           1      False    LC
# ..      ...     ...    ...         ...        ...   ...
# 739     131      98     99           6       True  Uber
# 740     100     150     50           6       True    RU
# 741     160     110    110           6       True    OU
# 742     170     130     80           6       True  Uber
# 743     130      90     70           6       True    OU
#
# [744 rows x 14 columns]

# %%
# create sqlite file for flask app by Becky Klosowski

# %%
import sqlite3
from pathlib import Path

# %%
database_path = "Resources/pokemon_with_tiers.sqlite"
Path(database_path).touch()

# %%
conn = sqlite3.connect(database_path)
c = conn.cursor()

# %%
c.execute('''DROP TABLE IF EXISTS poketiers;''')

# %%
c.execute('''CREATE TABLE poketiers(
    _ID INT NOT NULL PRIMARY KEY,
    Number INT NOT NULL,
  	Name VARCHAR(40) NOT NULL,
    Type_1 VARCHAR(40),
	Type_2 VARCHAR(40),
	HP INT NOT NULL,
	Attack INT NOT NULL,
	Defense INT NOT NULL,
	Sp_Atk INT NOT NULL,
	Sp_Def INT NOT NULL,
	Speed INT NOT NULL,
	Generation INT NOT NULL,
	Legendary INT NOT NULL,
	Tier VARCHAR(40) NOT NULL
	);''')

# %%
pokemon_df.to_sql("poketiers", conn, if_exists='append', index = False)

# %%
c.execute('''SELECT * from poketiers''').fetchone()
# Out:
# (0, 1, 'Bulbasaur', 'Grass', 'Poison', 45, 49, 49, 65, 65, 45, 1, 0, 'LC')

# %%
conn.close()

# %%
#Data Exploration by Crystal Butler

# %%
pokemon_df.head()
# Out:
#    _ID  Number           Name Type_1  Type_2  HP  Attack  Defense  Sp_Atk  \
# 0    0       1      Bulbasaur  Grass  Poison  45      49       49      65
# 1    1       2        Ivysaur  Grass  Poison  60      62       63      80
# 2    2       3       Venusaur  Grass  Poison  80      82       83     100
# 3    3       4  Mega Venusaur  Grass  Poison  80     100      123     122
# 4    4       5     Charmander   Fire     NaN  39      52       43      60
#
#    Sp_Def  Speed  Generation  Legendary Tier
# 0      65     45           1      False   LC
# 1      80     60           1      False  NFE
# 2     100     80           1      False   RU
# 3     120     80           1      False   OU
# 4      50     65           1      False   LC

# %%
battles_df = pd.read_csv("Resources/combats.csv")

# %%
battles_df = battles_df.sort_values('First_pokemon')

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner
# 15176              1             372     372
# 45814              1             462     462
# 17362              1               6       6
# 15251              1             649     649
# 4883               1             285       1

# %%
initial_value = 1
battles_df['Battle_number'] = range(initial_value, len(battles_df) +initial_value)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5

# %%
battles_df['Did_the_first_pokemon_win?'] = (battles_df['First_pokemon'] == battles_df['Winner']).astype(int)

# %%
battles_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176              1             372     372              1
# 45814              1             462     462              2
# 17362              1               6       6              3
# 15251              1             649     649              4
# 4883               1             285       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           0
# 45814                           0
# 17362                           0
# 15251                           0
# 4883                            1

# %%
battles2_df = battles_df.copy()

# %%
battles2_df = battles2_df.iloc[:,[1,0,2,3]]

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5

# %%
battles2_df['Did_the_first_pokemon_win?'] = (battles2_df['Second_pokemon'] == battles2_df['Winner']).astype(int)

# %%
battles2_df.head()
# Out:
#        Second_pokemon  First_pokemon  Winner  Battle_number  \
# 15176             372              1     372              1
# 45814             462              1     462              2
# 17362               6              1       6              3
# 15251             649              1     649              4
# 4883              285              1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
battles2_df.rename(columns = {'Second_pokemon':'First_pokemon', 'First_pokemon':'Second_pokemon'}, inplace = True)

# %%
battles2_df.head()
# Out:
#        First_pokemon  Second_pokemon  Winner  Battle_number  \
# 15176            372               1     372              1
# 45814            462               1     462              2
# 17362              6               1       6              3
# 15251            649               1     649              4
# 4883             285               1       1              5
#
#        Did_the_first_pokemon_win?
# 15176                           1
# 45814                           1
# 17362                           1
# 15251                           1
# 4883                            0

# %%
all_battles_df = pd.concat([battles_df, battles2_df], axis=0)

# %%
all_battles_df = all_battles_df.sort_values('Battle_number')

# %%
all_battles_df.dtypes
# Out:
# First_pokemon                 int64
# Second_pokemon                int64
# Winner                        int64
# Battle_number                 int64
# Did_the_first_pokemon_win?    int64
# dtype: object

# %%
merged_df = pd.merge(all_battles_df,pokemon_df, how='inner', left_on=['First_pokemon'], right_on = ['Number'])
merged_df.head()
# Out:
#    First_pokemon  Second_pokemon  Winner  Battle_number  \
# 0              1             372     372              1
# 1              1             462     462              2
# 2              1               6       6              3
# 3              1             649     649              4
# 4              1             285       1              5
#
#    Did_the_first_pokemon_win?  _ID  Number       Name Type_1  Type_2  HP  \
# 0                           0    0       1  Bulbasaur  Grass  Poison  45
# 1                           0    0       1  Bulbasaur  Grass  Poison  45
# 2                           0    0       1  Bulbasaur  Grass  Poison  45
# 3                           0    0       1  Bulbasaur  Grass  Poison  45
# 4                           1    0       1  Bulbasaur  Grass  Poison  45
#
#    Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary Tier
# 0      49       49      65      65     45           1      False   LC
# 1      49       49      65      65     45           1      False   LC
# 2      49       49      65      65     45           1      False   LC
# 3      49       49      65      65     45           1      False   LC
# 4      49       49      65      65     45           1      False   LC

# %%
merged_df = merged_df.iloc[:,[3,0,7,1,2,4]]

# %%
merged_df.rename(columns = {'Name':'First_name'},inplace = True)

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon First_name  Second_pokemon  Winner  \
# 0              1              1  Bulbasaur             372     372
# 1              2              1  Bulbasaur             462     462
# 2              3              1  Bulbasaur               6       6
# 3              4              1  Bulbasaur             649     649
# 4              5              1  Bulbasaur             285       1
#
#    Did_the_first_pokemon_win?
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           1

# %%
merged_df = pd.merge(merged_df,pokemon_df, how='inner', left_on=['Second_pokemon'], right_on = ['Number'])

# %%
merged_df.head()
# Out:
#    Battle_number  First_pokemon  First_name  Second_pokemon  Winner  \
# 0              1              1   Bulbasaur             372     372
# 1          23232            638  Gothitelle             372     638
# 2          24480            391     Tropius             372     372
# 3          23218            558       Tepig             372     372
# 4          19353            311     Breloom             372     311
#
#    Did_the_first_pokemon_win?  _ID  Number      Name Type_1  Type_2  HP  \
# 0                           0  363     372  Barboach  Water  Ground  50
# 1                           1  363     372  Barboach  Water  Ground  50
# 2                           0  363     372  Barboach  Water  Ground  50
# 3                           0  363     372  Barboach  Water  Ground  50
# 4                           1  363     372  Barboach  Water  Ground  50
#
#    Attack  Defense  Sp_Atk  Sp_Def  Speed  Generation  Legendary Tier
# 0      48       43      46      41     60           3      False   LC
# 1      48       43      46      41     60           3      False   LC
# 2      48       43      46      41     60           3      False   LC
# 3      48       43      46      41     60           3      False   LC
# 4      48       43      46      41     60           3      False   LC

# %%
merged_df.rename(columns = {'Name':'Second_name'},inplace = True)

# %%
merged_df = merged_df.iloc[:,[0,1,2,3,8,4,5]]

# %%
merged_df = merged_df.sort_values('Battle_number')

# %%
merged_df.head()
# Out:
#        Battle_number  First_pokemon  First_name  Second_pokemon Second_name  \
# 0                  1              1   Bulbasaur             372    Barboach
# 14008              1            372    Barboach               1   Bulbasaur
# 14009              2            462      Mothim               1   Bulbasaur
# 140                2              1   Bulbasaur             462      Mothim
# 14010              3              6  Charmeleon               1   Bulbasaur
#
#        Winner  Did_the_first_pokemon_win?
# 0         372                           0
# 14008     372                           1
# 14009     462                           1
# 140       462                           0
# 14010       6                           1

# %%
winner_df_names = merged_df.iloc[:,[0,2,4,6]]

# %%
winner_df_names.head()
# Out:
#        Battle_number  First_name Second_name  Did_the_first_pokemon_win?
# 0                  1   Bulbasaur    Barboach                           0
# 14008              1    Barboach   Bulbasaur                           1
# 14009              2      Mothim   Bulbasaur                           1
# 140                2   Bulbasaur      Mothim                           0
# 14010              3  Charmeleon   Bulbasaur                           1

# %%
#merging pokemon_df and merged_df dataframe, so First Name can have it's attributes associated with the pokemon that have battled
merged_w_tiers = pd.merge(pokemon_df,merged_df, how='left', left_on=['Name'], right_on=['First_name'])

# %%
#viewing dataframe
merged_w_tiers.head()
# Out:
#    _ID  Number       Name Type_1  Type_2  HP  Attack  Defense  Sp_Atk  Sp_Def  \
# 0    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 1    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 2    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 3    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
# 4    0       1  Bulbasaur  Grass  Poison  45      49       49      65      65
#
#    ...  Generation  Legendary  Tier Battle_number  First_pokemon  First_name  \
# 0  ...           1      False    LC           1.0            1.0   Bulbasaur
# 1  ...           1      False    LC           2.0            1.0   Bulbasaur
# 2  ...           1      False    LC           3.0            1.0   Bulbasaur
# 3  ...           1      False    LC           4.0            1.0   Bulbasaur
# 4  ...           1      False    LC           5.0            1.0   Bulbasaur
#
#   Second_pokemon  Second_name Winner  Did_the_first_pokemon_win?
# 0          372.0     Barboach  372.0                         0.0
# 1          462.0       Mothim  462.0                         0.0
# 2            6.0   Charmeleon    6.0                         0.0
# 3          649.0       Emolga  649.0                         0.0
# 4          285.0    Poochyena    1.0                         1.0
#
# [5 rows x 21 columns]

# %%
#merging pokemon_df and merged_w_tiers dataframe, so Second Name can have it's attributes as well
merged_w_tiers2 = pd.merge(pokemon_df,merged_w_tiers, how='left', left_on=['Name'], right_on=['Second_name']).sort_values('Battle_number')

# %%
#viewing columns for renaming
merged_w_tiers2.columns
# Out:
# Index(['_ID_x', 'Number_x', 'Name_x', 'Type_1_x', 'Type_2_x', 'HP_x',
#        'Attack_x', 'Defense_x', 'Sp_Atk_x', 'Sp_Def_x', 'Speed_x',
#        'Generation_x', 'Legendary_x', 'Tier_x', '_ID_y', 'Number_y', 'Name_y',
#        'Type_1_y', 'Type_2_y', 'HP_y', 'Attack_y', 'Defense_y', 'Sp_Atk_y',
#        'Sp_Def_y', 'Speed_y', 'Generation_y', 'Legendary_y', 'Tier_y',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win?'],
#       dtype='object')

# %%
#Renaming columns to reflect which attributes go to which Pokemon (First or Second)
merged_w_tiers2 = merged_w_tiers2.rename(columns={'Number_x':'Number_Second', 'Name_x':'Second_Name', 'Type_1_x':'Type_1_Second', 'Type_2_x':'Type_2_Second', 'HP_x':'HP_Second', 'Attack_x':'Attack_Second',
       'Defense_x':'Defense_Second', 'Sp_Atk_x':'Sp_Atk_Second', 'Sp_Def_x':'Sp_Def_Second', 'Speed_x':'Speed_Second', 'Generation_x':'Generation_Second',
       'Legendary_x':'Legendary_Second', 'Tier_x':'Tier_Second', 'Number_y':'Number_First', 'Name_y':'First_Name', 'Type_1_y':'Type_1_First', 'Type_2_y':'Type_2_First',
       'HP_y':'HP_First', 'Attack_y':'Attack_First', 'Defense_y':'Defense_First', 'Sp_Atk_y':'Sp_Atk_First', 'Sp_Def_y':'Sp_Def_First', 'Speed_y':'Speed_First',
       'Generation_y':'Generation_First', 'Legendary_y':'Legendary_First', 'Tier_y':'Tier_First', 'Did_the_first_pokemon_win?':'Did_the_first_pokemon_win' })
merged_w_tiers2
# Out:
#        _ID_x  Number_Second  Second_Name Type_1_Second Type_2_Second  \
# 65         0              1    Bulbasaur         Grass        Poison
# 42104    363            372     Barboach         Water        Ground
# 79         0              1    Bulbasaur         Grass        Poison
# 51724    444            462       Mothim           Bug        Flying
# 0          0              1    Bulbasaur         Grass        Poison
# ...      ...            ...          ...           ...           ...
# 47791    410            419  Mega Latias        Dragon       Psychic
# 53730    461            479    Honchkrow          Dark        Flying
# 61445    528            556      Servine         Grass           NaN
# 68469    588            618     Maractus         Grass           NaN
# 72650    625            655    Jellicent         Water         Ghost
#
#        HP_Second  Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  \
# 65            45             49              49             65             65
# 42104         50             48              43             46             41
# 79            45             49              49             65             65
# 51724         70             94              50             94             50
# 0             45             49              49             65             65
# ...          ...            ...             ...            ...            ...
# 47791         80            100             120            140            150
# 53730        100            125              52            105             52
# 61445         60             60              75             60             75
# 68469         75             86              67            106             67
# 72650        100             60              70             85            105
#
#        ...  Generation_First  Legendary_First  Tier_First Battle_number  \
# 65     ...               3.0            False          LC           1.0
# 42104  ...               1.0            False          LC           1.0
# 79     ...               4.0            False    Untiered           2.0
# 51724  ...               1.0            False          LC           2.0
# 0      ...               1.0            False         NFE           3.0
# ...    ...               ...              ...         ...           ...
# 47791  ...               NaN              NaN         NaN           NaN
# 53730  ...               NaN              NaN         NaN           NaN
# 61445  ...               NaN              NaN         NaN           NaN
# 68469  ...               NaN              NaN         NaN           NaN
# 72650  ...               NaN              NaN         NaN           NaN
#
#        First_pokemon  First_name Second_pokemon Second_name Winner  \
# 65             372.0    Barboach            1.0   Bulbasaur  372.0
# 42104            1.0   Bulbasaur          372.0    Barboach  372.0
# 79             462.0      Mothim            1.0   Bulbasaur  462.0
# 51724            1.0   Bulbasaur          462.0      Mothim  462.0
# 0                6.0  Charmeleon            1.0   Bulbasaur    6.0
# ...              ...         ...            ...         ...    ...
# 47791            NaN         NaN            NaN         NaN    NaN
# 53730            NaN         NaN            NaN         NaN    NaN
# 61445            NaN         NaN            NaN         NaN    NaN
# 68469            NaN         NaN            NaN         NaN    NaN
# 72650            NaN         NaN            NaN         NaN    NaN
#
#        Did_the_first_pokemon_win
# 65                           1.0
# 42104                        0.0
# 79                           1.0
# 51724                        0.0
# 0                            1.0
# ...                          ...
# 47791                        NaN
# 53730                        NaN
# 61445                        NaN
# 68469                        NaN
# 72650                        NaN
#
# [86739 rows x 35 columns]

# %%
#Sorting by Battle Number
merged_w_tiers2 = merged_w_tiers2.sort_values('Battle_number')

# %%
#Filtering to just Pokemon without battles
orphan_pokemon = merged_w_tiers2[merged_w_tiers2['Battle_number'].isnull()]

# %%
#Dataframe of Pokemon that haven't battled

orphan_pokemon.head()
# Out:
#       _ID_x  Number_Second Second_Name Type_1_Second Type_2_Second  HP_Second  \
# 1057      9             12   Blastoise         Water           NaN         79
# 3442     30             33   Sandshrew        Ground           NaN         50
# 4635     41             46  Wigglytuff        Normal         Fairy        140
# 6830     60             66     Poliwag         Water           NaN         40
# 8109     72             78  Victreebel         Grass        Poison         80
#
#       Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  ...  \
# 1057             83             100             85            105  ...
# 3442             75              85             20             30  ...
# 4635             70              45             85             50  ...
# 6830             50              40             40             40  ...
# 8109            105              65            100             70  ...
#
#       Generation_First  Legendary_First  Tier_First Battle_number  \
# 1057               NaN              NaN         NaN           NaN
# 3442               NaN              NaN         NaN           NaN
# 4635               NaN              NaN         NaN           NaN
# 6830               NaN              NaN         NaN           NaN
# 8109               NaN              NaN         NaN           NaN
#
#       First_pokemon  First_name Second_pokemon Second_name Winner  \
# 1057            NaN         NaN            NaN         NaN    NaN
# 3442            NaN         NaN            NaN         NaN    NaN
# 4635            NaN         NaN            NaN         NaN    NaN
# 6830            NaN         NaN            NaN         NaN    NaN
# 8109            NaN         NaN            NaN         NaN    NaN
#
#       Did_the_first_pokemon_win
# 1057                        NaN
# 3442                        NaN
# 4635                        NaN
# 6830                        NaN
# 8109                        NaN
#
# [5 rows x 35 columns]

# %%
#filtering out Pokemon that haven't battled
merged_reduced =merged_w_tiers2.dropna(subset=['Battle_number']).sort_values('Battle_number')

# %%
#Dataframe with only Pokemon that were involved in a battle

merged_reduced.head()
# Out:
#        _ID_x  Number_Second Second_Name Type_1_Second Type_2_Second  \
# 65         0              1   Bulbasaur         Grass        Poison
# 42104    363            372    Barboach         Water        Ground
# 79         0              1   Bulbasaur         Grass        Poison
# 51724    444            462      Mothim           Bug        Flying
# 0          0              1   Bulbasaur         Grass        Poison
#
#        HP_Second  Attack_Second  Defense_Second  Sp_Atk_Second  Sp_Def_Second  \
# 65            45             49              49             65             65
# 42104         50             48              43             46             41
# 79            45             49              49             65             65
# 51724         70             94              50             94             50
# 0             45             49              49             65             65
#
#        ...  Generation_First  Legendary_First  Tier_First Battle_number  \
# 65     ...               3.0            False          LC           1.0
# 42104  ...               1.0            False          LC           1.0
# 79     ...               4.0            False    Untiered           2.0
# 51724  ...               1.0            False          LC           2.0
# 0      ...               1.0            False         NFE           3.0
#
#        First_pokemon  First_name Second_pokemon Second_name Winner  \
# 65             372.0    Barboach            1.0   Bulbasaur  372.0
# 42104            1.0   Bulbasaur          372.0    Barboach  372.0
# 79             462.0      Mothim            1.0   Bulbasaur  462.0
# 51724            1.0   Bulbasaur          462.0      Mothim  462.0
# 0                6.0  Charmeleon            1.0   Bulbasaur    6.0
#
#        Did_the_first_pokemon_win
# 65                           1.0
# 42104                        0.0
# 79                           1.0
# 51724                        0.0
# 0                            1.0
#
# [5 rows x 35 columns]

# %%
merged_reduced.columns
# Out:
# Index(['_ID_x', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '_ID_y', 'Number_First',
#        'First_Name', 'Type_1_First', 'Type_2_First', 'HP_First',
#        'Attack_First', 'Defense_First', 'Sp_Atk_First', 'Sp_Def_First',
#        'Speed_First', 'Generation_First', 'Legendary_First', 'Tier_First',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
merged_reduced[['Number_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second', 'Number_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win']] = merged_reduced[['Number_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second', 'Number_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Battle_number',
       'First_pokemon', 'Second_pokemon',
       'Winner', 'Did_the_first_pokemon_win']].astype(int)

# %%
merged_reduced.columns
# Out:
# Index(['_ID_x', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', '_ID_y', 'Number_First',
#        'First_Name', 'Type_1_First', 'Type_2_First', 'HP_First',
#        'Attack_First', 'Defense_First', 'Sp_Atk_First', 'Sp_Def_First',
#        'Speed_First', 'Generation_First', 'Legendary_First', 'Tier_First',
#        'Battle_number', 'First_pokemon', 'First_name', 'Second_pokemon',
#        'Second_name', 'Winner', 'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
final_df = merged_reduced[['Number_First', 'First_Name',
       'Type_1_First', 'Type_2_First', 'HP_First', 'Attack_First',
       'Defense_First', 'Sp_Atk_First', 'Sp_Def_First', 'Speed_First',
       'Generation_First', 'Legendary_First', 'Tier_First','Number_Second', 'Second_Name', 'Type_1_Second', 'Type_2_Second',
       'HP_Second', 'Attack_Second', 'Defense_Second', 'Sp_Atk_Second',
       'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
       'Legendary_Second', 'Tier_Second',  'Battle_number',
       'Did_the_first_pokemon_win']]

# %%
final_df.head()
# Out:
#        Number_First  First_Name Type_1_First Type_2_First  HP_First  \
# 65              372    Barboach        Water       Ground        50
# 42104             1   Bulbasaur        Grass       Poison        45
# 79              462      Mothim          Bug       Flying        70
# 51724             1   Bulbasaur        Grass       Poison        45
# 0                 6  Charmeleon         Fire          NaN        58
#
#        Attack_First  Defense_First  Sp_Atk_First  Sp_Def_First  Speed_First  \
# 65               48             43            46            41           60
# 42104            49             49            65            65           45
# 79               94             50            94            50           66
# 51724            49             49            65            65           45
# 0                64             58            80            65           80
#
#        ...  Attack_Second Defense_Second Sp_Atk_Second  Sp_Def_Second  \
# 65     ...             49             49            65             65
# 42104  ...             48             43            46             41
# 79     ...             49             49            65             65
# 51724  ...             94             50            94             50
# 0      ...             49             49            65             65
#
#       Speed_Second Generation_Second Legendary_Second  Tier_Second  \
# 65              45                 1            False           LC
# 42104           60                 3            False           LC
# 79              45                 1            False           LC
# 51724           66                 4            False     Untiered
# 0               45                 1            False           LC
#
#        Battle_number  Did_the_first_pokemon_win
# 65                 1                          1
# 42104              1                          0
# 79                 2                          1
# 51724              2                          0
# 0                  3                          1
#
# [5 rows x 28 columns]

# %%
final_df.dtypes
# Out:
# Number_First                  int64
# First_Name                   object
# Type_1_First                 object
# Type_2_First                 object
# HP_First                      int64
# Attack_First                  int64
# Defense_First                 int64
# Sp_Atk_First                  int64
# Sp_Def_First                  int64
# Speed_First                   int64
# Generation_First              int64
# Legendary_First              object
# Tier_First                   object
# Number_Second                 int64
# Second_Name                  object
# Type_1_Second                object
# Type_2_Second                object
# HP_Second                     int64
# Attack_Second                 int64
# Defense_Second                int64
# Sp_Atk_Second                 int64
# Sp_Def_Second                 int64
# Speed_Second                  int64
# Generation_Second             int64
# Legendary_Second               bool
# Tier_Second                  object
# Battle_number                 int64
# Did_the_first_pokemon_win     int64
# dtype: object

# %%
final_df.index.name = "_ID"

# %%
final_df.columns
# Out:
# Index(['Number_First', 'First_Name', 'Type_1_First', 'Type_2_First',
#        'HP_First', 'Attack_First', 'Defense_First', 'Sp_Atk_First',
#        'Sp_Def_First', 'Speed_First', 'Generation_First', 'Legendary_First',
#        'Tier_First', 'Number_Second', 'Second_Name', 'Type_1_Second',
#        'Type_2_Second', 'HP_Second', 'Attack_Second', 'Defense_Second',
#        'Sp_Atk_Second', 'Sp_Def_Second', 'Speed_Second', 'Generation_Second',
#        'Legendary_Second', 'Tier_Second', 'Battle_number',
#        'Did_the_first_pokemon_win'],
#       dtype='object')

# %%
final_df.to_csv("Resources/final_df.csv")

# %%
# sqlite setup by Lea Jinks

# %%
database_path = "Resources/pokemon.sqlite"
Path(database_path).touch()

# %%
conn = sqlite3.connect(database_path)
c = conn.cursor()

# %%
c.execute('''DROP TABLE IF EXISTS pokemon;''')

# %%
c.execute('''CREATE TABLE pokemon(
    _ID INT NOT NULL PRIMARY KEY,
    Number_First INT NOT NULL,
  	First_Name VARCHAR(40) NOT NULL,
    Type_1_First VARCHAR(40),
	Type_2_First VARCHAR(40),
	HP_First INT NOT NULL,
	Attack_First INT NOT NULL,
	Defense_First INT NOT NULL,
	Sp_Atk_First INT NOT NULL,
	Sp_Def_First INT NOT NULL,
	Speed_First INT NOT NULL,
	Generation_First INT NOT NULL,
	Legendary_First VARCHAR(40),
	Tier_First VARCHAR(40) NOT NULL,
	Number_Second INT NOT NULL,
	Second_Name VARCHAR(40) NOT NULL,
	Type_1_Second VARCHAR(40),
	Type_2_Second VARCHAR(40),
	HP_Second INT NOT NULL,
	Attack_Second INT NOT NULL,
	Defense_Second INT NOT NULL,
	Sp_Atk_Second INT NOT NULL,
	Sp_Def_Second INT NOT NULL,
	Speed_Second INT NOT NULL,
	Generation_Second INT NOT NULL,
	Legendary_Second VARCHAR(40),
	Tier_Second VARCHAR(40) NOT NULL,
	Battle_number INT NOT NULL,
    Did_the_first_pokemon_win INT NOT NULL
   	);''')

# %%
poke_df = pd.read_csv("Resources/final_df.csv")

# %%
poke_df.head()
# Out:
#      _ID  Number_First  First_Name Type_1_First Type_2_First  HP_First  \
# 0     65           372    Barboach        Water       Ground        50
# 1  42104             1   Bulbasaur        Grass       Poison        45
# 2     79           462      Mothim          Bug       Flying        70
# 3  51724             1   Bulbasaur        Grass       Poison        45
# 4      0             6  Charmeleon         Fire          NaN        58
#
#    Attack_First  Defense_First  Sp_Atk_First  Sp_Def_First  ...  \
# 0            48             43            46            41  ...
# 1            49             49            65            65  ...
# 2            94             50            94            50  ...
# 3            49             49            65            65  ...
# 4            64             58            80            65  ...
#
#    Attack_Second  Defense_Second  Sp_Atk_Second Sp_Def_Second  Speed_Second  \
# 0             49              49             65            65            45
# 1             48              43             46            41            60
# 2             49              49             65            65            45
# 3             94              50             94            50            66
# 4             49              49             65            65            45
#
#   Generation_Second Legendary_Second Tier_Second  Battle_number  \
# 0                 1            False          LC              1
# 1                 3            False          LC              1
# 2                 1            False          LC              2
# 3                 4            False    Untiered              2
# 4                 1            False          LC              3
#
#    Did_the_first_pokemon_win
# 0                          1
# 1                          0
# 2                          1
# 3                          0
# 4                          1
#
# [5 rows x 29 columns]

# %%
poke_df.to_sql("pokemon", conn, if_exists='append', index = False)

# %%
c.execute('''SELECT * from pokemon''').fetchone()
# Out:
# (65,
#  372,
#  'Barboach',
#  'Water',
#  'Ground',
#  50,
#  48,
#  43,
#  46,
#  41,
#  60,
#  3,
#  '0',
#  'LC',
#  1,
#  'Bulbasaur',
#  'Grass',
#  'Poison',
#  45,
#  49,
#  49,
#  65,
#  65,
#  45,
#  1,
#  '0',
#  'LC',
#  1,
#  1)

# %%
conn.close()
